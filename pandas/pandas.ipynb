# %%
import pandas as pd

# %%
df = pd.read_csv("data.csv", low_memory=False, index_col="ResponseId")

# %%
#Got a DtypeWarning because some columns have mixed data types. Fixed by passing low_memory=False to read_csv, which reads the entire file at once before inferring column types.

# %%
#you can specify how many
df.head()
# Out:
#                                 MainBranch              Age  \
# ResponseId
# 1           I am a developer by profession  25-34 years old
# 2           I am a developer by profession  25-34 years old
# 3           I am a developer by profession  35-44 years old
# 4           I am a developer by profession  35-44 years old
# 5           I am a developer by profession  35-44 years old
#
#                                                     EdLevel  \
# ResponseId
# 1           Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 2                       Associate degree (A.A., A.S., etc.)
# 3              Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 4              Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 5           Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
#
#                                                    Employment  \
# ResponseId
# 1                                                    Employed
# 2                                                    Employed
# 3           Independent contractor, freelancer, or self-em...
# 4                                                    Employed
# 5           Independent contractor, freelancer, or self-em...
#
#                                              EmploymentAddl  WorkExp  \
# ResponseId
# 1           Caring for dependents (children, elderly, etc.)      8.0
# 2                                                       NaN      2.0
# 3                                         None of the above     10.0
# 4                                         None of the above      4.0
# 5           Caring for dependents (children, elderly, etc.)     21.0
#
#                                               LearnCodeChoose  \
# ResponseId
# 1           Yes, I am not new to coding but am learning ne...
# 2           Yes, I am not new to coding but am learning ne...
# 3           Yes, I am not new to coding but am learning ne...
# 4           Yes, I am not new to coding but am learning ne...
# 5           No, I am not new to coding and did not learn n...
#
#                                                     LearnCode  \
# ResponseId
# 1           Online Courses or Certification (includes all ...
# 2           Online Courses or Certification (includes all ...
# 3           Online Courses or Certification (includes all ...
# 4           Other online resources (e.g. standard search, ...
# 5                                                         NaN
#
#                                                   LearnCodeAI  \
# ResponseId
# 1           Yes, I learned how to use AI-enabled tools for...
# 2           Yes, I learned how to use AI-enabled tools for...
# 3           Yes, I learned how to use AI-enabled tools for...
# 4           Yes, I learned how to use AI-enabled tools for...
# 5           Yes, I learned how to use AI-enabled tools for...
#
#                                                    AILearnHow  ...  \
# ResponseId                                                     ...
# 1                         AI CodeGen tools or AI-enabled apps  ...
# 2                         AI CodeGen tools or AI-enabled apps  ...
# 3           AI CodeGen tools or AI-enabled apps;Technical ...  ...
# 4           AI CodeGen tools or AI-enabled apps;Videos (no...  ...
# 5           Technical documentation (is generated for/by t...  ...
#
#             AIAgentOrchestration AIAgentOrchWrite AIAgentObserveSecure  \
# ResponseId
# 1                      Vertex AI              NaN                  NaN
# 2                            NaN              NaN                  NaN
# 3                            NaN              NaN                  NaN
# 4                            NaN              NaN                  NaN
# 5                            NaN              NaN                  NaN
#
#            AIAgentObsWrite                                   AIAgentExternal  \
# ResponseId
# 1                      NaN                                           ChatGPT
# 2                      NaN                                               NaN
# 3                      NaN  ChatGPT;Claude Code;GitHub Copilot;Google Gemini
# 4                      NaN                               ChatGPT;Claude Code
# 5                      NaN                                               NaN
#
#            AIAgentExtWrite                                            AIHuman  \
# ResponseId
# 1                      NaN                    When I don’t trust AI’s answers
# 2                      NaN  When I don’t trust AI’s answers;When I want to...
# 3                      NaN  When I don’t trust AI’s answers;When I want to...
# 4                      NaN  When I don’t trust AI’s answers;When I want to...
# 5                      NaN                    When I don’t trust AI’s answers
#
#                                                        AIOpen  \
# ResponseId
# 1                       Troubleshooting, profiling, debugging
# 2                                   All skills. AI is a flop.
# 3           Understand how things actually work, problem s...
# 4                                                         NaN
# 5           critical thinking, the skill to define the tas...
#
#             ConvertedCompYearly  JobSat
# ResponseId
# 1                       61256.0    10.0
# 2                      104413.0     9.0
# 3                       53061.0     8.0
# 4                       36197.0     6.0
# 5                       60000.0     7.0
#
# [5 rows x 171 columns]

# %%
df.tail(10)
# Out:
#        ResponseId                                         MainBranch  \
# 49181       49182                     I am a developer by profession
# 49182       49183                     I am a developer by profession
# 49183       49184                     I am a developer by profession
# 49184       49185  I am not primarily a developer, but I write co...
# 49185       49186                     I am a developer by profession
# 49186       49187                        I code primarily as a hobby
# 49187       49188                     I am a developer by profession
# 49188       49189                     I am a developer by profession
# 49189       49190                     I am a developer by profession
# 49190       49191  I am not primarily a developer, but I write co...
#
#                    Age                                            EdLevel  \
# 49181  25-34 years old       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 49182  35-44 years old                                                NaN
# 49183  25-34 years old    Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 49184  45-54 years old     Professional degree (JD, MD, Ph.D, Ed.D, etc.)
# 49185  25-34 years old       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 49186  18-24 years old       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 49187  45-54 years old  Some college/university study without earning ...
# 49188  35-44 years old    Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 49189  25-34 years old     Professional degree (JD, MD, Ph.D, Ed.D, etc.)
# 49190  18-24 years old  Some college/university study without earning ...
#
#                                               Employment  \
# 49181                                            Student
# 49182                                                NaN
# 49183                                           Employed
# 49184                                           Employed
# 49185                                           Employed
# 49186                                           Employed
# 49187                                           Employed
# 49188                                           Employed
# 49189  Independent contractor, freelancer, or self-em...
# 49190                                            Student
#
#                                           EmploymentAddl  WorkExp  \
# 49181                                                NaN      NaN
# 49182                                                NaN      NaN
# 49183                                  None of the above      2.0
# 49184  Caring for dependents (children, elderly, etc....     30.0
# 49185                                                NaN      NaN
# 49186                                                NaN      NaN
# 49187    Caring for dependents (children, elderly, etc.)     25.0
# 49188                                  None of the above     17.0
# 49189                                  None of the above      2.0
# 49190                       Attending school (full-time)      NaN
#
#                                          LearnCodeChoose  \
# 49181                                                NaN
# 49182                                                NaN
# 49183     Yes, I am new to coding or currently a student
# 49184  Yes, I am not new to coding but am learning ne...
# 49185                                                NaN
# 49186                                                NaN
# 49187  Yes, I am not new to coding but am learning ne...
# 49188  Yes, I am not new to coding but am learning ne...
# 49189  Yes, I am not new to coding but am learning ne...
# 49190  Yes, I am not new to coding but am learning ne...
#
#                                                LearnCode  \
# 49181                                                NaN
# 49182                                                NaN
# 49183  Books / Physical media;Videos (not associated ...
# 49184  Online Courses or Certification (includes all ...
# 49185                                                NaN
# 49186                                                NaN
# 49187  Online Courses or Certification (includes all ...
# 49188  Online Courses or Certification (includes all ...
# 49189  Videos (not associated with specific online co...
# 49190  Online Courses or Certification (includes all ...
#
#                                              LearnCodeAI  ...  \
# 49181                                                NaN  ...
# 49182                                                NaN  ...
# 49183  Yes, I learned how to use AI-enabled tools for...  ...
# 49184  Yes, I learned how to use AI-enabled tools req...  ...
# 49185                                                NaN  ...
# 49186                                                NaN  ...
# 49187  Yes, I learned how to use AI-enabled tools req...  ...
# 49188  Yes, I learned how to use AI-enabled tools for...  ...
# 49189  Yes, I learned how to use AI-enabled tools for...  ...
# 49190  Yes, I learned how to use AI-enabled tools for...  ...
#
#       AIAgentOrchestration  AIAgentOrchWrite AIAgentObserveSecure  \
# 49181                  NaN               NaN                  NaN
# 49182                  NaN               NaN                  NaN
# 49183                  NaN               NaN                  NaN
# 49184                  NaN               NaN                  NaN
# 49185                  NaN               NaN                  NaN
# 49186                  NaN               NaN                  NaN
# 49187                  NaN               NaN                  NaN
# 49188                  NaN               NaN                  NaN
# 49189                  NaN               NaN                  NaN
# 49190                  NaN               NaN                  NaN
#
#       AIAgentObsWrite AIAgentExternal AIAgentExtWrite AIHuman AIOpen  \
# 49181             NaN             NaN             NaN     NaN    NaN
# 49182             NaN             NaN             NaN     NaN    NaN
# 49183             NaN             NaN             NaN     NaN    NaN
# 49184             NaN             NaN             NaN     NaN    NaN
# 49185             NaN             NaN             NaN     NaN    NaN
# 49186             NaN             NaN             NaN     NaN    NaN
# 49187             NaN             NaN             NaN     NaN    NaN
# 49188             NaN             NaN             NaN     NaN    NaN
# 49189             NaN             NaN             NaN     NaN    NaN
# 49190             NaN             NaN             NaN     NaN    NaN
#
#        ConvertedCompYearly  JobSat
# 49181                  NaN     NaN
# 49182                  NaN     NaN
# 49183                  NaN     NaN
# 49184                  NaN     NaN
# 49185                  NaN     NaN
# 49186                  NaN     NaN
# 49187                  NaN     NaN
# 49188                  NaN     9.0
# 49189                  NaN     NaN
# 49190                  NaN     NaN
#
# [10 rows x 172 columns]

# %%
#Number of rows and columns 
df.shape
# Out:
# (49191, 172)

# %%
#Number of rows and columns and all of the data type
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 49191 entries, 0 to 49190
# Columns: 172 entries, ResponseId to JobSat
# dtypes: float64(52), int64(1), str(119)
# memory usage: 64.6 MB

# %%
df.dtypes
# Out:
# ResponseId               int64
# MainBranch                 str
# Age                        str
# EdLevel                    str
# Employment                 str
#                         ...
# AIAgentExtWrite            str
# AIHuman                    str
# AIOpen                     str
# ConvertedCompYearly    float64
# JobSat                 float64
# Length: 172, dtype: object

# %%
pd.set_option('display.max_columns', 172)

# %%
schema_df= pd.read_csv('schema.csv', index_col="qname")

# %%
schema_df
# Out:
#         qid            qname  \
# 0     QID18    TechEndorse_1
# 1     QID18    TechEndorse_2
# 2     QID18    TechEndorse_3
# 3     QID18    TechEndorse_4
# 4     QID18    TechEndorse_5
# ..      ...              ...
# 134  QID103  AIAgentObsWrite
# 135   QID92  AIAgentExternal
# 136  QID104  AIAgentExtWrite
# 137  QID100          AIHuman
# 138   QID93           AIOpen
#
#                                               question type  \
# 0    What attracts you to a technology or causes yo...   RO
# 1    What attracts you to a technology or causes yo...   RO
# 2    What attracts you to a technology or causes yo...   RO
# 3    What attracts you to a technology or causes yo...   RO
# 4    What attracts you to a technology or causes yo...   RO
# ..                                                 ...  ...
# 134  Was the tool or tools for AI agent observabili...   TE
# 135  You indicated you use or develop AI agents as ...   MC
# 136  Was the out-of-the-box agents, copilots or ass...   TE
# 137  In the future, if AI can do most coding tasks,...   MC
# 138  Looking ahead 3–5 years, what skills do you be...   TE
#
#                                          sub  sq_id
# 0    AI integration or AI Agent capabilities    1.0
# 1                            Easy-to-use API    2.0
# 2                    Robust and complete API    3.0
# 3       Customizable and manageable codebase    4.0
# 4                     Reputation for quality    5.0
# ..                                       ...    ...
# 134                                      NaN    NaN
# 135                                      NaN    NaN
# 136                                      NaN    NaN
# 137                                      NaN    NaN
# 138                                      NaN    NaN
#
# [139 rows x 6 columns]

# %%
people = {
    "first": ["Corey", "Jane", "John", "Ada"],
    "last": ["Schafer", "Doe", "Doe", "Wong"],
    "email": ["CoreyMSchafer@gmail.com", "JaneDoe@email.com", "JohnDoe@email.com", "Ada@email.com"]
}

# %%
#Create a dataframe with the information above

# %%
df = pd.DataFrame(people)

# %%
df
# Out:
#    first     last                    email
# 0  Corey  Schafer  CoreyMSchafer@gmail.com
# 1   Jane      Doe        JaneDoe@email.com
# 2   John      Doe        JohnDoe@email.com

# %%
df["email"]
# Out:
# 0    CoreyMSchafer@gmail.com
# 1          JaneDoe@email.com
# 2          JohnDoe@email.com
# Name: email, dtype: str

# %%
df.email
# Out:
# 0    CoreyMSchafer@gmail.com
# 1          JaneDoe@email.com
# 2          JohnDoe@email.com
# Name: email, dtype: str

# %%
df[["last", "email"]]
# Out:
#       last                    email
# 0  Schafer  CoreyMSchafer@gmail.com
# 1      Doe        JaneDoe@email.com
# 2      Doe        JohnDoe@email.com

# %%
df.columns
# Out:
# Index(['first', 'last', 'email'], dtype='str')

# %%
#iloc = access rows and columns by integer location
df.iloc[[0,1], 2]
# Out:
# 0    CoreyMSchafer@gmail.com
# 1          JaneDoe@email.com
# Name: email, dtype: str

# %%
df
# Out:
#    first     last                    email
# 0  Corey  Schafer  CoreyMSchafer@gmail.com
# 1   Jane      Doe        JaneDoe@email.com
# 2   John      Doe        JohnDoe@email.com

# %%
#loc = access rows and columns by label
df.loc[[0,1], ["first", "last"]]
# Out:
#    first     last
# 0  Corey  Schafer
# 1   Jane      Doe

# %%
df.shape
# Out:
# (3, 3)

# %%
df.columns
# Out:
# Index(['first', 'last', 'email'], dtype='str')

# %%
list(df.columns)
# Out:
# ['first', 'last', 'email']

# %%
#value_counts() returns the number of occurrences of each unique value in a column, sorted from most to least frequent.
df["Country"].value_counts()
# Out:
# Country
# United States of America                                7233
# Germany                                                 3025
# India                                                   2547
# United Kingdom of Great Britain and Northern Ireland    2042
# France                                                  1409
#                                                         ...
# San Marino                                                 1
# Djibouti                                                   1
# Cape Verde                                                 1
# Palau                                                      1
# Guinea                                                     1
# Name: count, Length: 177, dtype: int64

# %%
#df.loc[row_label, column_label] - first argument is the row label, second is the column label.
df.loc[0:2, "Country":"LanguageChoice"]
# Out:
#        Country               Currency  CompTotal LanguageChoice
# 0      Ukraine      EUR European Euro    52800.0            Yes
# 1  Netherlands      EUR European Euro    90000.0            Yes
# 2      Ukraine  UAH Ukrainian hryvnia  2214000.0            Yes

# %%
df["email"]
# Out:
# 0    CoreyMSchafer@gmail.com
# 1          JaneDoe@email.com
# 2          JohnDoe@email.com
# Name: email, dtype: str

# %%
df.set_index("email", inplace=True)

# %%
df
# Out:
#                          first     last
# email
# CoreyMSchafer@gmail.com  Corey  Schafer
# JaneDoe@email.com         Jane      Doe
# JohnDoe@email.com         John      Doe

# %%
df.index
# Out:
# Index(['CoreyMSchafer@gmail.com', 'JaneDoe@email.com', 'JohnDoe@email.com'], dtype='str', name='email')

# %%
df.loc["JohnDoe@email.com", "last"]
# Out:
# 'Doe'

# %%
df.iloc[0]
# Out:
# first      Corey
# last     Schafer
# Name: CoreyMSchafer@gmail.com, dtype: str

# %%
df.reset_index(inplace=True)

# %%
df
# Out:
#                      email  first     last
# 0  CoreyMSchafer@gmail.com  Corey  Schafer
# 1        JaneDoe@email.com   Jane      Doe
# 2        JohnDoe@email.com   John      Doe

# %%
list(df.columns)
# Out:
# ['MainBranch',
#  'Age',
#  'EdLevel',
#  'Employment',
#  'EmploymentAddl',
#  'WorkExp',
#  'LearnCodeChoose',
#  'LearnCode',
#  'LearnCodeAI',
#  'AILearnHow',
#  'YearsCode',
#  'DevType',
#  'OrgSize',
#  'ICorPM',
#  'RemoteWork',
#  'PurchaseInfluence',
#  'TechEndorseIntro',
#  'TechEndorse_1',
#  'TechEndorse_2',
#  'TechEndorse_3',
#  'TechEndorse_4',
#  'TechEndorse_5',
#  'TechEndorse_6',
#  'TechEndorse_7',
#  'TechEndorse_8',
#  'TechEndorse_9',
#  'TechEndorse_13',
#  'TechEndorse_13_TEXT',
#  'TechOppose_1',
#  'TechOppose_2',
#  'TechOppose_3',
#  'TechOppose_5',
#  'TechOppose_7',
#  'TechOppose_9',
#  'TechOppose_11',
#  'TechOppose_13',
#  'TechOppose_16',
#  'TechOppose_15',
#  'TechOppose_15_TEXT',
#  'Industry',
#  'JobSatPoints_1',
#  'JobSatPoints_2',
#  'JobSatPoints_3',
#  'JobSatPoints_4',
#  'JobSatPoints_5',
#  'JobSatPoints_6',
#  'JobSatPoints_7',
#  'JobSatPoints_8',
#  'JobSatPoints_9',
#  'JobSatPoints_10',
#  'JobSatPoints_11',
#  'JobSatPoints_13',
#  'JobSatPoints_14',
#  'JobSatPoints_15',
#  'JobSatPoints_16',
#  'JobSatPoints_15_TEXT',
#  'AIThreat',
#  'NewRole',
#  'ToolCountWork',
#  'ToolCountPersonal',
#  'Country',
#  'Currency',
#  'CompTotal',
#  'LanguageChoice',
#  'LanguageHaveWorkedWith',
#  'LanguageWantToWorkWith',
#  'LanguageAdmired',
#  'LanguagesHaveEntry',
#  'LanguagesWantEntry',
#  'DatabaseChoice',
#  'DatabaseHaveWorkedWith',
#  'DatabaseWantToWorkWith',
#  'DatabaseAdmired',
#  'DatabaseHaveEntry',
#  'DatabaseWantEntry',
#  'PlatformChoice',
#  'PlatformHaveWorkedWith',
#  'PlatformWantToWorkWith',
#  'PlatformAdmired',
#  'PlatformHaveEntry',
#  'PlatformWantEntry',
#  'WebframeChoice',
#  'WebframeHaveWorkedWith',
#  'WebframeWantToWorkWith',
#  'WebframeAdmired',
#  'WebframeHaveEntry',
#  'WebframeWantEntry',
#  'DevEnvsChoice',
#  'DevEnvsHaveWorkedWith',
#  'DevEnvsWantToWorkWith',
#  'DevEnvsAdmired',
#  'DevEnvHaveEntry',
#  'DevEnvWantEntry',
#  'SOTagsHaveWorkedWith',
#  'SOTagsWantToWorkWith',
#  'SOTagsAdmired',
#  'SOTagsHaveEntry',
#  'SOTagsWant Entry',
#  'OpSysPersonal use',
#  'OpSysProfessional use',
#  'OfficeStackAsyncHaveWorkedWith',
#  'OfficeStackAsyncWantToWorkWith',
#  'OfficeStackAsyncAdmired',
#  'OfficeStackHaveEntry',
#  'OfficeStackWantEntry',
#  'CommPlatformHaveWorkedWith',
#  'CommPlatformWantToWorkWith',
#  'CommPlatformAdmired',
#  'CommPlatformHaveEntr',
#  'CommPlatformWantEntr',
#  'AIModelsChoice',
#  'AIModelsHaveWorkedWith',
#  'AIModelsWantToWorkWith',
#  'AIModelsAdmired',
#  'AIModelsHaveEntry',
#  'AIModelsWantEntry',
#  'SOAccount',
#  'SOVisitFreq',
#  'SODuration',
#  'SOPartFreq',
#  'SO_Dev_Content',
#  'SO_Actions_1',
#  'SO_Actions_16',
#  'SO_Actions_3',
#  'SO_Actions_4',
#  'SO_Actions_5',
#  'SO_Actions_6',
#  'SO_Actions_9',
#  'SO_Actions_7',
#  'SO_Actions_10',
#  'SO_Actions_15',
#  'SO_Actions_15_TEXT',
#  'SOComm',
#  'SOFriction',
#  'AISelect',
#  'AISent',
#  'AIAcc',
#  'AIComplex',
#  'AIToolCurrently partially AI',
#  "AIToolDon't plan to use AI for this task",
#  'AIToolPlan to partially use AI',
#  'AIToolPlan to mostly use AI',
#  'AIToolCurrently mostly AI',
#  'AIFrustration',
#  'AIExplain',
#  'AIAgents',
#  'AIAgentChange',
#  'AIAgent_Uses',
#  'AgentUsesGeneral',
#  'AIAgentImpactSomewhat agree',
#  'AIAgentImpactNeutral',
#  'AIAgentImpactSomewhat disagree',
#  'AIAgentImpactStrongly agree',
#  'AIAgentImpactStrongly disagree',
#  'AIAgentChallengesNeutral',
#  'AIAgentChallengesSomewhat disagree',
#  'AIAgentChallengesStrongly agree',
#  'AIAgentChallengesSomewhat agree',
#  'AIAgentChallengesStrongly disagree',
#  'AIAgentKnowledge',
#  'AIAgentKnowWrite',
#  'AIAgentOrchestration',
#  'AIAgentOrchWrite',
#  'AIAgentObserveSecure',
#  'AIAgentObsWrite',
#  'AIAgentExternal',
#  'AIAgentExtWrite',
#  'AIHuman',
#  'AIOpen',
#  'ConvertedCompYearly',
#  'JobSat']

# %%
schema_df.loc["YearsCode", "question"]
# Out:
# 'Including any education, how many years have you been coding in total?  Please round to the nearest whole number, excluding any decimal points.'

# %%
schema_df.sort_index()
# Out:
#                       qid                                           question  \
# qname
# AIAcc               QID80  How much do you trust the accuracy of the outp...
# AIAgentChallenges   QID88  To what extent do you agree with the following...
# AIAgentChange       QID83  Have AI tools or AI agents changed how you com...
# AIAgentExtWrite    QID104  Was the out-of-the-box agents, copilots or ass...
# AIAgentExternal     QID92  You indicated you use or develop AI agents as ...
# ...                   ...                                                ...
# WebframeChoice      QID47  Did you work with web frameworks and web techn...
# WebframeHaveEntry   QID58  Were the web frameworks and web technologies y...
# WebframeWantEntry   QID59  Were the web frameworks and web technologies y...
# WorkExp             QID14  How many years of professional work experience...
# YearsCode           QID13  Including any education, how many years have y...
#
#                      type  sub  sq_id
# qname
# AIAcc                  MC  NaN    NaN
# AIAgentChallenges  Matrix  NaN    NaN
# AIAgentChange          MC  NaN    NaN
# AIAgentExtWrite        TE  NaN    NaN
# AIAgentExternal        MC  NaN    NaN
# ...                   ...  ...    ...
# WebframeChoice         MC  NaN    NaN
# WebframeHaveEntry      TE  NaN    NaN
# WebframeWantEntry      TE  NaN    NaN
# WorkExp                TE  NaN    NaN
# YearsCode              TE  NaN    NaN
#
# [139 rows x 5 columns]

# %%
filt = (df["last"] == "Schafer") | (df["first"] == "John")

# %%
df.loc[~filt, "email"]
# Out:
# 1    JaneDoe@email.com
# Name: email, dtype: str

# %%
countries = ["United States", "Brazil", "Ukraine","Canada", "Russia"]
high_salary = (df["ConvertedCompYearly"] > 180000) & (df["Country"].isin(countries)) & (df["LanguageHaveWorkedWith"].str.contains("Python", na=False))

# %%
df.loc[high_salary, ["Country", "LanguageHaveWorkedWith", "WorkExp", "ConvertedCompYearly"]]
# Out:
#             Country                             LanguageHaveWorkedWith  \
# ResponseId
# 544          Canada                                C;C++;Kotlin;Python
# 957          Canada  Bash/Shell (all shells);Go;HTML/CSS;JavaScript...
# 1046         Canada     HTML/CSS;JavaScript;Python;Ruby;SQL;TypeScript
# 1281         Canada  Bash/Shell (all shells);C#;HTML/CSS;JavaScript...
# 2096         Canada  Bash/Shell (all shells);HTML/CSS;JavaScript;Py...
# 2145         Canada                Bash/Shell (all shells);Java;Python
# 2310         Canada           HTML/CSS;Java;JavaScript;Python;Ruby;SQL
# 2536         Canada  Bash/Shell (all shells);Go;HTML/CSS;Java;JavaS...
# 2962         Canada  Bash/Shell (all shells);Dart;HTML/CSS;JavaScri...
# 3082         Canada                                  Delphi;Python;SQL
# 3415         Canada  Bash/Shell (all shells);C#;C++;Groovy;Lua;Powe...
# 4871         Canada               Bash/Shell (all shells);Python;Swift
# 4906         Canada      C;C++;Go;Groovy;HTML/CSS;Java;Python;Rust;SQL
# 5415         Canada       Bash/Shell (all shells);PHP;Python;Ruby;Rust
# 5770         Canada            Bash/Shell (all shells);C++;Python;Rust
# 5846         Canada  Assembly;C;C#;GDScript;Go;HTML/CSS;JavaScript;...
# 5953         Canada                     HTML/CSS;JavaScript;Python;SQL
# 8604         Canada                                         Python;SQL
# 8632         Canada                   Java;JavaScript;Python;Scala;SQL
# 11118        Canada  Bash/Shell (all shells);HTML/CSS;Python;Scala;...
# 11275        Brazil  Bash/Shell (all shells);HTML/CSS;JavaScript;Py...
# 11407        Canada  Bash/Shell (all shells);C;Java;JavaScript;Pyth...
# 11825        Canada                         C++;Python;Rust;TypeScript
# 12078        Canada  Bash/Shell (all shells);C#;Java;JavaScript;Pyt...
# 14243        Canada  Bash/Shell (all shells);Go;JavaScript;Python;T...
# 16954        Canada  Bash/Shell (all shells);C#;HTML/CSS;JavaScript...
# 18194        Canada   HTML/CSS;JavaScript;Kotlin;Python;SQL;TypeScript
# 18825        Canada  Bash/Shell (all shells);C;C++;Go;Java;JavaScri...
# 19019        Canada  Bash/Shell (all shells);C;C++;HTML/CSS;MATLAB;...
# 20866        Canada   Assembly;Bash/Shell (all shells);C++;Python;Rust
# 21017        Canada  Assembly;C#;C++;HTML/CSS;JavaScript;Perl;PHP;P...
# 23399        Canada         Java;JavaScript;Lua;Perl;Python;TypeScript
# 24044        Canada  Assembly;Bash/Shell (all shells);C;C#;C++;Go;H...
# 26501        Canada  Elixir;Go;HTML/CSS;JavaScript;Python;Ruby;Rust...
# 26599        Canada  Bash/Shell (all shells);Erlang;Go;HTML/CSS;Jav...
# 27272        Canada  Bash/Shell (all shells);HTML/CSS;JavaScript;Py...
# 27345        Canada  Bash/Shell (all shells);C;C++;HTML/CSS;JavaScr...
# 27378        Canada                                          Go;Python
# 28225        Canada  Bash/Shell (all shells);GDScript;Go;HTML/CSS;J...
# 30182        Canada  Bash/Shell (all shells);JavaScript;Lua;PowerSh...
# 30616        Canada  Assembly;Bash/Shell (all shells);C;HTML/CSS;Ja...
# 30729        Brazil    Bash/Shell (all shells);Elixir;Go;Kotlin;Python
# 31599        Canada  Bash/Shell (all shells);Go;HTML/CSS;JavaScript...
# 31956        Canada  Bash/Shell (all shells);C;C++;Java;JavaScript;...
# 35675        Brazil  Ada;Assembly;C;C#;C++;COBOL;Dart;Delphi;Elixir...
# 35687        Canada   C;C++;HTML/CSS;JavaScript;Python;Ruby;Rust;Swift
# 37367        Canada                             Java;Kotlin;Python;SQL
# 38571        Canada                  Bash/Shell (all shells);Go;Python
# 40342        Canada  Bash/Shell (all shells);C;C++;Java;JavaScript;...
# 40576        Canada  Assembly;Bash/Shell (all shells);C;C++;Go;Lua;...
# 40783        Canada                                        C;Go;Python
# 44880        Canada                                          Go;Python
# 44958        Canada  Bash/Shell (all shells);C#;GDScript;Go;JavaScr...
# 45580        Canada          HTML/CSS;JavaScript;Python;SQL;TypeScript
# 45837        Canada  Bash/Shell (all shells);JavaScript;Perl;Python...
# 48429       Ukraine  Assembly;C#;GDScript;HTML/CSS;JavaScript;Micro...
#
#             WorkExp  ConvertedCompYearly
# ResponseId
# 544            30.0             218875.0
# 957            25.0             221064.0
# 1046           16.0             248058.0
# 1281           19.0             218875.0
# 2096           21.0             200635.0
# 2145           19.0             364792.0
# 2310           16.0             198447.0
# 2536           10.0             196988.0
# 2962            4.0             210000.0
# 3082           35.0             182396.0
# 3415           23.0             350200.0
# 4871            8.0             218875.0
# 4906           30.0             284538.0
# 5415           10.0             204283.0
# 5770           45.0             185000.0
# 5846           20.0             182396.0
# 5953            4.0             729584.0
# 8604           10.0             200635.0
# 8632           10.0             277242.0
# 11118          20.0             218875.0
# 11275          20.0             210252.0
# 11407          23.0             182396.0
# 11825          10.0             510708.0
# 12078          18.0             183456.0
# 14243          25.0             189692.0
# 16954          12.0             182396.0
# 18194          17.0             182396.0
# 18825           7.0             218875.0
# 19019          13.0             200635.0
# 20866          10.0             364792.0
# 21017          30.0             196988.0
# 23399          18.0             240763.0
# 24044          30.0             452342.0
# 26501          15.0             199176.0
# 26599          30.0             182396.0
# 27272          20.0             189692.0
# 27345          16.0             182396.0
# 27378          13.0             237115.0
# 28225          20.0             229819.0
# 30182          10.0             218875.0
# 30616          17.0             182396.0
# 30729          17.0            6371285.0
# 31599           2.0             218875.0
# 31956          48.0             542810.0
# 35675           1.0             182037.0
# 35687           8.0             242951.0
# 37367           5.0             583667.0
# 38571          16.0             215227.0
# 40342          15.0             182396.0
# 40576          21.0             218875.0
# 40783           9.0             182396.0
# 44880          15.0             200635.0
# 44958          15.0             218875.0
# 45580          15.0             189692.0
# 45837          30.0             182396.0
# 48429           NaN           10000000.0

# %%
filt = df["LanguageHaveWorkedWith"].str.contains("Python", na=False)

# %%
df.loc[filt, "LanguageHaveWorkedWith"]
# Out:
# ResponseId
# 5        C;C#;C++;Delphi;HTML/CSS;Java;JavaScript;Lua;P...
# 8        Bash/Shell (all shells);HTML/CSS;JavaScript;Py...
# 9                                        Java;Python;Scala
# 16       Ada;Assembly;C;C#;C++;COBOL;Dart;Delphi;Elixir...
# 18                          HTML/CSS;JavaScript;Python;SQL
#                                ...
# 49144            HTML/CSS;JavaScript;Python;SQL;TypeScript
# 49146    Assembly;Bash/Shell (all shells);C;C++;Python;...
# 49176    Bash/Shell (all shells);C#;C++;GDScript;HTML/C...
# 49177    Bash/Shell (all shells);HTML/CSS;JavaScript;Py...
# 49178    Bash/Shell (all shells);HTML/CSS;Lisp;PowerShe...
# Name: LanguageHaveWorkedWith, Length: 18466, dtype: str

# %%
df
# Out:
#    first     last                    email
# 0  Corey  Schafer  CoreyMSchafer@gmail.com
# 1   Jane      Doe        JaneDoe@email.com
# 2   John      Doe        JohnDoe@email.com

# %%
df.columns
# Out:
# Index(['first', 'last', 'email'], dtype='str')

# %%
#Rename all columns name

# %%
df.columns = ["first_name", "last_name", "email"]

# %%
df
# Out:
#   first_name last_name                    email
# 0      Corey   Schafer  CoreyMSchafer@gmail.com
# 1       Jane       Doe        JaneDoe@email.com
# 2       John       Doe        JohnDoe@email.com

# %%
#Uppercase all

df.columns= [x.lower() for x in df.columns]
df
# Out:
#   first_name last_name                    email
# 0      Corey   Schafer  CoreyMSchafer@gmail.com
# 1       Jane       Doe        JaneDoe@email.com
# 2       John       Doe        JohnDoe@email.com

# %%
df.columns = df.columns.str.replace(" ", "_")
df
# Out:
#   first_name last_name                    email
# 0      Corey   Schafer  CoreyMSchafer@gmail.com
# 1       Jane       Doe        JaneDoe@email.com
# 2       John       Doe        JohnDoe@email.com

# %%
#Change Some Columns

df.rename(columns={"first_name": "first",
                   "last_name":  "last"}, inplace=True)

df
# Out:
#    first     last                    email
# 0  Corey  Schafer  CoreyMSchafer@gmail.com
# 1   Jane      Doe        JaneDoe@email.com
# 2   John      Doe        JohnDoe@email.com

# %%
df.loc[2, ["last", "email"]] = ["Smith", "JohnSmith@email.com"]

# %%
 df
# Out:
#    first     last                    email
# 0  Corey  Schafer  CoreyMSchafer@gmail.com
# 1   Jane      Doe        JaneDoe@email.com
# 2   John    Smith      JohnSmith@email.com

# %%
df.loc[2, "last"] = "Doe"

# %%
df
# Out:
#    first     last                    email
# 0  Corey  Schafer  CoreyMSchafer@gmail.com
# 1   Jane      Doe        JaneDoe@email.com
# 2   John      Doe      JohnSmith@email.com

# %%
df.at[2, "email"] = "JohnDoe@email.com"

# %%
df
# Out:
#    first     last                    email
# 0  Corey  Schafer  CoreyMSchafer@gmail.com
# 1   Jane      Doe        JaneDoe@email.com
# 2   John      Doe        JohnDoe@email.com

# %%
filt = (df["email"] == "JohnDoe@email.com")
df.loc[filt, "last"] = "Smith"

# %%
df
# Out:
#    first     last                    email
# 0  Corey  Schafer  CoreyMSchafer@gmail.com
# 1   Jane      Doe        JaneDoe@email.com
# 2   John    Smith        JohnDoe@email.com

# %%
df["email"] = df["email"].str.lower()

# %%
df
# Out:
#    first     last                    email
# 0  Corey  Schafer  coreymschafer@gmail.com
# 1   Jane      Doe        janedoe@email.com
# 2   John    Smith        johndoe@email.com

# %%
apply
map
applymap
replace

# %%
df["email"].apply(len)
# Out:
# 0    23
# 1    17
# 2    17
# Name: email, dtype: int64

# %%
def update_email(email):
    return email.upper()

# %%
#apply() takes a function and applies it to every element in a column. Can be used with a named function or a lambda for concise one-liners.

df["email"].apply(update_email)
# Out:
# 0    COREYMSCHAFER@GMAIL.COM
# 1          JANEDOE@EMAIL.COM
# 2          JOHNDOE@EMAIL.COM
# Name: email, dtype: str

# %%
df["email"].apply(lambda x: x.lower())
# Out:
# 0    coreymschafer@gmail.com
# 1          janedoe@email.com
# 2          johndoe@email.com
# Name: email, dtype: str

# %%
df["email"].apply(len)
# Out:
# 0    23
# 1    17
# 2    17
# Name: email, dtype: int64

# %%
df.apply(pd.Series.min)
# Out:
# first                      Corey
# last                         Doe
# email    CoreyMSchafer@gmail.com
# dtype: str

# %%
df.apply(lambda x: x.min())
# Out:
# first                      Corey
# last                         Doe
# email    CoreyMSchafer@gmail.com
# dtype: str

# %%
df.map(len)
# Out:
#    first  last  email
# 0      5     7     23
# 1      4     3     17
# 2      4     3     17

# %%
df.map(str.lower)
# Out:
#    first     last                    email
# 0  corey  schafer  coreymschafer@gmail.com
# 1   jane      doe        janedoe@email.com
# 2   john      doe        johndoe@email.com

# %%
df["first"].map({"Corey": "Caio"})
# Out:
# 0    Caio
# 1     NaN
# 2     NaN
# Name: first, dtype: str

# %%
df["first"] = df["first"].replace({"Corey": "Caio"})

# %%
df
# Out:
#                                                    MainBranch  \
# ResponseId
# 1                              I am a developer by profession
# 2                              I am a developer by profession
# 3                              I am a developer by profession
# 4                              I am a developer by profession
# 5                              I am a developer by profession
# ...                                                       ...
# 49187                             I code primarily as a hobby
# 49188                          I am a developer by profession
# 49189                          I am a developer by profession
# 49190                          I am a developer by profession
# 49191       I am not primarily a developer, but I write co...
#
#                         Age  \
# ResponseId
# 1           25-34 years old
# 2           25-34 years old
# 3           35-44 years old
# 4           35-44 years old
# 5           35-44 years old
# ...                     ...
# 49187       18-24 years old
# 49188       45-54 years old
# 49189       35-44 years old
# 49190       25-34 years old
# 49191       18-24 years old
#
#                                                       EdLevel  \
# ResponseId
# 1             Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 2                         Associate degree (A.A., A.S., etc.)
# 3                Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 4                Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 5             Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# ...                                                       ...
# 49187            Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 49188       Some college/university study without earning ...
# 49189         Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 49190          Professional degree (JD, MD, Ph.D, Ed.D, etc.)
# 49191       Some college/university study without earning ...
#
#                                                    Employment  \
# ResponseId
# 1                                                    Employed
# 2                                                    Employed
# 3           Independent contractor, freelancer, or self-em...
# 4                                                    Employed
# 5           Independent contractor, freelancer, or self-em...
# ...                                                       ...
# 49187                                                Employed
# 49188                                                Employed
# 49189                                                Employed
# 49190       Independent contractor, freelancer, or self-em...
# 49191                                                 Student
#
#                                              EmploymentAddl  WorkExp  \
# ResponseId
# 1           Caring for dependents (children, elderly, etc.)      8.0
# 2                                                       NaN      2.0
# 3                                         None of the above     10.0
# 4                                         None of the above      4.0
# 5           Caring for dependents (children, elderly, etc.)     21.0
# ...                                                     ...      ...
# 49187                                                   NaN      NaN
# 49188       Caring for dependents (children, elderly, etc.)     25.0
# 49189                                     None of the above     17.0
# 49190                                     None of the above      2.0
# 49191                          Attending school (full-time)      NaN
#
#                                               LearnCodeChoose  \
# ResponseId
# 1           Yes, I am not new to coding but am learning ne...
# 2           Yes, I am not new to coding but am learning ne...
# 3           Yes, I am not new to coding but am learning ne...
# 4           Yes, I am not new to coding but am learning ne...
# 5           No, I am not new to coding and did not learn n...
# ...                                                       ...
# 49187                                                     NaN
# 49188       Yes, I am not new to coding but am learning ne...
# 49189       Yes, I am not new to coding but am learning ne...
# 49190       Yes, I am not new to coding but am learning ne...
# 49191       Yes, I am not new to coding but am learning ne...
#
#                                                     LearnCode  \
# ResponseId
# 1           Online Courses or Certification (includes all ...
# 2           Online Courses or Certification (includes all ...
# 3           Online Courses or Certification (includes all ...
# 4           Other online resources (e.g. standard search, ...
# 5                                                         NaN
# ...                                                       ...
# 49187                                                     NaN
# 49188       Online Courses or Certification (includes all ...
# 49189       Online Courses or Certification (includes all ...
# 49190       Videos (not associated with specific online co...
# 49191       Online Courses or Certification (includes all ...
#
#                                                   LearnCodeAI  \
# ResponseId
# 1           Yes, I learned how to use AI-enabled tools for...
# 2           Yes, I learned how to use AI-enabled tools for...
# 3           Yes, I learned how to use AI-enabled tools for...
# 4           Yes, I learned how to use AI-enabled tools for...
# 5           Yes, I learned how to use AI-enabled tools for...
# ...                                                       ...
# 49187                                                     NaN
# 49188       Yes, I learned how to use AI-enabled tools req...
# 49189       Yes, I learned how to use AI-enabled tools for...
# 49190       Yes, I learned how to use AI-enabled tools for...
# 49191       Yes, I learned how to use AI-enabled tools for...
#
#                                                    AILearnHow  ...  \
# ResponseId                                                     ...
# 1                         AI CodeGen tools or AI-enabled apps  ...
# 2                         AI CodeGen tools or AI-enabled apps  ...
# 3           AI CodeGen tools or AI-enabled apps;Technical ...  ...
# 4           AI CodeGen tools or AI-enabled apps;Videos (no...  ...
# 5           Technical documentation (is generated for/by t...  ...
# ...                                                       ...  ...
# 49187                                                     NaN  ...
# 49188                                                     NaN  ...
# 49189       AI CodeGen tools or AI-enabled apps;Videos (no...  ...
# 49190                                                     NaN  ...
# 49191                     AI CodeGen tools or AI-enabled apps  ...
#
#             AIAgentOrchestration AIAgentOrchWrite AIAgentObserveSecure  \
# ResponseId
# 1                      Vertex AI              NaN                  NaN
# 2                            NaN              NaN                  NaN
# 3                            NaN              NaN                  NaN
# 4                            NaN              NaN                  NaN
# 5                            NaN              NaN                  NaN
# ...                          ...              ...                  ...
# 49187                        NaN              NaN                  NaN
# 49188                        NaN              NaN                  NaN
# 49189                        NaN              NaN                  NaN
# 49190                        NaN              NaN                  NaN
# 49191                        NaN              NaN                  NaN
#
#            AIAgentObsWrite                                   AIAgentExternal  \
# ResponseId
# 1                      NaN                                           ChatGPT
# 2                      NaN                                               NaN
# 3                      NaN  ChatGPT;Claude Code;GitHub Copilot;Google Gemini
# 4                      NaN                               ChatGPT;Claude Code
# 5                      NaN                                               NaN
# ...                    ...                                               ...
# 49187                  NaN                                               NaN
# 49188                  NaN                                               NaN
# 49189                  NaN                                               NaN
# 49190                  NaN                                               NaN
# 49191                  NaN                                               NaN
#
#            AIAgentExtWrite                                            AIHuman  \
# ResponseId
# 1                      NaN                    When I don’t trust AI’s answers
# 2                      NaN  When I don’t trust AI’s answers;When I want to...
# 3                      NaN  When I don’t trust AI’s answers;When I want to...
# 4                      NaN  When I don’t trust AI’s answers;When I want to...
# 5                      NaN                    When I don’t trust AI’s answers
# ...                    ...                                                ...
# 49187                  NaN                                                NaN
# 49188                  NaN                                                NaN
# 49189                  NaN                                                NaN
# 49190                  NaN                                                NaN
# 49191                  NaN                                                NaN
#
#                                                        AIOpen  \
# ResponseId
# 1                       Troubleshooting, profiling, debugging
# 2                                   All skills. AI is a flop.
# 3           Understand how things actually work, problem s...
# 4                                                         NaN
# 5           critical thinking, the skill to define the tas...
# ...                                                       ...
# 49187                                                     NaN
# 49188                                                     NaN
# 49189                                                     NaN
# 49190                                                     NaN
# 49191                                                     NaN
#
#             ConvertedCompYearly  JobSat
# ResponseId
# 1                       61256.0    10.0
# 2                      104413.0     9.0
# 3                       53061.0     8.0
# 4                       36197.0     6.0
# 5                       60000.0     7.0
# ...                         ...     ...
# 49187                       NaN     NaN
# 49188                       NaN     NaN
# 49189                       NaN     9.0
# 49190                       NaN     NaN
# 49191                       NaN     NaN
#
# [49191 rows x 171 columns]

# %%
df.rename(columns = {"ConvertedCompYearly": "SalaryUSDYearly"})
# Out:
#                                                    MainBranch  \
# ResponseId
# 1                              I am a developer by profession
# 2                              I am a developer by profession
# 3                              I am a developer by profession
# 4                              I am a developer by profession
# 5                              I am a developer by profession
# ...                                                       ...
# 49187                             I code primarily as a hobby
# 49188                          I am a developer by profession
# 49189                          I am a developer by profession
# 49190                          I am a developer by profession
# 49191       I am not primarily a developer, but I write co...
#
#                         Age  \
# ResponseId
# 1           25-34 years old
# 2           25-34 years old
# 3           35-44 years old
# 4           35-44 years old
# 5           35-44 years old
# ...                     ...
# 49187       18-24 years old
# 49188       45-54 years old
# 49189       35-44 years old
# 49190       25-34 years old
# 49191       18-24 years old
#
#                                                       EdLevel  \
# ResponseId
# 1             Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 2                         Associate degree (A.A., A.S., etc.)
# 3                Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 4                Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 5             Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# ...                                                       ...
# 49187            Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 49188       Some college/university study without earning ...
# 49189         Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 49190          Professional degree (JD, MD, Ph.D, Ed.D, etc.)
# 49191       Some college/university study without earning ...
#
#                                                    Employment  \
# ResponseId
# 1                                                    Employed
# 2                                                    Employed
# 3           Independent contractor, freelancer, or self-em...
# 4                                                    Employed
# 5           Independent contractor, freelancer, or self-em...
# ...                                                       ...
# 49187                                                Employed
# 49188                                                Employed
# 49189                                                Employed
# 49190       Independent contractor, freelancer, or self-em...
# 49191                                                 Student
#
#                                              EmploymentAddl  WorkExp  \
# ResponseId
# 1           Caring for dependents (children, elderly, etc.)      8.0
# 2                                                       NaN      2.0
# 3                                         None of the above     10.0
# 4                                         None of the above      4.0
# 5           Caring for dependents (children, elderly, etc.)     21.0
# ...                                                     ...      ...
# 49187                                                   NaN      NaN
# 49188       Caring for dependents (children, elderly, etc.)     25.0
# 49189                                     None of the above     17.0
# 49190                                     None of the above      2.0
# 49191                          Attending school (full-time)      NaN
#
#                                               LearnCodeChoose  \
# ResponseId
# 1           Yes, I am not new to coding but am learning ne...
# 2           Yes, I am not new to coding but am learning ne...
# 3           Yes, I am not new to coding but am learning ne...
# 4           Yes, I am not new to coding but am learning ne...
# 5           No, I am not new to coding and did not learn n...
# ...                                                       ...
# 49187                                                     NaN
# 49188       Yes, I am not new to coding but am learning ne...
# 49189       Yes, I am not new to coding but am learning ne...
# 49190       Yes, I am not new to coding but am learning ne...
# 49191       Yes, I am not new to coding but am learning ne...
#
#                                                     LearnCode  \
# ResponseId
# 1           Online Courses or Certification (includes all ...
# 2           Online Courses or Certification (includes all ...
# 3           Online Courses or Certification (includes all ...
# 4           Other online resources (e.g. standard search, ...
# 5                                                         NaN
# ...                                                       ...
# 49187                                                     NaN
# 49188       Online Courses or Certification (includes all ...
# 49189       Online Courses or Certification (includes all ...
# 49190       Videos (not associated with specific online co...
# 49191       Online Courses or Certification (includes all ...
#
#                                                   LearnCodeAI  \
# ResponseId
# 1           Yes, I learned how to use AI-enabled tools for...
# 2           Yes, I learned how to use AI-enabled tools for...
# 3           Yes, I learned how to use AI-enabled tools for...
# 4           Yes, I learned how to use AI-enabled tools for...
# 5           Yes, I learned how to use AI-enabled tools for...
# ...                                                       ...
# 49187                                                     NaN
# 49188       Yes, I learned how to use AI-enabled tools req...
# 49189       Yes, I learned how to use AI-enabled tools for...
# 49190       Yes, I learned how to use AI-enabled tools for...
# 49191       Yes, I learned how to use AI-enabled tools for...
#
#                                                    AILearnHow  ...  \
# ResponseId                                                     ...
# 1                         AI CodeGen tools or AI-enabled apps  ...
# 2                         AI CodeGen tools or AI-enabled apps  ...
# 3           AI CodeGen tools or AI-enabled apps;Technical ...  ...
# 4           AI CodeGen tools or AI-enabled apps;Videos (no...  ...
# 5           Technical documentation (is generated for/by t...  ...
# ...                                                       ...  ...
# 49187                                                     NaN  ...
# 49188                                                     NaN  ...
# 49189       AI CodeGen tools or AI-enabled apps;Videos (no...  ...
# 49190                                                     NaN  ...
# 49191                     AI CodeGen tools or AI-enabled apps  ...
#
#             AIAgentOrchestration AIAgentOrchWrite AIAgentObserveSecure  \
# ResponseId
# 1                      Vertex AI              NaN                  NaN
# 2                            NaN              NaN                  NaN
# 3                            NaN              NaN                  NaN
# 4                            NaN              NaN                  NaN
# 5                            NaN              NaN                  NaN
# ...                          ...              ...                  ...
# 49187                        NaN              NaN                  NaN
# 49188                        NaN              NaN                  NaN
# 49189                        NaN              NaN                  NaN
# 49190                        NaN              NaN                  NaN
# 49191                        NaN              NaN                  NaN
#
#            AIAgentObsWrite                                   AIAgentExternal  \
# ResponseId
# 1                      NaN                                           ChatGPT
# 2                      NaN                                               NaN
# 3                      NaN  ChatGPT;Claude Code;GitHub Copilot;Google Gemini
# 4                      NaN                               ChatGPT;Claude Code
# 5                      NaN                                               NaN
# ...                    ...                                               ...
# 49187                  NaN                                               NaN
# 49188                  NaN                                               NaN
# 49189                  NaN                                               NaN
# 49190                  NaN                                               NaN
# 49191                  NaN                                               NaN
#
#            AIAgentExtWrite                                            AIHuman  \
# ResponseId
# 1                      NaN                    When I don’t trust AI’s answers
# 2                      NaN  When I don’t trust AI’s answers;When I want to...
# 3                      NaN  When I don’t trust AI’s answers;When I want to...
# 4                      NaN  When I don’t trust AI’s answers;When I want to...
# 5                      NaN                    When I don’t trust AI’s answers
# ...                    ...                                                ...
# 49187                  NaN                                                NaN
# 49188                  NaN                                                NaN
# 49189                  NaN                                                NaN
# 49190                  NaN                                                NaN
# 49191                  NaN                                                NaN
#
#                                                        AIOpen  \
# ResponseId
# 1                       Troubleshooting, profiling, debugging
# 2                                   All skills. AI is a flop.
# 3           Understand how things actually work, problem s...
# 4                                                         NaN
# 5           critical thinking, the skill to define the tas...
# ...                                                       ...
# 49187                                                     NaN
# 49188                                                     NaN
# 49189                                                     NaN
# 49190                                                     NaN
# 49191                                                     NaN
#
#             SalaryUSDYearly  JobSat
# ResponseId
# 1                   61256.0    10.0
# 2                  104413.0     9.0
# 3                   53061.0     8.0
# 4                   36197.0     6.0
# 5                   60000.0     7.0
# ...                     ...     ...
# 49187                   NaN     NaN
# 49188                   NaN     NaN
# 49189                   NaN     9.0
# 49190                   NaN     NaN
# 49191                   NaN     NaN
#
# [49191 rows x 171 columns]

# %%
df
# Out:
#                                                    MainBranch  \
# ResponseId
# 1                              I am a developer by profession
# 2                              I am a developer by profession
# 3                              I am a developer by profession
# 4                              I am a developer by profession
# 5                              I am a developer by profession
# ...                                                       ...
# 49187                             I code primarily as a hobby
# 49188                          I am a developer by profession
# 49189                          I am a developer by profession
# 49190                          I am a developer by profession
# 49191       I am not primarily a developer, but I write co...
#
#                         Age  \
# ResponseId
# 1           25-34 years old
# 2           25-34 years old
# 3           35-44 years old
# 4           35-44 years old
# 5           35-44 years old
# ...                     ...
# 49187       18-24 years old
# 49188       45-54 years old
# 49189       35-44 years old
# 49190       25-34 years old
# 49191       18-24 years old
#
#                                                       EdLevel  \
# ResponseId
# 1             Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 2                         Associate degree (A.A., A.S., etc.)
# 3                Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 4                Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 5             Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# ...                                                       ...
# 49187            Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 49188       Some college/university study without earning ...
# 49189         Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 49190          Professional degree (JD, MD, Ph.D, Ed.D, etc.)
# 49191       Some college/university study without earning ...
#
#                                                    Employment  \
# ResponseId
# 1                                                    Employed
# 2                                                    Employed
# 3           Independent contractor, freelancer, or self-em...
# 4                                                    Employed
# 5           Independent contractor, freelancer, or self-em...
# ...                                                       ...
# 49187                                                Employed
# 49188                                                Employed
# 49189                                                Employed
# 49190       Independent contractor, freelancer, or self-em...
# 49191                                                 Student
#
#                                              EmploymentAddl  WorkExp  \
# ResponseId
# 1           Caring for dependents (children, elderly, etc.)      8.0
# 2                                                       NaN      2.0
# 3                                         None of the above     10.0
# 4                                         None of the above      4.0
# 5           Caring for dependents (children, elderly, etc.)     21.0
# ...                                                     ...      ...
# 49187                                                   NaN      NaN
# 49188       Caring for dependents (children, elderly, etc.)     25.0
# 49189                                     None of the above     17.0
# 49190                                     None of the above      2.0
# 49191                          Attending school (full-time)      NaN
#
#                                               LearnCodeChoose  \
# ResponseId
# 1           Yes, I am not new to coding but am learning ne...
# 2           Yes, I am not new to coding but am learning ne...
# 3           Yes, I am not new to coding but am learning ne...
# 4           Yes, I am not new to coding but am learning ne...
# 5           No, I am not new to coding and did not learn n...
# ...                                                       ...
# 49187                                                     NaN
# 49188       Yes, I am not new to coding but am learning ne...
# 49189       Yes, I am not new to coding but am learning ne...
# 49190       Yes, I am not new to coding but am learning ne...
# 49191       Yes, I am not new to coding but am learning ne...
#
#                                                     LearnCode  \
# ResponseId
# 1           Online Courses or Certification (includes all ...
# 2           Online Courses or Certification (includes all ...
# 3           Online Courses or Certification (includes all ...
# 4           Other online resources (e.g. standard search, ...
# 5                                                         NaN
# ...                                                       ...
# 49187                                                     NaN
# 49188       Online Courses or Certification (includes all ...
# 49189       Online Courses or Certification (includes all ...
# 49190       Videos (not associated with specific online co...
# 49191       Online Courses or Certification (includes all ...
#
#                                                   LearnCodeAI  \
# ResponseId
# 1           Yes, I learned how to use AI-enabled tools for...
# 2           Yes, I learned how to use AI-enabled tools for...
# 3           Yes, I learned how to use AI-enabled tools for...
# 4           Yes, I learned how to use AI-enabled tools for...
# 5           Yes, I learned how to use AI-enabled tools for...
# ...                                                       ...
# 49187                                                     NaN
# 49188       Yes, I learned how to use AI-enabled tools req...
# 49189       Yes, I learned how to use AI-enabled tools for...
# 49190       Yes, I learned how to use AI-enabled tools for...
# 49191       Yes, I learned how to use AI-enabled tools for...
#
#                                                    AILearnHow  ...  \
# ResponseId                                                     ...
# 1                         AI CodeGen tools or AI-enabled apps  ...
# 2                         AI CodeGen tools or AI-enabled apps  ...
# 3           AI CodeGen tools or AI-enabled apps;Technical ...  ...
# 4           AI CodeGen tools or AI-enabled apps;Videos (no...  ...
# 5           Technical documentation (is generated for/by t...  ...
# ...                                                       ...  ...
# 49187                                                     NaN  ...
# 49188                                                     NaN  ...
# 49189       AI CodeGen tools or AI-enabled apps;Videos (no...  ...
# 49190                                                     NaN  ...
# 49191                     AI CodeGen tools or AI-enabled apps  ...
#
#             AIAgentOrchestration AIAgentOrchWrite AIAgentObserveSecure  \
# ResponseId
# 1                      Vertex AI              NaN                  NaN
# 2                            NaN              NaN                  NaN
# 3                            NaN              NaN                  NaN
# 4                            NaN              NaN                  NaN
# 5                            NaN              NaN                  NaN
# ...                          ...              ...                  ...
# 49187                        NaN              NaN                  NaN
# 49188                        NaN              NaN                  NaN
# 49189                        NaN              NaN                  NaN
# 49190                        NaN              NaN                  NaN
# 49191                        NaN              NaN                  NaN
#
#            AIAgentObsWrite                                   AIAgentExternal  \
# ResponseId
# 1                      NaN                                           ChatGPT
# 2                      NaN                                               NaN
# 3                      NaN  ChatGPT;Claude Code;GitHub Copilot;Google Gemini
# 4                      NaN                               ChatGPT;Claude Code
# 5                      NaN                                               NaN
# ...                    ...                                               ...
# 49187                  NaN                                               NaN
# 49188                  NaN                                               NaN
# 49189                  NaN                                               NaN
# 49190                  NaN                                               NaN
# 49191                  NaN                                               NaN
#
#            AIAgentExtWrite                                            AIHuman  \
# ResponseId
# 1                      NaN                    When I don’t trust AI’s answers
# 2                      NaN  When I don’t trust AI’s answers;When I want to...
# 3                      NaN  When I don’t trust AI’s answers;When I want to...
# 4                      NaN  When I don’t trust AI’s answers;When I want to...
# 5                      NaN                    When I don’t trust AI’s answers
# ...                    ...                                                ...
# 49187                  NaN                                                NaN
# 49188                  NaN                                                NaN
# 49189                  NaN                                                NaN
# 49190                  NaN                                                NaN
# 49191                  NaN                                                NaN
#
#                                                        AIOpen  \
# ResponseId
# 1                       Troubleshooting, profiling, debugging
# 2                                   All skills. AI is a flop.
# 3           Understand how things actually work, problem s...
# 4                                                         NaN
# 5           critical thinking, the skill to define the tas...
# ...                                                       ...
# 49187                                                     NaN
# 49188                                                     NaN
# 49189                                                     NaN
# 49190                                                     NaN
# 49191                                                     NaN
#
#             ConvertedCompYearly  JobSat
# ResponseId
# 1                       61256.0    10.0
# 2                      104413.0     9.0
# 3                       53061.0     8.0
# 4                       36197.0     6.0
# 5                       60000.0     7.0
# ...                         ...     ...
# 49187                       NaN     NaN
# 49188                       NaN     NaN
# 49189                       NaN     9.0
# 49190                       NaN     NaN
# 49191                       NaN     NaN
#
# [49191 rows x 171 columns]

# %%
df["first"] + "  " + df["last"]
# Out:
# 0    Corey  Schafer
# 1         Jane  Doe
# 2         John  Doe
# dtype: str

# %%
df["full_name"] = df["first"] + "  " + df["last"]
df
# Out:
#    first     last                    email       full_name
# 0  Corey  Schafer  CoreyMSchafer@gmail.com  Corey  Schafer
# 1   Jane      Doe        JaneDoe@email.com       Jane  Doe
# 2   John      Doe        JohnDoe@email.com       John  Doe

# %%
df.drop(columns=["first", "last"], inplace=True)

# %%
df
# Out:
#                      email       full_name
# 0  CoreyMSchafer@gmail.com  Corey  Schafer
# 1        JaneDoe@email.com       Jane  Doe
# 2        JohnDoe@email.com       John  Doe

# %%
df["full_name"].str.split("  ", expand=True)
# Out:
#        0        1
# 0  Corey  Schafer
# 1   Jane      Doe
# 2   John      Doe

# %%
df[["first", "last"]] = df["full_name"].str.split("  ", expand=True)

# %%
df
# Out:
#                      email       full_name  first     last
# 0  CoreyMSchafer@gmail.com  Corey  Schafer  Corey  Schafer
# 1        JaneDoe@email.com       Jane  Doe   Jane      Doe
# 2        JohnDoe@email.com       John  Doe   John      Doe

# %%
pd.concat([df, pd.DataFrame({"first": ["Tony"]})], ignore_index=True)
# Out:
#                      email       full_name  first     last
# 0  CoreyMSchafer@gmail.com  Corey  Schafer  Corey  Schafer
# 1        JaneDoe@email.com       Jane  Doe   Jane      Doe
# 2        JohnDoe@email.com       John  Doe   John      Doe
# 3                      NaN             NaN   Tony      NaN

# %%
people = {
    "first": ["Zé", "Balão"],
    "last": ["Hanna", "Marin"],
    "email": ["darksouls@gmail.com", "soulsdark@email.com"]
}

df2 = pd.DataFrame(people)

# %%
df2
# Out:
#    first   last                email
# 0     Zé  Hanna  darksouls@gmail.com
# 1  Balão  Marin  soulsdark@email.com

# %%
df3 = pd.concat([df, df2], ignore_index=True)

# %%
df3
# Out:
#                      email       full_name  first     last
# 0  CoreyMSchafer@gmail.com  Corey  Schafer  Corey  Schafer
# 1        JaneDoe@email.com       Jane  Doe   Jane      Doe
# 2        JohnDoe@email.com       John  Doe   John      Doe
# 3      darksouls@gmail.com             NaN     Zé    Hanna
# 4      soulsdark@email.com             NaN  Balão    Marin

# %%
df3.drop(index=4)
# Out:
#                      email       full_name  first     last
# 0  CoreyMSchafer@gmail.com  Corey  Schafer  Corey  Schafer
# 1        JaneDoe@email.com       Jane  Doe   Jane      Doe
# 2        JohnDoe@email.com       John  Doe   John      Doe
# 3      darksouls@gmail.com             NaN     Zé    Hanna

# %%
# 1. df["last"] == "Doe" - creates a boolean mask, True where last name is "Doe"
# 2. df[mask] - filters the DataFrame, returning only the rows where mask is True
# 3. .index - gets the index labels of those filtered rows
# 4. df.drop(index=...) - drops the rows with those index labels from the DataFrame
df.drop(index=df[df["last"] == "Doe"].index)
# Out:
#                      email       full_name  first     last
# 0  CoreyMSchafer@gmail.com  Corey  Schafer  Corey  Schafer

# %%
df.sort_values(by="last", ascending=False)
# Out:
#    first     last                    email
# 3    Ada     Wong            Ada@email.com
# 0  Corey  Schafer  CoreyMSchafer@gmail.com
# 1   Jane      Doe        JaneDoe@email.com
# 2   John      Doe        JohnDoe@email.com

# %%
df.sort_values(by=["last", "first"], ascending=False)
# Out:
#    first     last                    email
# 3    Ada     Wong            Ada@email.com
# 0  Corey  Schafer  CoreyMSchafer@gmail.com
# 2   John      Doe        JohnDoe@email.com
# 1   Jane      Doe        JaneDoe@email.com

# %%
df.sort_values(by=["last", "first"], ascending=[False, True], inplace=True)

# %%
df
# Out:
#    first     last                    email
# 3    Ada     Wong            Ada@email.com
# 0  Corey  Schafer  CoreyMSchafer@gmail.com
# 1   Jane      Doe        JaneDoe@email.com
# 2   John      Doe        JohnDoe@email.com

# %%
df.sort_index()
# Out:
#    first     last                    email
# 0  Corey  Schafer  CoreyMSchafer@gmail.com
# 1   Jane      Doe        JaneDoe@email.com
# 2   John      Doe        JohnDoe@email.com
# 3    Ada     Wong            Ada@email.com

# %%
df["last"].sort_values()
# Out:
# 1        Doe
# 2        Doe
# 0    Schafer
# 3       Wong
# Name: last, dtype: str

# %%
df.sort_values(by=["Country", "ConvertedCompYearly"], ascending=[True, False], inplace=True)

# %%
df[["Country", "ConvertedCompYearly"]].head(50)
# Out:
#                 Country  ConvertedCompYearly
# ResponseId
# 40967       Afghanistan              65000.0
# 40307       Afghanistan               9858.0
# 7077        Afghanistan               8450.0
# 45925       Afghanistan               7042.0
# 7167        Afghanistan               5200.0
# 38609       Afghanistan               1000.0
# 6010        Afghanistan                986.0
# 7925        Afghanistan                282.0
# 6836        Afghanistan                  NaN
# 15708       Afghanistan                  NaN
# 19816       Afghanistan                  NaN
# 44797       Afghanistan                  NaN
# 27099       Afghanistan                  NaN
# 2023            Albania             139218.0
# 28588           Albania             118286.0
# 3185            Albania             116014.0
# 37731           Albania              67779.0
# 35934           Albania              50000.0
# 14758           Albania              34804.0
# 33940           Albania              17734.0
# 48950           Albania              17402.0
# 3888            Albania              14187.0
# 16850           Albania                236.0
# 22400           Albania                 15.0
# 27802           Albania                  8.0
# 36997           Albania                  NaN
# 35184           Albania                  NaN
# 16239           Albania                  NaN
# 45421           Albania                  NaN
# 44879           Albania                  NaN
# 44946           Albania                  NaN
# 8776            Albania                  NaN
# 11874           Albania                  NaN
# 41907           Albania                  NaN
# 25304           Albania                  NaN
# 41296           Algeria              98612.0
# 37619           Algeria              50000.0
# 26446           Algeria              23114.0
# 1541            Algeria              20883.0
# 23091           Algeria              12000.0
# 29465           Algeria               7705.0
# 16686           Algeria               7088.0
# 30107           Algeria               6472.0
# 1841            Algeria               4438.0
# 31352           Algeria               3852.0
# 46636           Algeria               2400.0
# 14548           Algeria               1156.0
# 34029           Algeria               1109.0
# 25845           Algeria                185.0
# 11322           Algeria                 17.0

# %%
df["ConvertedCompYearly"].nlargest(10)
# Out:
# ResponseId
# 34268    50000000.0
# 28701    33552715.0
# 43144    18387548.0
# 35354    15430267.0
# 45972    13921760.0
# 48429    10000000.0
# 24901     9531653.0
# 10026     9000000.0
# 37353     6890299.0
# 30729     6371285.0
# Name: ConvertedCompYearly, dtype: float64

# %%
df.nlargest(10, "ConvertedCompYearly")
# Out:
#                                                    MainBranch  \
# ResponseId
# 34268                             I code primarily as a hobby
# 28701                          I am a developer by profession
# 43144                             I code primarily as a hobby
# 35354                          I am a developer by profession
# 45972       I work with developers or my work supports dev...
# 48429                             I code primarily as a hobby
# 24901                          I am a developer by profession
# 10026                          I am a developer by profession
# 37353                          I am a developer by profession
# 30729                          I am a developer by profession
#
#                         Age                                          EdLevel  \
# ResponseId
# 34268       55-64 years old              Associate degree (A.A., A.S., etc.)
# 28701       35-44 years old  Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 43144       18-24 years old              Associate degree (A.A., A.S., etc.)
# 35354       35-44 years old     Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 45972       55-64 years old  Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 48429       18-24 years old     Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 24901       18-24 years old     Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 10026       25-34 years old                        Primary/elementary school
# 37353       35-44 years old  Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 30729       35-44 years old   Professional degree (JD, MD, Ph.D, Ed.D, etc.)
#
#                                                    Employment  \
# ResponseId
# 34268       Independent contractor, freelancer, or self-em...
# 28701                                                Employed
# 43144                                                Employed
# 35354                                                Employed
# 45972                                                Employed
# 48429                                                 Student
# 24901                                                Employed
# 10026                                                Employed
# 37353       Independent contractor, freelancer, or self-em...
# 30729                                                Employed
#
#                                                EmploymentAddl  WorkExp  \
# ResponseId
# 34268                                       None of the above     10.0
# 28701             Engaged in paid work (20-29 hours per week)     20.0
# 43144       Engaged in paid work (20-29 hours per week);En...     10.0
# 35354             Engaged in paid work (20-29 hours per week)     15.0
# 45972             Engaged in paid work (20-29 hours per week)     30.0
# 48429       Engaged in paid work (10-19 hours per week);En...      NaN
# 24901             Engaged in paid work (20-29 hours per week)      1.0
# 10026                            Attending school (full-time)      2.0
# 37353                                Volunteering (regularly)     15.0
# 30729       Attending school (part-time);Engaged in paid w...     17.0
#
#                                               LearnCodeChoose  \
# ResponseId
# 34268       Yes, I am not new to coding but am learning ne...
# 28701       No, I am not new to coding and did not learn n...
# 43144       Yes, I am not new to coding but am learning ne...
# 35354       No, I am not new to coding and did not learn n...
# 45972       Yes, I am not new to coding but am learning ne...
# 48429       Yes, I am not new to coding but am learning ne...
# 24901       Yes, I am not new to coding but am learning ne...
# 10026       No, I am not new to coding and did not learn n...
# 37353       No, I am not new to coding and did not learn n...
# 30729       Yes, I am not new to coding but am learning ne...
#
#                                                     LearnCode  \
# ResponseId
# 34268       Other online resources (e.g. standard search, ...
# 28701                                                     NaN
# 43144                                 Other (please specify):
# 35354                                                     NaN
# 45972                        Colleague or on-the-job training
# 48429       Other online resources (e.g. standard search, ...
# 24901       Online Courses or Certification (includes all ...
# 10026                                                     NaN
# 37353                                                     NaN
# 30729       Stack Overflow or Stack Exchange;Technical doc...
#
#                                                   LearnCodeAI  \
# ResponseId
# 34268       Yes, I learned how to use AI-enabled tools for...
# 28701       Yes, I learned how to use AI-enabled tools req...
# 43144       Yes, I learned how to use AI-enabled tools for...
# 35354                                                     NaN
# 45972       Yes, I learned how to use AI-enabled tools req...
# 48429       Yes, I learned how to use AI-enabled tools req...
# 24901       Yes, I learned how to use AI-enabled tools for...
# 10026       No, I learned something that was not related t...
# 37353       Yes, I learned how to use AI-enabled tools req...
# 30729       Yes, I learned how to use AI-enabled tools req...
#
#                                                    AILearnHow  ...  \
# ResponseId                                                     ...
# 34268       Technical documentation (is generated for/by t...  ...
# 28701                     AI CodeGen tools or AI-enabled apps  ...
# 43144                     AI CodeGen tools or AI-enabled apps  ...
# 35354                                                     NaN  ...
# 45972                        Colleague or on-the-job training  ...
# 48429       Technical documentation (is generated for/by t...  ...
# 24901                     AI CodeGen tools or AI-enabled apps  ...
# 10026                                                     NaN  ...
# 37353       Videos (not associated with specific online co...  ...
# 30729       Technical documentation (is generated for/by t...  ...
#
#             AIAgentOrchestration AIAgentOrchWrite AIAgentObserveSecure  \
# ResponseId
# 34268                        NaN              NaN                  NaN
# 28701                        NaN              NaN                  NaN
# 43144                        NaN              NaN                  NaN
# 35354                        NaN              NaN                  NaN
# 45972                        NaN              NaN                  NaN
# 48429                        NaN              NaN                  NaN
# 24901                        NaN              NaN                  NaN
# 10026                        NaN              NaN                  NaN
# 37353                        NaN              NaN                  NaN
# 30729                        NaN              NaN                  NaN
#
#            AIAgentObsWrite                       AIAgentExternal  \
# ResponseId
# 34268                  NaN                                   NaN
# 28701                  NaN  ChatGPT;GitHub Copilot;Google Gemini
# 43144                  NaN                                   NaN
# 35354                  NaN                 ChatGPT;Google Gemini
# 45972                  NaN                                   NaN
# 48429                  NaN                                   NaN
# 24901                  NaN                                   NaN
# 10026                  NaN                                   NaN
# 37353                  NaN                                   NaN
# 30729                  NaN                                   NaN
#
#            AIAgentExtWrite                                            AIHuman  \
# ResponseId
# 34268                  NaN                                                NaN
# 28701                  NaN  When I don’t trust AI’s answers;When I have et...
# 43144                  NaN  When I don’t trust AI’s answers;When I want to...
# 35354                  NaN       When I’m stuck and can’t explain the problem
# 45972                  NaN                                                NaN
# 48429                  NaN                                                NaN
# 24901                  NaN  When I want to fully understand something;When...
# 10026                  NaN  When I don’t trust AI’s answers;When I want to...
# 37353                  NaN  When I want to fully understand something;When...
# 30729                  NaN  When I don’t trust AI’s answers;When I want to...
#
#                                                        AIOpen  \
# ResponseId
# 34268                                                     NaN
# 28701                                                     NaN
# 43144                                          being laid off
# 35354                                                     NaN
# 45972                                                     NaN
# 48429                                                     NaN
# 24901                                                     NaN
# 10026                                              Everything
# 37353       All the same: right tools for proper tasks, co...
# 30729       problem synthesis, communication, panoramic vi...
#
#             ConvertedCompYearly  JobSat
# ResponseId
# 34268                50000000.0     NaN
# 28701                33552715.0     7.0
# 43144                18387548.0     NaN
# 35354                15430267.0     8.0
# 45972                13921760.0     NaN
# 48429                10000000.0     NaN
# 24901                 9531653.0     4.0
# 10026                 9000000.0     9.0
# 37353                 6890299.0     7.0
# 30729                 6371285.0     8.0
#
# [10 rows x 171 columns]

# %%
df.nsmallest(10, "ConvertedCompYearly")
# Out:
#                                                    MainBranch  \
# ResponseId
# 34866                          I am a developer by profession
# 41683       I am not primarily a developer, but I write co...
# 34568                          I am a developer by profession
# 27893                                   I am learning to code
# 28178                          I am a developer by profession
# 42079       I work with developers or my work supports dev...
# 16490                                   I am learning to code
# 4581                           I am a developer by profession
# 21035                          I am a developer by profession
# 26962                          I am a developer by profession
#
#                         Age  \
# ResponseId
# 34866       35-44 years old
# 41683       45-54 years old
# 34568       25-34 years old
# 27893       35-44 years old
# 28178       18-24 years old
# 42079       25-34 years old
# 16490       18-24 years old
# 4581        18-24 years old
# 21035       18-24 years old
# 26962       25-34 years old
#
#                                                       EdLevel  \
# ResponseId
# 34866         Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 41683         Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 34568                               Primary/elementary school
# 27893       Some college/university study without earning ...
# 28178          Professional degree (JD, MD, Ph.D, Ed.D, etc.)
# 42079       Some college/university study without earning ...
# 16490                               Primary/elementary school
# 4581                      Associate degree (A.A., A.S., etc.)
# 21035         Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 26962            Bachelor’s degree (B.A., B.S., B.Eng., etc.)
#
#                                                    Employment  \
# ResponseId
# 34866                                                Employed
# 41683       Independent contractor, freelancer, or self-em...
# 34568                                                Employed
# 27893                                            Not employed
# 28178       Independent contractor, freelancer, or self-em...
# 42079                                                 Student
# 16490       Independent contractor, freelancer, or self-em...
# 4581                                                  Student
# 21035                                            Not employed
# 26962                                                Employed
#
#                                                EmploymentAddl  WorkExp  \
# ResponseId
# 34866       Engaged in paid work (less than 10 hours per w...     16.0
# 41683                                       None of the above     13.0
# 34568                                Volunteering (regularly)      8.0
# 27893                                       None of the above     12.0
# 28178       Volunteering (regularly);Engaged in paid work ...      1.0
# 42079                            Attending school (full-time)     12.0
# 16490                                Volunteering (regularly)      1.0
# 4581        Attending school (full-time);Engaged in paid w...      6.0
# 21035         Caring for dependents (children, elderly, etc.)      1.0
# 26962             Engaged in paid work (20-29 hours per week)     11.0
#
#                                               LearnCodeChoose  \
# ResponseId
# 34866       Yes, I am not new to coding but am learning ne...
# 41683       Yes, I am not new to coding but am learning ne...
# 34568       No, I am not new to coding and did not learn n...
# 27893       Yes, I am not new to coding but am learning ne...
# 28178       Yes, I am not new to coding but am learning ne...
# 42079          Yes, I am new to coding or currently a student
# 16490       No, I am not new to coding and did not learn n...
# 4581           Yes, I am new to coding or currently a student
# 21035       Yes, I am not new to coding but am learning ne...
# 26962       Yes, I am not new to coding but am learning ne...
#
#                                                     LearnCode  \
# ResponseId
# 34866       Other online resources (e.g. standard search, ...
# 41683       Other online resources (e.g. standard search, ...
# 34568                                                     NaN
# 27893       Online Courses or Certification (includes all ...
# 28178       Online Courses or Certification (includes all ...
# 42079                 School (i.e., University, College, etc)
# 16490                                                     NaN
# 4581        Other online resources (e.g. standard search, ...
# 21035       Online Courses or Certification (includes all ...
# 26962                     AI CodeGen tools or AI-enabled apps
#
#                                                   LearnCodeAI  \
# ResponseId
# 34866       Yes, I learned how to use AI-enabled tools for...
# 41683       No, I learned something that was not related t...
# 34568       Yes, I learned how to use AI-enabled tools req...
# 27893       No, I learned something that was not related t...
# 28178       Yes, I learned how to use AI-enabled tools for...
# 42079       Yes, I learned how to use AI-enabled tools req...
# 16490       Yes, I learned how to use AI-enabled tools for...
# 4581        Yes, I learned how to use AI-enabled tools for...
# 21035       Yes, I learned how to use AI-enabled tools req...
# 26962       Yes, I learned how to use AI-enabled tools for...
#
#                                                    AILearnHow  ...  \
# ResponseId                                                     ...
# 34866       AI CodeGen tools or AI-enabled apps;Technical ...  ...
# 41683                                                     NaN  ...
# 34568                     AI CodeGen tools or AI-enabled apps  ...
# 27893                                                     NaN  ...
# 28178       Videos (not associated with specific online co...  ...
# 42079       Other online resources (e.g. standard search, ...  ...
# 16490       Technical documentation (is generated for/by t...  ...
# 4581        Videos (not associated with specific online co...  ...
# 21035       Videos (not associated with specific online co...  ...
# 26962                     AI CodeGen tools or AI-enabled apps  ...
#
#                   AIAgentOrchestration AIAgentOrchWrite  \
# ResponseId
# 34866                           Ollama              NaN
# 41683                              NaN              NaN
# 34568                              NaN              NaN
# 27893                              NaN              NaN
# 28178                              NaN              NaN
# 42079            Amazon Bedrock Agents              NaN
# 16490                              NaN              NaN
# 4581                               NaN              NaN
# 21035                           Zapier              NaN
# 26962       CrewAI;LangChain;LangGraph              NaN
#
#                             AIAgentObserveSecure AIAgentObsWrite  \
# ResponseId
# 34866                                        NaN             NaN
# 41683                                        NaN             NaN
# 34568                                        NaN             NaN
# 27893                                        NaN             NaN
# 28178                                        NaN             NaN
# 42079       Adversarial Robustness Toolbox (ART)             NaN
# 16490                                        NaN             NaN
# 4581                                         NaN             NaN
# 21035                                   Langfuse             NaN
# 26962                                        NaN             NaN
#
#                                               AIAgentExternal AIAgentExtWrite  \
# ResponseId
# 34866       ChatGPT;Claude Code;GitHub Copilot;Google Gemi...             NaN
# 41683                                                     NaN             NaN
# 34568                                                     NaN             NaN
# 27893                                                     NaN             NaN
# 28178                                                     NaN             NaN
# 42079                          OpenHands (formerly OpenDevin)             NaN
# 16490                                                     NaN             NaN
# 4581                                                      NaN             NaN
# 21035                                        ChatGPT;Bolt.new             NaN
# 26962                                                     NaN             NaN
#
#                                                       AIHuman  \
# ResponseId
# 34866       When I don’t trust AI’s answers;When I want to...
# 41683               When I want to fully understand something
# 34568                                                     NaN
# 27893                                                     NaN
# 28178       When I don’t trust AI’s answers;When I want to...
# 42079               When I want to fully understand something
# 16490                                                     NaN
# 4581             When I’m stuck and can’t explain the problem
# 21035                  When I need quick help troubleshooting
# 26962                                                     NaN
#
#                                                        AIOpen  \
# ResponseId
# 34866                                             all of them
# 41683       AI provides the code but if it is not somethin...
# 34568                                                     NaN
# 27893                                                     NaN
# 28178                            Solve any problem with logic
# 42079                                               Mentioned
# 16490                                                     NaN
# 4581                                                      NaN
# 21035           Well it will gradually take to a killing path
# 26962                                                     NaN
#
#             ConvertedCompYearly  JobSat
# ResponseId
# 34866                       1.0     8.0
# 41683                       1.0     NaN
# 34568                       1.0     5.0
# 27893                       1.0     NaN
# 28178                       1.0     8.0
# 42079                       1.0     NaN
# 16490                       1.0     NaN
# 4581                        1.0     8.0
# 21035                       1.0     6.0
# 26962                       1.0     4.0
#
# [10 rows x 171 columns]

# %%
df["ConvertedCompYearly"].head(15)
# Out:
# ResponseId
# 1      61256.0
# 2     104413.0
# 3      53061.0
# 4      36197.0
# 5      60000.0
# 6     120000.0
# 7       6240.0
# 8      72000.0
# 9      70000.0
# 10      5400.0
# 11     65691.0
# 12     14400.0
# 13      1099.0
# 14         NaN
# 15         NaN
# Name: ConvertedCompYearly, dtype: float64

# %%
df["ConvertedCompYearly"].median()
# Out:
# np.float64(75320.0)

# %%
df.describe()
# Out:
#             WorkExp     YearsCode  TechEndorse_1  TechEndorse_2  \
# count  42893.000000  43042.000000   35975.000000   35975.000000
# mean      13.367403     16.570861       7.867352       4.104211
# std       10.800117     11.787610       2.397432       2.275821
# min        1.000000      1.000000       1.000000       1.000000
# 25%        5.000000      8.000000       7.000000       2.000000
# 50%       10.000000     14.000000       9.000000       4.000000
# 75%       20.000000     24.000000       9.000000       6.000000
# max      100.000000    100.000000      14.000000      14.000000
#
#        TechEndorse_3  TechEndorse_4  TechEndorse_5  TechEndorse_6  \
# count   35975.000000   35975.000000   35975.000000   35975.000000
# mean        4.110271       5.678193       4.119388       5.225990
# std         2.329536       2.398084       2.437945       2.801045
# min         1.000000       1.000000       1.000000       1.000000
# 25%         2.000000       4.000000       2.000000       3.000000
# 50%         4.000000       6.000000       4.000000       5.000000
# 75%         6.000000       8.000000       6.000000       8.000000
# max        14.000000      14.000000      14.000000      14.000000
#
#        TechEndorse_7  TechEndorse_8  ...  SO_Actions_3  SO_Actions_4  \
# count   35975.000000   35975.000000  ...  26260.000000  26260.000000
# mean        6.477387       4.370841  ...      5.718355      4.561767
# std         2.331468       2.357058  ...      2.628016      3.070548
# min         1.000000       1.000000  ...      1.000000      1.000000
# 25%         5.000000       2.000000  ...      3.000000      1.000000
# 50%         7.000000       4.000000  ...      6.000000      4.000000
# 75%         8.000000       6.000000  ...      8.000000      7.000000
# max        14.000000      14.000000  ...     15.000000     15.000000
#
#        SO_Actions_5  SO_Actions_6  SO_Actions_9  SO_Actions_7  SO_Actions_10  \
# count  26260.000000  26260.000000  26260.000000  26260.000000   26260.000000
# mean       4.790861      5.199657      5.676314      4.984653       7.099505
# std        2.643177      2.563562      2.310659      2.490095       2.469394
# min        1.000000      1.000000      1.000000      1.000000       1.000000
# 25%        3.000000      3.000000      4.000000      3.000000       6.000000
# 50%        5.000000      5.000000      6.000000      5.000000       8.000000
# 75%        7.000000      7.000000      7.000000      7.000000       9.000000
# max       15.000000     15.000000     15.000000     15.000000      15.000000
#
#        SO_Actions_15  ConvertedCompYearly        JobSat
# count   26260.000000         2.394700e+04  26670.000000
# mean       10.079284         1.017615e+05      7.201950
# std         1.940928         4.617569e+05      1.997245
# min         1.000000         1.000000e+00      0.000000
# 25%        10.000000         3.817100e+04      6.000000
# 50%        10.000000         7.532000e+04      8.000000
# 75%        10.000000         1.205960e+05      8.000000
# max        15.000000         5.000000e+07     10.000000
#
# [8 rows x 52 columns]

# %%
df["ConvertedCompYearly"].count()
# Out:
# np.int64(23947)

# %%
pd.set_option('display.max_columns', None)

# %%
df.head()
# Out:
#                                 MainBranch              Age  \
# ResponseId
# 1           I am a developer by profession  25-34 years old
# 2           I am a developer by profession  25-34 years old
# 3           I am a developer by profession  35-44 years old
# 4           I am a developer by profession  35-44 years old
# 5           I am a developer by profession  35-44 years old
#
#                                                     EdLevel  \
# ResponseId
# 1           Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 2                       Associate degree (A.A., A.S., etc.)
# 3              Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 4              Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 5           Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
#
#                                                    Employment  \
# ResponseId
# 1                                                    Employed
# 2                                                    Employed
# 3           Independent contractor, freelancer, or self-em...
# 4                                                    Employed
# 5           Independent contractor, freelancer, or self-em...
#
#                                              EmploymentAddl  WorkExp  \
# ResponseId
# 1           Caring for dependents (children, elderly, etc.)      8.0
# 2                                                       NaN      2.0
# 3                                         None of the above     10.0
# 4                                         None of the above      4.0
# 5           Caring for dependents (children, elderly, etc.)     21.0
#
#                                               LearnCodeChoose  \
# ResponseId
# 1           Yes, I am not new to coding but am learning ne...
# 2           Yes, I am not new to coding but am learning ne...
# 3           Yes, I am not new to coding but am learning ne...
# 4           Yes, I am not new to coding but am learning ne...
# 5           No, I am not new to coding and did not learn n...
#
#                                                     LearnCode  \
# ResponseId
# 1           Online Courses or Certification (includes all ...
# 2           Online Courses or Certification (includes all ...
# 3           Online Courses or Certification (includes all ...
# 4           Other online resources (e.g. standard search, ...
# 5                                                         NaN
#
#                                                   LearnCodeAI  \
# ResponseId
# 1           Yes, I learned how to use AI-enabled tools for...
# 2           Yes, I learned how to use AI-enabled tools for...
# 3           Yes, I learned how to use AI-enabled tools for...
# 4           Yes, I learned how to use AI-enabled tools for...
# 5           Yes, I learned how to use AI-enabled tools for...
#
#                                                    AILearnHow  YearsCode  \
# ResponseId
# 1                         AI CodeGen tools or AI-enabled apps       14.0
# 2                         AI CodeGen tools or AI-enabled apps       10.0
# 3           AI CodeGen tools or AI-enabled apps;Technical ...       12.0
# 4           AI CodeGen tools or AI-enabled apps;Videos (no...        5.0
# 5           Technical documentation (is generated for/by t...       22.0
#
#                          DevType                   OrgSize  \
# ResponseId
# 1              Developer, mobile        20 to 99 employees
# 2            Developer, back-end      500 to 999 employees
# 3           Developer, front-end                       NaN
# 4            Developer, back-end  10,000 or more employees
# 5            Engineering manager                       NaN
#
#                             ICorPM  \
# ResponseId
# 1                   People manager
# 2           Individual contributor
# 3                              NaN
# 4           Individual contributor
# 5                              NaN
#
#                                                    RemoteWork  \
# ResponseId
# 1                                                      Remote
# 2           Hybrid (some in-person, leans heavy to flexibi...
# 3                                                         NaN
# 4                                                      Remote
# 5                                                         NaN
#
#                                             PurchaseInfluence  \
# ResponseId
# 1           Yes, I influenced the purchase of a substantia...
# 2                                                          No
# 3                                                          No
# 4                                                          No
# 5           Yes, I endorsed a tool that was open-source an...
#
#             TechEndorseIntro  TechEndorse_1  TechEndorse_2  TechEndorse_3  \
# ResponseId
# 1                       Work           10.0            7.0            9.0
# 2           Personal Project           13.0            1.0            2.0
# 3                       Work           12.0            2.0            3.0
# 4           Personal Project            2.0           12.0            6.0
# 5                       Work            6.0            3.0            1.0
#
#             TechEndorse_4  TechEndorse_5  TechEndorse_6  TechEndorse_7  \
# ResponseId
# 1                     6.0            3.0           11.0           12.0
# 2                     9.0            4.0            3.0           12.0
# 3                     7.0            5.0           10.0           13.0
# 4                     5.0           13.0            3.0            8.0
# 5                     9.0           10.0            8.0            7.0
#
#             TechEndorse_8  TechEndorse_9  TechEndorse_13 TechEndorse_13_TEXT  \
# ResponseId
# 1                     1.0            8.0            14.0                 NaN
# 2                     5.0            7.0            14.0                 NaN
# 3                     1.0            4.0            14.0                 NaN
# 4                    11.0            7.0            14.0                 NaN
# 5                     4.0            2.0            14.0                 NaN
#
#             TechOppose_1  TechOppose_2  TechOppose_3  TechOppose_5  \
# ResponseId
# 1                   15.0           7.0           8.0          12.0
# 2                   14.0           1.0          13.0          10.0
# 3                    8.0           1.0           2.0          12.0
# 4                   10.0           5.0           8.0           4.0
# 5                    7.0          13.0           3.0           9.0
#
#             TechOppose_7  TechOppose_9  TechOppose_11  TechOppose_13  \
# ResponseId
# 1                   11.0           1.0            6.0           13.0
# 2                    9.0           3.0            4.0            2.0
# 3                   13.0           3.0            9.0            4.0
# 4                   13.0          12.0            2.0            7.0
# 5                   12.0           6.0            1.0            8.0
#
#             TechOppose_16  TechOppose_15 TechOppose_15_TEXT  \
# ResponseId
# 1                     3.0           16.0                NaN
# 2                     5.0           15.0                NaN
# 3                    11.0           15.0                NaN
# 4                     1.0           15.0                NaN
# 5                    14.0           15.0                NaN
#
#                                 Industry  JobSatPoints_1  JobSatPoints_2  \
# ResponseId
# 1                                Fintech             3.0             1.0
# 2           Retail and Consumer Services            10.0             8.0
# 3                   Software Development             9.0             6.0
# 4           Retail and Consumer Services             1.0             2.0
# 5                   Software Development             9.0             4.0
#
#             JobSatPoints_3  JobSatPoints_4  JobSatPoints_5  JobSatPoints_6  \
# ResponseId
# 1                      4.0             9.0             5.0            10.0
# 2                      3.0             9.0            12.0             1.0
# 3                      7.0            11.0             8.0            12.0
# 4                      4.0             5.0             6.0             7.0
# 5                     11.0            13.0            14.0             8.0
#
#             JobSatPoints_7  JobSatPoints_8  JobSatPoints_9  JobSatPoints_10  \
# ResponseId
# 1                     12.0            11.0             2.0              6.0
# 2                      6.0             2.0            11.0              4.0
# 3                      1.0             5.0             2.0              4.0
# 4                      8.0             9.0            10.0             11.0
# 5                      6.0             5.0             7.0              2.0
#
#             JobSatPoints_11  JobSatPoints_13  JobSatPoints_14  \
# ResponseId
# 1                       7.0             13.0             14.0
# 2                       7.0             13.0             14.0
# 3                       3.0             13.0             14.0
# 4                      12.0             13.0             14.0
# 5                       1.0             12.0             10.0
#
#             JobSatPoints_15  JobSatPoints_16 JobSatPoints_15_TEXT  \
# ResponseId
# 1                      15.0              8.0                  NaN
# 2                      15.0              5.0                  NaN
# 3                      15.0             10.0                  NaN
# 4                      15.0              3.0                  NaN
# 5                      15.0              3.0                  NaN
#
#                 AIThreat                                            NewRole  \
# ResponseId
# 1           I'm not sure  I have neither consider or transitioned into a...
# 2           I'm not sure  I have transitioned into a new career and/or i...
# 3                     No  I have transitioned into a new career and/or i...
# 4                     No  I have neither consider or transitioned into a...
# 5                     No  I have neither consider or transitioned into a...
#
#             ToolCountWork  ToolCountPersonal      Country  \
# ResponseId
# 1                     7.0                3.0      Ukraine
# 2                     6.0                5.0  Netherlands
# 3                     3.0                3.0      Ukraine
# 4                     NaN                NaN      Ukraine
# 5                     4.0                3.0      Ukraine
#
#                             Currency  CompTotal LanguageChoice  \
# ResponseId
# 1                  EUR European Euro    52800.0            Yes
# 2                  EUR European Euro    90000.0            Yes
# 3              UAH Ukrainian hryvnia  2214000.0            Yes
# 4                  EUR European Euro    31200.0            Yes
# 5           USD United States dollar    60000.0            Yes
#
#                                        LanguageHaveWorkedWith  \
# ResponseId
# 1                            Bash/Shell (all shells);Dart;SQL
# 2                                                        Java
# 3                         Dart;HTML/CSS;JavaScript;TypeScript
# 4                                             Java;Kotlin;SQL
# 5           C;C#;C++;Delphi;HTML/CSS;Java;JavaScript;Lua;P...
#
#                               LanguageWantToWorkWith  \
# ResponseId
# 1                                               Dart
# 2                                  Java;Python;Swift
# 3                Dart;HTML/CSS;JavaScript;TypeScript
# 4                                        Java;Kotlin
# 5           C#;Java;JavaScript;Python;SQL;TypeScript
#
#                                      LanguageAdmired LanguagesHaveEntry  \
# ResponseId
# 1                                               Dart                NaN
# 2                                               Java                NaN
# 3                Dart;HTML/CSS;JavaScript;TypeScript                NaN
# 4                                        Java;Kotlin                NaN
# 5           C#;Java;JavaScript;Python;SQL;TypeScript                NaN
#
#            LanguagesWantEntry DatabaseChoice  \
# ResponseId
# 1                         NaN            Yes
# 2                         NaN            Yes
# 3                         NaN            Yes
# 4                         NaN             No
# 5                         NaN            Yes
#
#                                        DatabaseHaveWorkedWith  \
# ResponseId
# 1                                  Cloud Firestore;PostgreSQL
# 2                                            Dynamodb;MongoDB
# 3                                    MongoDB;MySQL;PostgreSQL
# 4                                                         NaN
# 5           Elasticsearch;Microsoft SQL Server;MySQL;Oracl...
#
#                         DatabaseWantToWorkWith  \
# ResponseId
# 1                                          NaN
# 2                             Dynamodb;MongoDB
# 3           Firebase Realtime Database;MongoDB
# 4                                          NaN
# 5              Elasticsearch;Oracle;PostgreSQL
#
#                             DatabaseAdmired DatabaseHaveEntry  \
# ResponseId
# 1                                       NaN               NaN
# 2                          Dynamodb;MongoDB               NaN
# 3                                   MongoDB               NaN
# 4                                       NaN               NaN
# 5           Elasticsearch;Oracle;PostgreSQL               NaN
#
#            DatabaseWantEntry PlatformChoice  \
# ResponseId
# 1                        NaN            Yes
# 2                        NaN            Yes
# 3                        NaN            Yes
# 4                        NaN            Yes
# 5                        NaN            Yes
#
#                                        PlatformHaveWorkedWith  \
# ResponseId
# 1           Amazon Web Services (AWS);Cloudflare;Firebase;...
# 2           Amazon Web Services (AWS);Datadog;Docker;Homeb...
# 3                                   Datadog;Firebase;npm;pnpm
# 4                      Amazon Web Services (AWS);Google Cloud
# 5           Amazon Web Services (AWS);APT;Docker;Make;Mave...
#
#                                        PlatformWantToWorkWith  \
# ResponseId
# 1                                                         NaN
# 2           Amazon Web Services (AWS);Datadog;Docker;Homeb...
# 3            Amazon Web Services (AWS);Firebase;npm;pnpm;Vite
# 4                      Amazon Web Services (AWS);Google Cloud
# 5           Amazon Web Services (AWS);APT;Docker;Maven (bu...
#
#                                               PlatformAdmired  \
# ResponseId
# 1                                                         NaN
# 2           Amazon Web Services (AWS);Datadog;Docker;Homeb...
# 3                                           Firebase;npm;pnpm
# 4                      Amazon Web Services (AWS);Google Cloud
# 5           Amazon Web Services (AWS);APT;Docker;Maven (bu...
#
#            PlatformHaveEntry PlatformWantEntry WebframeChoice  \
# ResponseId
# 1                        NaN               NaN             No
# 2                        NaN               NaN            Yes
# 3                        NaN               NaN            Yes
# 4                        NaN               NaN            Yes
# 5                        NaN               NaN            Yes
#
#                                WebframeHaveWorkedWith  \
# ResponseId
# 1                                                 NaN
# 2                                         Spring Boot
# 3                               Next.js;Node.js;React
# 4                                         Spring Boot
# 5           Angular;ASP.NET;ASP.NET Core;Flask;jQuery
#
#                 WebframeWantToWorkWith             WebframeAdmired  \
# ResponseId
# 1                                  NaN                         NaN
# 2                          Spring Boot                 Spring Boot
# 3                Next.js;Node.js;React       Next.js;Node.js;React
# 4                          Spring Boot                 Spring Boot
# 5           Angular;ASP.NET Core;Flask  Angular;ASP.NET Core;Flask
#
#            WebframeHaveEntry WebframeWantEntry DevEnvsChoice  \
# ResponseId
# 1                        NaN               NaN           Yes
# 2                        NaN               NaN           Yes
# 3                        NaN          Solid.js           Yes
# 4                        NaN               NaN            No
# 5                        NaN               NaN           Yes
#
#                                         DevEnvsHaveWorkedWith  \
# ResponseId
# 1           Android Studio;Notepad++;Visual Studio;Visual ...
# 2              IntelliJ IDEA;PyCharm;Visual Studio Code;Xcode
# 3                                          Visual Studio Code
# 4                                                         NaN
# 5           Eclipse;IntelliJ IDEA;Jupyter Notebook/Jupyter...
#
#                                         DevEnvsWantToWorkWith  \
# ResponseId
# 1                                                         NaN
# 2              IntelliJ IDEA;PyCharm;Visual Studio Code;Xcode
# 3                                 Visual Studio Code;Windsurf
# 4                                                         NaN
# 5           IntelliJ IDEA;Jupyter Notebook/JupyterLab;Note...
#
#                                                DevEnvsAdmired DevEnvHaveEntry  \
# ResponseId
# 1                                                         NaN             NaN
# 2              IntelliJ IDEA;PyCharm;Visual Studio Code;Xcode             NaN
# 3                                          Visual Studio Code             NaN
# 4                                                         NaN             NaN
# 5           IntelliJ IDEA;Jupyter Notebook/JupyterLab;Note...             NaN
#
#            DevEnvWantEntry                SOTagsHaveWorkedWith  \
# ResponseId
# 1                      NaN                                 NaN
# 2                      NaN                                 NaN
# 3                      NaN                       Google Gemini
# 4                      NaN                      Amazon Bedrock
# 5                      NaN  Large Language Model;Google Gemini
#
#                SOTagsWantToWorkWith         SOTagsAdmired SOTagsHaveEntry  \
# ResponseId
# 1                               NaN                   NaN             NaN
# 2                               NaN                   NaN             NaN
# 3           Google Gemini;Shadcn/ui         Google Gemini             NaN
# 4                               NaN                   NaN             NaN
# 5              Large Language Model  Large Language Model             NaN
#
#            SOTagsWant Entry         OpSysPersonal use  \
# ResponseId
# 1                       NaN     Windows;MacOS;Android
# 2                       NaN  Windows;MacOS;iOS;iPadOS
# 3                       NaN             MacOS;Android
# 4                       NaN                   Windows
# 5                       NaN               Windows;iOS
#
#                        OpSysProfessional use  \
# ResponseId
# 1           Windows;MacOS;Android;iOS;iPadOS
# 2                                      MacOS
# 3                                      MacOS
# 4                             Windows;Ubuntu
# 5                      Windows;Ubuntu;Debian
#
#                          OfficeStackAsyncHaveWorkedWith  \
# ResponseId
# 1           Confluence;GitHub;GitLab;Jira;Markdown File
# 2                                Confluence;GitHub;Jira
# 3                                    GitHub;GitLab;Jira
# 4                                      GitLab;Jira;Miro
# 5                              Azure Devops;GitHub;Jira
#
#            OfficeStackAsyncWantToWorkWith   OfficeStackAsyncAdmired  \
# ResponseId
# 1                           Markdown File             Markdown File
# 2                  Confluence;GitHub;Jira    Confluence;GitHub;Jira
# 3                      GitHub;GitLab;Jira        GitHub;GitLab;Jira
# 4                             GitLab;Jira               GitLab;Jira
# 5                Azure Devops;GitHub;Jira  Azure Devops;GitHub;Jira
#
#            OfficeStackHaveEntry OfficeStackWantEntry  \
# ResponseId
# 1                           NaN                  NaN
# 2                           NaN                  NaN
# 3                           NaN                  NaN
# 4                           NaN                  NaN
# 5                           NaN                  NaN
#
#                                    CommPlatformHaveWorkedWith  \
# ResponseId
# 1           Stack Overflow;Reddit;GitHub (public projects,...
# 2           Stack Overflow;Discord;Reddit;Dev.to;Hacker Ne...
# 3            Stack Overflow;Discord;Dev.to;X;YouTube;LinkedIn
# 4                      Stack Overflow;Reddit;YouTube;LinkedIn
# 5           Stack Overflow;Stack Exchange;GitHub (public p...
#
#                                    CommPlatformWantToWorkWith  \
# ResponseId
# 1                                                         NaN
# 2           Stack Overflow;Discord;Reddit;Dev.to;Hacker Ne...
# 3            Stack Overflow;Discord;Dev.to;X;YouTube;LinkedIn
# 4           Stack Overflow;Reddit;GitHub (public projects,...
# 5           Stack Overflow;Stack Exchange;GitHub (public p...
#
#                                           CommPlatformAdmired  \
# ResponseId
# 1                                                         NaN
# 2           Stack Overflow;Discord;Reddit;Dev.to;Hacker Ne...
# 3            Stack Overflow;Discord;Dev.to;X;YouTube;LinkedIn
# 4                      Stack Overflow;Reddit;YouTube;LinkedIn
# 5           Stack Overflow;Stack Exchange;GitHub (public p...
#
#            CommPlatformHaveEntr CommPlatformWantEntr AIModelsChoice  \
# ResponseId
# 1                           NaN                  NaN            Yes
# 2                           NaN                  NaN            Yes
# 3                           NaN                  NaN            Yes
# 4                           NaN                  NaN             No
# 5                           NaN                  NaN            Yes
#
#                                        AIModelsHaveWorkedWith  \
# ResponseId
# 1           openAI GPT (chatbot models);openAI Image gener...
# 2                                 openAI GPT (chatbot models)
# 3           Gemini (Flash general purpose models);openAI G...
# 4                                                         NaN
# 5                                 openAI GPT (chatbot models)
#
#                                        AIModelsWantToWorkWith  \
# ResponseId
# 1                                                         NaN
# 2                                 openAI GPT (chatbot models)
# 3           Gemini (Flash general purpose models);Gemini (...
# 4                                                         NaN
# 5                                 openAI GPT (chatbot models)
#
#                                               AIModelsAdmired  \
# ResponseId
# 1                                                         NaN
# 2                                 openAI GPT (chatbot models)
# 3           Gemini (Flash general purpose models);openAI G...
# 4                                                         NaN
# 5                                 openAI GPT (chatbot models)
#
#            AIModelsHaveEntry AIModelsWantEntry                SOAccount  \
# ResponseId
# 1                        NaN               NaN                      Yes
# 2                        NaN               NaN  Not sure/can't remember
# 3                        NaN               NaN  Not sure/can't remember
# 4                        NaN               NaN                      Yes
# 5                        NaN               NaN                       No
#
#                                 SOVisitFreq               SODuration  \
# ResponseId
# 1                      A few times per week   Between 5 and 10 years
# 2                    Multiple times per day  Between 10 and 15 years
# 3                      A few times per week   Between 5 and 10 years
# 4           A few times per month or weekly    Between 3 and 5 years
# 5           A few times per month or weekly   Between 5 and 10 years
#
#                                                    SOPartFreq  \
# ResponseId
# 1           I have never participated in Q&A on Stack Over...
# 2                       Infrequently, less than once per year
# 3                       Infrequently, less than once per year
# 4           I have never participated in Q&A on Stack Over...
# 5                       Infrequently, less than once per year
#
#                                                SO_Dev_Content  SO_Actions_1  \
# ResponseId
# 1                                                         NaN           1.0
# 2           Chat (people);Message Boards;Long-form article...           6.0
# 3           Chat (people);Videos;Lists of recommendations ...           3.0
# 4                                        Videos;Chat (bot/AI)           1.0
# 5                                          Long-form articles           1.0
#
#             SO_Actions_16  SO_Actions_3  SO_Actions_4  SO_Actions_5  \
# ResponseId
# 1                     NaN           6.0           2.0           3.0
# 2                     NaN           5.0           8.0           2.0
# 3                     NaN           4.0           5.0           1.0
# 4                     NaN           4.0           5.0           6.0
# 5                     NaN           7.0           4.0           2.0
#
#             SO_Actions_6  SO_Actions_9  SO_Actions_7  SO_Actions_10  \
# ResponseId
# 1                    7.0           8.0           9.0           11.0
# 2                    4.0           9.0          10.0           11.0
# 3                    2.0           7.0           9.0           11.0
# 4                    7.0           8.0           9.0           11.0
# 5                    5.0          10.0           6.0           12.0
#
#             SO_Actions_15 SO_Actions_15_TEXT          SOComm  \
# ResponseId
# 1                    15.0                NaN         Neutral
# 2                    15.0                NaN   Yes, somewhat
# 3                    15.0                NaN         Neutral
# 4                    15.0                NaN         Neutral
# 5                    15.0                NaN  No, not really
#
#                         SOFriction  \
# ResponseId
# 1             Rarely, almost never
# 2           About half of the time
# 3           About half of the time
# 4             Rarely, almost never
# 5             Rarely, almost never
#
#                                                AISelect       AISent  \
# ResponseId
# 1           Yes, I use AI tools monthly or infrequently  Indifferent
# 2                            Yes, I use AI tools weekly  Indifferent
# 3                             Yes, I use AI tools daily    Favorable
# 4                            Yes, I use AI tools weekly    Favorable
# 5                            Yes, I use AI tools weekly    Favorable
#
#                                  AIAcc  \
# ResponseId
# 1           Neither trust nor distrust
# 2           Neither trust nor distrust
# 3                       Somewhat trust
# 4                       Somewhat trust
# 5           Neither trust nor distrust
#
#                                                 AIComplex  \
# ResponseId
# 1                           Bad at handling complex tasks
# 2                           Bad at handling complex tasks
# 3           Neither good or bad at handling complex tasks
# 4                           Bad at handling complex tasks
# 5           Good, but not great at handling complex tasks
#
#                                  AIToolCurrently partially AI  \
# ResponseId
# 1           Learning about a codebase;Writing code;Search ...
# 2                       Learning new concepts or technologies
# 3           Documenting code;Debugging or fixing code;Test...
# 4                                                         NaN
# 5           Learning about a codebase;Writing code;Debuggi...
#
#                      AIToolDon't plan to use AI for this task  \
# ResponseId
# 1           Project planning;Deployment and monitoring;Lea...
# 2           Learning about a codebase;Project planning;Com...
# 3                                                         NaN
# 4           Project planning;Documenting code;Testing code...
# 5           Project planning;Documenting code;Testing code...
#
#                                AIToolPlan to partially use AI  \
# ResponseId
# 1           Documenting code;Debugging or fixing code;Test...
# 2           Writing code;Documenting code;Debugging or fix...
# 3           Project planning;Committing and reviewing code...
# 4           Learning about a codebase;Writing code;Debuggi...
# 5                        Generating content or synthetic data
#
#                                   AIToolPlan to mostly use AI  \
# ResponseId
# 1                                                         NaN
# 2                                                         NaN
# 3           Learning about a codebase;Writing code;Generat...
# 4           Search for answers;Generating content or synth...
# 5                                                         NaN
#
#            AIToolCurrently mostly AI  \
# ResponseId
# 1                                NaN
# 2                                NaN
# 3                                NaN
# 4                                NaN
# 5                                NaN
#
#                                                 AIFrustration AIExplain  \
# ResponseId
# 1           AI solutions that are almost right, but not quite        No
# 2           AI solutions that are almost right, but not qu...        No
# 3           AI solutions that are almost right, but not qu...        No
# 4           AI solutions that are almost right, but not qu...        NO
# 5           AI solutions that are almost right, but not quite    partly
#
#                                                      AIAgents  \
# ResponseId
# 1           Yes, I use AI agents at work monthly or infreq...
# 2                                     No, and I don't plan to
# 3                         Yes, I use AI agents at work weekly
# 4           Yes, I use AI agents at work monthly or infreq...
# 5                                     No, and I don't plan to
#
#                       AIAgentChange          AIAgent_Uses  \
# ResponseId
# 1           Not at all or minimally  Software engineering
# 2           Not at all or minimally                   NaN
# 3                     Yes, somewhat  Software engineering
# 4           Not at all or minimally  Software engineering
# 5            Yes, to a great extent                   NaN
#
#                             AgentUsesGeneral  \
# ResponseId
# 1                                        NaN
# 2                                        NaN
# 3           Multi-platform search enablement
# 4                        Language processing
# 5                                        NaN
#
#                                   AIAgentImpactSomewhat agree  \
# ResponseId
# 1           AI agents have increased my productivity.;AI a...
# 2                                                         NaN
# 3           AI agents have increased my productivity.;AI a...
# 4           AI agents have accelerated my learning about n...
# 5                                                         NaN
#
#                                          AIAgentImpactNeutral  \
# ResponseId
# 1           AI agents have helped me automate repetitive t...
# 2                                                         NaN
# 3           AI agents have improved the quality of my code...
# 4           AI agents have increased my productivity.;AI a...
# 5                                                         NaN
#
#                                AIAgentImpactSomewhat disagree  \
# ResponseId
# 1                                                         NaN
# 2                                                         NaN
# 3           AI agents have improved collaboration within m...
# 4           AI agents have helped me automate repetitive t...
# 5                                                         NaN
#
#            AIAgentImpactStrongly agree AIAgentImpactStrongly disagree  \
# ResponseId
# 1                                  NaN                            NaN
# 2                                  NaN                            NaN
# 3                                  NaN                            NaN
# 4                                  NaN                            NaN
# 5                                  NaN                            NaN
#
#                                      AIAgentChallengesNeutral  \
# ResponseId
# 1           I am concerned about the accuracy of the infor...
# 2           It takes significant time and effort to learn ...
# 3           It takes significant time and effort to learn ...
# 4           It takes significant time and effort to learn ...
# 5           Integrating AI agents with my existing tools a...
#
#                            AIAgentChallengesSomewhat disagree  \
# ResponseId
# 1           Integrating AI agents with my existing tools a...
# 2                                                         NaN
# 3           My company's IT and/or InfoSec teams have stri...
# 4                                                         NaN
# 5                                                         NaN
#
#                               AIAgentChallengesStrongly agree  \
# ResponseId
# 1           The cost of using certain AI agent platforms i...
# 2           I am concerned about the accuracy of the infor...
# 3                                                         NaN
# 4           I am concerned about the accuracy of the infor...
# 5           I am concerned about the accuracy of the infor...
#
#                               AIAgentChallengesSomewhat agree  \
# ResponseId
# 1                                                         NaN
# 2           Integrating AI agents with my existing tools a...
# 3           I am concerned about the accuracy of the infor...
# 4           Integrating AI agents with my existing tools a...
# 5           It takes significant time and effort to learn ...
#
#            AIAgentChallengesStrongly disagree AIAgentKnowledge  \
# ResponseId
# 1                                         NaN              NaN
# 2                                         NaN              NaN
# 3                                         NaN            Redis
# 4                                         NaN              NaN
# 5                                         NaN              NaN
#
#            AIAgentKnowWrite AIAgentOrchestration AIAgentOrchWrite  \
# ResponseId
# 1                       NaN            Vertex AI              NaN
# 2                       NaN                  NaN              NaN
# 3                       NaN                  NaN              NaN
# 4                       NaN                  NaN              NaN
# 5                       NaN                  NaN              NaN
#
#            AIAgentObserveSecure AIAgentObsWrite  \
# ResponseId
# 1                           NaN             NaN
# 2                           NaN             NaN
# 3                           NaN             NaN
# 4                           NaN             NaN
# 5                           NaN             NaN
#
#                                              AIAgentExternal AIAgentExtWrite  \
# ResponseId
# 1                                                    ChatGPT             NaN
# 2                                                        NaN             NaN
# 3           ChatGPT;Claude Code;GitHub Copilot;Google Gemini             NaN
# 4                                        ChatGPT;Claude Code             NaN
# 5                                                        NaN             NaN
#
#                                                       AIHuman  \
# ResponseId
# 1                             When I don’t trust AI’s answers
# 2           When I don’t trust AI’s answers;When I want to...
# 3           When I don’t trust AI’s answers;When I want to...
# 4           When I don’t trust AI’s answers;When I want to...
# 5                             When I don’t trust AI’s answers
#
#                                                        AIOpen  \
# ResponseId
# 1                       Troubleshooting, profiling, debugging
# 2                                   All skills. AI is a flop.
# 3           Understand how things actually work, problem s...
# 4                                                         NaN
# 5           critical thinking, the skill to define the tas...
#
#             ConvertedCompYearly  JobSat
# ResponseId
# 1                       61256.0    10.0
# 2                      104413.0     9.0
# 3                       53061.0     8.0
# 4                       36197.0     6.0
# 5                       60000.0     7.0

# %%
df["LanguageChoice"].value_counts()
# Out:
# LanguageChoice
# Yes    31553
# No       661
# Name: count, dtype: int64

# %%
pd.set_option('display.max_rows', None)
schema_df
# Out:
#                          qid  \
# qname
# TechEndorse_1          QID18
# TechEndorse_2          QID18
# TechEndorse_3          QID18
# TechEndorse_4          QID18
# TechEndorse_5          QID18
# TechEndorse_6          QID18
# TechEndorse_7          QID18
# TechEndorse_8          QID18
# TechEndorse_9          QID18
# TechEndorse_13         QID18
# TechEndorse_13_TEXT    QID18
# TechOppose_1           QID19
# TechOppose_2           QID19
# TechOppose_3           QID19
# TechOppose_5           QID19
# TechOppose_7           QID19
# TechOppose_9           QID19
# TechOppose_11          QID19
# TechOppose_13          QID19
# TechOppose_16          QID19
# TechOppose_15          QID19
# TechOppose_15_TEXT     QID19
# JobSatPoints_1         QID27
# JobSatPoints_2         QID27
# JobSatPoints_16        QID27
# JobSatPoints_3         QID27
# JobSatPoints_4         QID27
# JobSatPoints_5         QID27
# JobSatPoints_6         QID27
# JobSatPoints_7         QID27
# JobSatPoints_8         QID27
# JobSatPoints_9         QID27
# JobSatPoints_10        QID27
# JobSatPoints_11        QID27
# JobSatPoints_13        QID27
# JobSatPoints_14        QID27
# JobSatPoints_15        QID27
# JobSatPoints_15_TEXT   QID27
# SO_Actions_1           QID76
# SO_Actions_16          QID76
# SO_Actions_3           QID76
# SO_Actions_4           QID76
# SO_Actions_5           QID76
# SO_Actions_6           QID76
# SO_Actions_9           QID76
# SO_Actions_7           QID76
# SO_Actions_10          QID76
# SO_Actions_15          QID76
# SO_Actions_15_TEXT     QID76
# MainBranch              QID3
# Age                     QID4
# EdLevel                 QID9
# Employment              QID7
# EmploymentAddl          QID8
# WorkExp                QID14
# LearnCodeChoose        QID10
# LearnCode              QID11
# LearnCodeAI            QID12
# AILearnHow             QID32
# YearsCode              QID13
# DevType                QID15
# OrgSize                QID16
# ICorPM                 QID23
# RemoteWork             QID24
# PurchaseInfluence      QID17
# TechEndorseIntro       QID33
# Industry               QID25
# JobSat                 QID26
# AIThreat               QID28
# NewRole                QID29
# ToolCountWork          QID30
# ToolCountPersonal      QID31
# Country                QID20
# Currency               QID21
# CompTotal              QID22
# LanguageChoice         QID44
# Language               QID34
# LanguagesHaveEntry     QID51
# LanguagesWantEntry     QID52
# DatabaseChoice         QID45
# Database               QID35
# DatabaseHaveEntry      QID54
# DatabaseWantEntry      QID55
# PlatformChoice         QID46
# Platform               QID36
# PlatformHaveEntry      QID56
# PlatformWantEntry      QID57
# WebframeChoice         QID47
# Webframe               QID37
# WebframeHaveEntry      QID58
# WebframeWantEntry      QID59
# DevEnvsChoice          QID48
# DevEnvs                QID38
# DevEnvHaveEntry        QID60
# DevEnvWantEntry        QID61
# SOTags                 QID39
# SOTagsHaveEntry        QID62
# SOTagsWant Entry       QID63
# OpSys                  QID40
# OfficeStackAsync       QID41
# OfficeStackHaveEntry   QID64
# OfficeStackWantEntry   QID65
# CommPlatform           QID42
# CommPlatformHaveEntr   QID66
# CommPlatformWantEntr   QID67
# AIModelsChoice         QID50
# AIModels               QID43
# AIModelsHaveEntry      QID68
# AIModelsWantEntry      QID69
# SOAccount              QID72
# SOVisitFreq            QID70
# SODuration             QID71
# SOPartFreq             QID73
# SO_Dev_Content         QID75
# SOComm                 QID77
# SOFriction             QID97
# AISelect               QID78
# AISent                 QID79
# AIAcc                  QID80
# AIComplex              QID81
# AITool                 QID82
# AIFrustration          QID99
# AIExplain              QID84
# AIAgents               QID85
# AIAgentChange          QID83
# AIAgent_Uses           QID86
# AgentUsesGeneral      QID106
# AIAgentImpact          QID87
# AIAgentChallenges      QID88
# AIAgentKnowledge       QID89
# AIAgentKnowWrite      QID107
# AIAgentOrchestration   QID90
# AIAgentOrchWrite      QID102
# AIAgentObserveSecure   QID91
# AIAgentObsWrite       QID103
# AIAgentExternal        QID92
# AIAgentExtWrite       QID104
# AIHuman               QID100
# AIOpen                 QID93
#
#                                                                question  \
# qname
# TechEndorse_1         What attracts you to a technology or causes yo...
# TechEndorse_2         What attracts you to a technology or causes yo...
# TechEndorse_3         What attracts you to a technology or causes yo...
# TechEndorse_4         What attracts you to a technology or causes yo...
# TechEndorse_5         What attracts you to a technology or causes yo...
# TechEndorse_6         What attracts you to a technology or causes yo...
# TechEndorse_7         What attracts you to a technology or causes yo...
# TechEndorse_8         What attracts you to a technology or causes yo...
# TechEndorse_9         What attracts you to a technology or causes yo...
# TechEndorse_13        What attracts you to a technology or causes yo...
# TechEndorse_13_TEXT   What attracts you to a technology or causes yo...
# TechOppose_1          What would turn you off or cause you to reject...
# TechOppose_2          What would turn you off or cause you to reject...
# TechOppose_3          What would turn you off or cause you to reject...
# TechOppose_5          What would turn you off or cause you to reject...
# TechOppose_7          What would turn you off or cause you to reject...
# TechOppose_9          What would turn you off or cause you to reject...
# TechOppose_11         What would turn you off or cause you to reject...
# TechOppose_13         What would turn you off or cause you to reject...
# TechOppose_16         What would turn you off or cause you to reject...
# TechOppose_15         What would turn you off or cause you to reject...
# TechOppose_15_TEXT    What would turn you off or cause you to reject...
# JobSatPoints_1        Rank the following attributes of your current ...
# JobSatPoints_2        Rank the following attributes of your current ...
# JobSatPoints_16       Rank the following attributes of your current ...
# JobSatPoints_3        Rank the following attributes of your current ...
# JobSatPoints_4        Rank the following attributes of your current ...
# JobSatPoints_5        Rank the following attributes of your current ...
# JobSatPoints_6        Rank the following attributes of your current ...
# JobSatPoints_7        Rank the following attributes of your current ...
# JobSatPoints_8        Rank the following attributes of your current ...
# JobSatPoints_9        Rank the following attributes of your current ...
# JobSatPoints_10       Rank the following attributes of your current ...
# JobSatPoints_11       Rank the following attributes of your current ...
# JobSatPoints_13       Rank the following attributes of your current ...
# JobSatPoints_14       Rank the following attributes of your current ...
# JobSatPoints_15       Rank the following attributes of your current ...
# JobSatPoints_15_TEXT  Rank the following attributes of your current ...
# SO_Actions_1          When visiting Stack Overflow, which following ...
# SO_Actions_16         When visiting Stack Overflow, which following ...
# SO_Actions_3          When visiting Stack Overflow, which following ...
# SO_Actions_4          When visiting Stack Overflow, which following ...
# SO_Actions_5          When visiting Stack Overflow, which following ...
# SO_Actions_6          When visiting Stack Overflow, which following ...
# SO_Actions_9          When visiting Stack Overflow, which following ...
# SO_Actions_7          When visiting Stack Overflow, which following ...
# SO_Actions_10         When visiting Stack Overflow, which following ...
# SO_Actions_15         When visiting Stack Overflow, which following ...
# SO_Actions_15_TEXT    When visiting Stack Overflow, which following ...
# MainBranch            Are you someone who writes code? Please select...
# Age                                                   What is your age?
# EdLevel               Which of the following best describes the high...
# Employment            Which of the following best describes your cur...
# EmploymentAddl        Which of the following <strong>additional</str...
# WorkExp               How many years of professional work experience...
# LearnCodeChoose       Did you begin learning to code or learn a new ...
# LearnCode             How did you learn to code in the past year? Se...
# LearnCodeAI           Did you spend time in the last year learning A...
# AILearnHow            How did you learn to code for AI in the past y...
# YearsCode             Including any education, how many years have y...
# DevType               Which of the following describes your current ...
# OrgSize               Approximately how many people are employed by ...
# ICorPM                Are you an individual contributor or people ma...
# RemoteWork            Which best describes your current work situation?
# PurchaseInfluence     Have you <strong>influenced or endorsed</stron...
# TechEndorseIntro      When you&rsquo;re in a position to <strong>inf...
# Industry                              What industry do you work for in?
# JobSat                How satisfied are you in your current professi...
# AIThreat              Do you believe AI is a threat to your current ...
# NewRole               Have you considered a career change or transit...
# ToolCountWork         For your <b>primary work role</b> (student, de...
# ToolCountPersonal     <b></b>For your <b>side projects or other pers...
# Country                                              Where do you live?
# Currency              Which currency do you use day-to-day? If your ...
# CompTotal             What is your current total <b>annual</b> compe...
# LanguageChoice        Did you work with programming, scripting and m...
# Language              Which <b>programming, scripting, and markup la...
# LanguagesHaveEntry    Was the programming language you use not liste...
# LanguagesWantEntry    Was the programming language you want to use n...
# DatabaseChoice        Did you work with database environments in the...
# Database              Which <b>database environments </b>have you do...
# DatabaseHaveEntry     Was the database environment you use not liste...
# DatabaseWantEntry     Was the database environment you want to use n...
# PlatformChoice        Did you work with cloud platforms, containeriz...
# Platform              Which <b>cloud platforms, containerization/orc...
# PlatformHaveEntry     Was the cloud platforms, containerization/orch...
# PlatformWantEntry     Was the cloud platforms, containerization/orch...
# WebframeChoice        Did you work with web frameworks and web techn...
# Webframe              Which <b>web frameworks and web technologies</...
# WebframeHaveEntry     Were the web frameworks and web technologies y...
# WebframeWantEntry     Were the web frameworks and web technologies y...
# DevEnvsChoice         Did you work with development environments or ...
# DevEnvs               Which <strong>development environments and AI-...
# DevEnvHaveEntry       Was the developer environment or AI-enabled co...
# DevEnvWantEntry       Was the developer environment or AI-enabled co...
# SOTags                Which rising technology of the added as <b>new...
# SOTagsHaveEntry       Was the new tag on Stack Overflow (i.e. added ...
# SOTagsWant Entry      Was the new tag on Stack Overflow (i.e. added ...
# OpSys                 What is the primary <b>operating system</b> in...
# OfficeStackAsync      Which <b>collaborative work management and/or ...
# OfficeStackHaveEntry  Was the collaborative work management and/or c...
# OfficeStackWantEntry  Was the collaborative work management and/or c...
# CommPlatform          Which <b>community platforms</b> have you util...
# CommPlatformHaveEntr  Was the community platform you use not listed ...
# CommPlatformWantEntr  Was the community platform you want to use not...
# AIModelsChoice        Did you utilize or integrate specific Large La...
# AIModels              Which <b>LLM models for AI tools</b> have you ...
# AIModelsHaveEntry     Was the LLM model for AI tools you use not lis...
# AIModelsWantEntry     Was the LLM model for AI tools you want to use...
# SOAccount                         Do you have a Stack Overflow account?
# SOVisitFreq           How frequently would you say you visit Stack O...
# SODuration                       How long have you used Stack Overflow?
# SOPartFreq            How frequently would you say you participate i...
# SO_Dev_Content        Whether it be to solve a problem, for career g...
# SOComm                Do you consider yourself a member of the Stack...
# SOFriction            When you visit Stack Overflow, how often is it...
# AISelect              Do you currently use AI tools in your developm...
# AISent                How favorable is your stance on using AI tools...
# AIAcc                 How much do you trust the accuracy of the outp...
# AIComplex             How well do the AI tools you use in your devel...
# AITool                Which parts of your development workflow are y...
# AIFrustration         When using AI tools, which of the following pr...
# AIExplain             In your own words, is &quot;vibe coding&quot; ...
# AIAgents              Are you using AI agents in your work (developm...
# AIAgentChange         Have AI tools or AI agents changed how you com...
# AIAgent_Uses          What industry purposes or specific tasks are y...
# AgentUsesGeneral
# AIAgentImpact         To what extent do you agree with the following...
# AIAgentChallenges     To what extent do you agree with the following...
# AIAgentKnowledge      You indicated you use or develop AI agents as ...
# AIAgentKnowWrite      Was the tool or tools for AI agent orchestrati...
# AIAgentOrchestration  You indicated you use or develop AI agents as ...
# AIAgentOrchWrite      Was the tool or tools for AI agent orchestrati...
# AIAgentObserveSecure  You indicated you use or develop AI agents as ...
# AIAgentObsWrite       Was the tool or tools for AI agent observabili...
# AIAgentExternal       You indicated you use or develop AI agents as ...
# AIAgentExtWrite       Was the out-of-the-box agents, copilots or ass...
# AIHuman               In the future, if AI can do most coding tasks,...
# AIOpen                Looking ahead 3–5 years, what skills do you be...
#
#                         type  \
# qname
# TechEndorse_1             RO
# TechEndorse_2             RO
# TechEndorse_3             RO
# TechEndorse_4             RO
# TechEndorse_5             RO
# TechEndorse_6             RO
# TechEndorse_7             RO
# TechEndorse_8             RO
# TechEndorse_9             RO
# TechEndorse_13            RO
# TechEndorse_13_TEXT       RO
# TechOppose_1              RO
# TechOppose_2              RO
# TechOppose_3              RO
# TechOppose_5              RO
# TechOppose_7              RO
# TechOppose_9              RO
# TechOppose_11             RO
# TechOppose_13             RO
# TechOppose_16             RO
# TechOppose_15             RO
# TechOppose_15_TEXT        RO
# JobSatPoints_1            RO
# JobSatPoints_2            RO
# JobSatPoints_16           RO
# JobSatPoints_3            RO
# JobSatPoints_4            RO
# JobSatPoints_5            RO
# JobSatPoints_6            RO
# JobSatPoints_7            RO
# JobSatPoints_8            RO
# JobSatPoints_9            RO
# JobSatPoints_10           RO
# JobSatPoints_11           RO
# JobSatPoints_13           RO
# JobSatPoints_14           RO
# JobSatPoints_15           RO
# JobSatPoints_15_TEXT      RO
# SO_Actions_1              RO
# SO_Actions_16             RO
# SO_Actions_3              RO
# SO_Actions_4              RO
# SO_Actions_5              RO
# SO_Actions_6              RO
# SO_Actions_9              RO
# SO_Actions_7              RO
# SO_Actions_10             RO
# SO_Actions_15             RO
# SO_Actions_15_TEXT        RO
# MainBranch                MC
# Age                       MC
# EdLevel                   MC
# Employment                MC
# EmploymentAddl            MC
# WorkExp                   TE
# LearnCodeChoose           MC
# LearnCode                 MC
# LearnCodeAI               MC
# AILearnHow                MC
# YearsCode                 TE
# DevType                   MC
# OrgSize                   MC
# ICorPM                    MC
# RemoteWork                MC
# PurchaseInfluence         MC
# TechEndorseIntro          MC
# Industry                  MC
# JobSat                    MC
# AIThreat                  MC
# NewRole                   MC
# ToolCountWork             TE
# ToolCountPersonal         TE
# Country                   MC
# Currency                  MC
# CompTotal                 TE
# LanguageChoice            MC
# Language              Matrix
# LanguagesHaveEntry        TE
# LanguagesWantEntry        TE
# DatabaseChoice            MC
# Database              Matrix
# DatabaseHaveEntry         TE
# DatabaseWantEntry         TE
# PlatformChoice            MC
# Platform              Matrix
# PlatformHaveEntry         TE
# PlatformWantEntry         TE
# WebframeChoice            MC
# Webframe              Matrix
# WebframeHaveEntry         TE
# WebframeWantEntry         TE
# DevEnvsChoice             MC
# DevEnvs               Matrix
# DevEnvHaveEntry           TE
# DevEnvWantEntry           TE
# SOTags                Matrix
# SOTagsHaveEntry           TE
# SOTagsWant Entry          TE
# OpSys                 Matrix
# OfficeStackAsync      Matrix
# OfficeStackHaveEntry      TE
# OfficeStackWantEntry      TE
# CommPlatform          Matrix
# CommPlatformHaveEntr      TE
# CommPlatformWantEntr      TE
# AIModelsChoice            MC
# AIModels              Matrix
# AIModelsHaveEntry         TE
# AIModelsWantEntry         TE
# SOAccount                 MC
# SOVisitFreq               MC
# SODuration                MC
# SOPartFreq                MC
# SO_Dev_Content            MC
# SOComm                    MC
# SOFriction                MC
# AISelect                  MC
# AISent                    MC
# AIAcc                     MC
# AIComplex                 MC
# AITool                Matrix
# AIFrustration             MC
# AIExplain                 TE
# AIAgents                  MC
# AIAgentChange             MC
# AIAgent_Uses              MC
# AgentUsesGeneral          MC
# AIAgentImpact         Matrix
# AIAgentChallenges     Matrix
# AIAgentKnowledge          MC
# AIAgentKnowWrite          TE
# AIAgentOrchestration      MC
# AIAgentOrchWrite          TE
# AIAgentObserveSecure      MC
# AIAgentObsWrite           TE
# AIAgentExternal           MC
# AIAgentExtWrite           TE
# AIHuman                   MC
# AIOpen                    TE
#
#                                                                     sub  sq_id
# qname
# TechEndorse_1                   AI integration or AI Agent capabilities    1.0
# TechEndorse_2                                           Easy-to-use API    2.0
# TechEndorse_3                                   Robust and complete API    3.0
# TechEndorse_4                      Customizable and manageable codebase    4.0
# TechEndorse_5                                    Reputation for quality    5.0
# TechEndorse_6                       Connected to an open-source project    6.0
# TechEndorse_7                               Good brand and public image    7.0
# TechEndorse_8                               Reliability and low latency    8.0
# TechEndorse_9                                      Costs are manageable    9.0
# TechEndorse_13                                  Other (please specify):   10.0
# TechEndorse_13_TEXT                      Other (please specify): - Text   13.0
# TechOppose_1                                    Lack of AI or AI agents    1.0
# TechOppose_2                                             Poor usability    2.0
# TechOppose_3                                     Lack of or sub-par API    3.0
# TechOppose_5                                 Inefficient or time-costly    4.0
# TechOppose_7                                        Prohibitive pricing    5.0
# TechOppose_9                               Security or privacy concerns    6.0
# TechOppose_11                       Availability of better alternatives    7.0
# TechOppose_13               Outdated or obsolete technology or features    8.0
# TechOppose_16                                          Ethical concerns    9.0
# TechOppose_15                                   Other (please specify):   10.0
# TechOppose_15_TEXT                       Other (please specify): - Text   15.0
# JobSatPoints_1            Control over the level of quality in projects    1.0
# JobSatPoints_2              Autonomy and trust to manage your own tasks    2.0
# JobSatPoints_16                                   You like your manager    3.0
# JobSatPoints_3                    Collaboration and support from a team    4.0
# JobSatPoints_4                                           Expert mentors    5.0
# JobSatPoints_5        Opportunities to mentor and lead junior-level ...    6.0
# JobSatPoints_6                         Developing specialized expertise    7.0
# JobSatPoints_7                              Solving real-world problems    8.0
# JobSatPoints_8        Job stability and career growth with a single ...    9.0
# JobSatPoints_9        Innovation through solving challenging and com...   10.0
# JobSatPoints_10                 Working with new technologies and tools   11.0
# JobSatPoints_11                            Competitive pay and benefits   12.0
# JobSatPoints_13                    Recognition from peers for your work   13.0
# JobSatPoints_14               Recognition from leadership for your work   14.0
# JobSatPoints_15                                 Other (please specify):   15.0
# JobSatPoints_15_TEXT                     Other (please specify): - Text   15.0
# SO_Actions_1          Browse content related to Q&A posts I recently...    1.0
# SO_Actions_16         Read and/or vote on comments for a Question or...    2.0
# SO_Actions_3                            Bookmark posts to look at later    3.0
# SO_Actions_4          Directly open a Q&A post via search, documenta...    4.0
# SO_Actions_5                                             Ask a question    5.0
# SO_Actions_6                                          Answer a question    6.0
# SO_Actions_9                                       Comment on Q&A posts    7.0
# SO_Actions_7                                  Upvote/Downvote Q&A posts    8.0
# SO_Actions_10                            Use discussion or chat feature    9.0
# SO_Actions_15                                         Other (write in):   10.0
# SO_Actions_15_TEXT                             Other (write in): - Text   15.0
# MainBranch                                                          NaN    NaN
# Age                                                                 NaN    NaN
# EdLevel                                                             NaN    NaN
# Employment                                                          NaN    NaN
# EmploymentAddl                                                      NaN    NaN
# WorkExp                                                             NaN    NaN
# LearnCodeChoose                                                     NaN    NaN
# LearnCode                                                           NaN    NaN
# LearnCodeAI                                                         NaN    NaN
# AILearnHow                                                          NaN    NaN
# YearsCode                                                           NaN    NaN
# DevType                                                             NaN    NaN
# OrgSize                                                             NaN    NaN
# ICorPM                                                              NaN    NaN
# RemoteWork                                                          NaN    NaN
# PurchaseInfluence                                                   NaN    NaN
# TechEndorseIntro                                                    NaN    NaN
# Industry                                                            NaN    NaN
# JobSat                                                              NaN    NaN
# AIThreat                                                            NaN    NaN
# NewRole                                                             NaN    NaN
# ToolCountWork                                                       NaN    NaN
# ToolCountPersonal                                                   NaN    NaN
# Country                                                             NaN    NaN
# Currency                                                            NaN    NaN
# CompTotal                                                           NaN    NaN
# LanguageChoice                                                      NaN    NaN
# Language                                                            NaN    NaN
# LanguagesHaveEntry                                                  NaN    NaN
# LanguagesWantEntry                                                  NaN    NaN
# DatabaseChoice                                                      NaN    NaN
# Database                                                            NaN    NaN
# DatabaseHaveEntry                                                   NaN    NaN
# DatabaseWantEntry                                                   NaN    NaN
# PlatformChoice                                                      NaN    NaN
# Platform                                                            NaN    NaN
# PlatformHaveEntry                                                   NaN    NaN
# PlatformWantEntry                                                   NaN    NaN
# WebframeChoice                                                      NaN    NaN
# Webframe                                                            NaN    NaN
# WebframeHaveEntry                                                   NaN    NaN
# WebframeWantEntry                                                   NaN    NaN
# DevEnvsChoice                                                       NaN    NaN
# DevEnvs                                                             NaN    NaN
# DevEnvHaveEntry                                                     NaN    NaN
# DevEnvWantEntry                                                     NaN    NaN
# SOTags                                                              NaN    NaN
# SOTagsHaveEntry                                                     NaN    NaN
# SOTagsWant Entry                                                    NaN    NaN
# OpSys                                                               NaN    NaN
# OfficeStackAsync                                                    NaN    NaN
# OfficeStackHaveEntry                                                NaN    NaN
# OfficeStackWantEntry                                                NaN    NaN
# CommPlatform                                                        NaN    NaN
# CommPlatformHaveEntr                                                NaN    NaN
# CommPlatformWantEntr                                                NaN    NaN
# AIModelsChoice                                                      NaN    NaN
# AIModels                                                            NaN    NaN
# AIModelsHaveEntry                                                   NaN    NaN
# AIModelsWantEntry                                                   NaN    NaN
# SOAccount                                                           NaN    NaN
# SOVisitFreq                                                         NaN    NaN
# SODuration                                                          NaN    NaN
# SOPartFreq                                                          NaN    NaN
# SO_Dev_Content                                                      NaN    NaN
# SOComm                                                              NaN    NaN
# SOFriction                                                          NaN    NaN
# AISelect                                                            NaN    NaN
# AISent                                                              NaN    NaN
# AIAcc                                                               NaN    NaN
# AIComplex                                                           NaN    NaN
# AITool                                                              NaN    NaN
# AIFrustration                                                       NaN    NaN
# AIExplain                                                           NaN    NaN
# AIAgents                                                            NaN    NaN
# AIAgentChange                                                       NaN    NaN
# AIAgent_Uses                                                        NaN    NaN
# AgentUsesGeneral                                                    NaN    NaN
# AIAgentImpact                                                       NaN    NaN
# AIAgentChallenges                                                   NaN    NaN
# AIAgentKnowledge                                                    NaN    NaN
# AIAgentKnowWrite                                                    NaN    NaN
# AIAgentOrchestration                                                NaN    NaN
# AIAgentOrchWrite                                                    NaN    NaN
# AIAgentObserveSecure                                                NaN    NaN
# AIAgentObsWrite                                                     NaN    NaN
# AIAgentExternal                                                     NaN    NaN
# AIAgentExtWrite                                                     NaN    NaN
# AIHuman                                                             NaN    NaN
# AIOpen                                                              NaN    NaN

# %%
schema_df.loc["LanguageChoice", "question"]
# Out:
# 'Did you work with programming, scripting and markup languages in the last year or do you plan to in the year to come?  Here, we are referring to anything you use that is conventionally referred to as code.'

# %%
df["AIAgentKnowWrite"].value_counts()
# Out:
# AIAgentKnowWrite
# Copilot                                                                                                                                                                                                                                                                                                                           15
# n8n                                                                                                                                                                                                                                                                                                                               15
# Cursor                                                                                                                                                                                                                                                                                                                            13
# ChatGPT                                                                                                                                                                                                                                                                                                                           13
# Junie                                                                                                                                                                                                                                                                                                                             12
# no                                                                                                                                                                                                                                                                                                                                 9
# Claude Code                                                                                                                                                                                                                                                                                                                        8
# copilot                                                                                                                                                                                                                                                                                                                            7
# LangChain                                                                                                                                                                                                                                                                                                                          7
# Langchain                                                                                                                                                                                                                                                                                                                          7
# No                                                                                                                                                                                                                                                                                                                                 7
# cursor                                                                                                                                                                                                                                                                                                                             7
# Github Copilot                                                                                                                                                                                                                                                                                                                     7
# custom                                                                                                                                                                                                                                                                                                                             6
# GitHub Copilot                                                                                                                                                                                                                                                                                                                     6
# chatgpt                                                                                                                                                                                                                                                                                                                            5
# 1                                                                                                                                                                                                                                                                                                                                  5
# Azure AI Search                                                                                                                                                                                                                                                                                                                    4
# Tidewave                                                                                                                                                                                                                                                                                                                           4
# Cline                                                                                                                                                                                                                                                                                                                              4
# yes                                                                                                                                                                                                                                                                                                                                4
# Claude                                                                                                                                                                                                                                                                                                                             4
# MongoDB                                                                                                                                                                                                                                                                                                                            3
# LangGraph                                                                                                                                                                                                                                                                                                                          3
# Gemini                                                                                                                                                                                                                                                                                                                             3
# langgraph                                                                                                                                                                                                                                                                                                                          3
# CoPilot                                                                                                                                                                                                                                                                                                                            3
# LangChain, LangGraph                                                                                                                                                                                                                                                                                                               3
# Custom                                                                                                                                                                                                                                                                                                                             3
# Augment                                                                                                                                                                                                                                                                                                                            3
# langchain                                                                                                                                                                                                                                                                                                                          3
# Amazon Q                                                                                                                                                                                                                                                                                                                           3
# Zed                                                                                                                                                                                                                                                                                                                                3
# ollama                                                                                                                                                                                                                                                                                                                             2
# opensearch                                                                                                                                                                                                                                                                                                                         2
# SurrealDB                                                                                                                                                                                                                                                                                                                          2
# ChatGPT, Gemini                                                                                                                                                                                                                                                                                                                    2
# JetBrains AI                                                                                                                                                                                                                                                                                                                       2
# Cursor AI                                                                                                                                                                                                                                                                                                                          2
# zed                                                                                                                                                                                                                                                                                                                                2
# Roo Code                                                                                                                                                                                                                                                                                                                           2
# aider                                                                                                                                                                                                                                                                                                                              2
# Codex                                                                                                                                                                                                                                                                                                                              2
# Claude code                                                                                                                                                                                                                                                                                                                        2
# Mastra                                                                                                                                                                                                                                                                                                                             2
# Dify                                                                                                                                                                                                                                                                                                                               2
# Agno                                                                                                                                                                                                                                                                                                                               2
# Warp                                                                                                                                                                                                                                                                                                                               2
# github copilot                                                                                                                                                                                                                                                                                                                     2
# pydantic-ai                                                                                                                                                                                                                                                                                                                        2
# Context7                                                                                                                                                                                                                                                                                                                           2
# Co-pilot                                                                                                                                                                                                                                                                                                                           2
# Microsoft Semantic Kernel                                                                                                                                                                                                                                                                                                          2
# Semantic Kernel                                                                                                                                                                                                                                                                                                                    2
# LlamaIndex                                                                                                                                                                                                                                                                                                                         2
# 3                                                                                                                                                                                                                                                                                                                                  2
# Chatgpt                                                                                                                                                                                                                                                                                                                            2
# Github copilot                                                                                                                                                                                                                                                                                                                     2
# na                                                                                                                                                                                                                                                                                                                                 2
# OpenSearch                                                                                                                                                                                                                                                                                                                         2
# Spring AI                                                                                                                                                                                                                                                                                                                          2
# 0                                                                                                                                                                                                                                                                                                                                  2
# Jetbrains Junie                                                                                                                                                                                                                                                                                                                    2
# OpenAI                                                                                                                                                                                                                                                                                                                             2
# Typesense                                                                                                                                                                                                                                                                                                                          2
# Elasticsearch                                                                                                                                                                                                                                                                                                                      2
# Pydantic AI                                                                                                                                                                                                                                                                                                                        2
# Chat GPT                                                                                                                                                                                                                                                                                                                           2
# cline                                                                                                                                                                                                                                                                                                                              2
# LangChain, LangGraph, Elasticsearch                                                                                                                                                                                                                                                                                                1
# Junie from jetbrains                                                                                                                                                                                                                                                                                                               1
# AgentForce                                                                                                                                                                                                                                                                                                                         1
# Claude's Sonnet 4                                                                                                                                                                                                                                                                                                                  1
# ADA for Slack                                                                                                                                                                                                                                                                                                                      1
# Aider, OpenAI Codex, custom made agent for internal use                                                                                                                                                                                                                                                                            1
# Not sure how to answer. I use ChatGTP models daily for help in programming tasks.  Also my development enviroment has a package manager that allows for a vareity of AI's.  We are in the process of figuring out which to use for integration.                                                                                    1
# Lovable, Google AI Studio, Cursor                                                                                                                                                                                                                                                                                                  1
# SQL Server as vectorstore                                                                                                                                                                                                                                                                                                          1
# Claude-Code                                                                                                                                                                                                                                                                                                                        1
# iMacros, (Win64) File System with .iim/.txt/.tmp/.csv Files                                                                                                                                                                                                                                                                        1
# USG chatbot                                                                                                                                                                                                                                                                                                                        1
# Single-agent, no orchestration. Mostly Claude Code.                                                                                                                                                                                                                                                                                1
# amqp                                                                                                                                                                                                                                                                                                                               1
# internal                                                                                                                                                                                                                                                                                                                           1
# Google AI Studio                                                                                                                                                                                                                                                                                                                   1
# Cursor,Copilot                                                                                                                                                                                                                                                                                                                     1
# Manus.im                                                                                                                                                                                                                                                                                                                           1
# Companies own                                                                                                                                                                                                                                                                                                                      1
# Our own agentic framework                                                                                                                                                                                                                                                                                                          1
# We have an in house LLM. Also peek at MS CoPilot and ChatGPT at times                                                                                                                                                                                                                                                              1
# Github actions                                                                                                                                                                                                                                                                                                                     1
# not yet                                                                                                                                                                                                                                                                                                                            1
# Codeium, Windsurf                                                                                                                                                                                                                                                                                                                  1
# GPT4All                                                                                                                                                                                                                                                                                                                            1
# Claude Code, OpenAI Cortex, Google Jules, Windsurf and Cursor                                                                                                                                                                                                                                                                      1
# Jules by google                                                                                                                                                                                                                                                                                                                    1
# smolagents                                                                                                                                                                                                                                                                                                                         1
# docker                                                                                                                                                                                                                                                                                                                             1
# Claude Sonnet 3.7                                                                                                                                                                                                                                                                                                                  1
# semantic kernel, kernel memory, azure ai search                                                                                                                                                                                                                                                                                    1
# vs2022                                                                                                                                                                                                                                                                                                                             1
# I build them                                                                                                                                                                                                                                                                                                                       1
# context7 nixos-mcp                                                                                                                                                                                                                                                                                                                 1
# Langflow, Astra DB, Cassandra                                                                                                                                                                                                                                                                                                      1
# Cline, Roo-Code, Cursor, Librechat                                                                                                                                                                                                                                                                                                 1
# Amazon bedrock                                                                                                                                                                                                                                                                                                                     1
# In-house solution                                                                                                                                                                                                                                                                                                                  1
# Taskmaster, Stagehand                                                                                                                                                                                                                                                                                                              1
# langflow , ollama , langchain                                                                                                                                                                                                                                                                                                      1
# ChatGPT, Perplexity AI, Google Gemini, Meta AI                                                                                                                                                                                                                                                                                     1
# OpenAI agents SDK                                                                                                                                                                                                                                                                                                                  1
# Dust                                                                                                                                                                                                                                                                                                                               1
# GCP AI agent                                                                                                                                                                                                                                                                                                                       1
# TeamDynamix                                                                                                                                                                                                                                                                                                                        1
# doubao hunyuan                                                                                                                                                                                                                                                                                                                     1
# copilot, windsurf                                                                                                                                                                                                                                                                                                                  1
# mcp                                                                                                                                                                                                                                                                                                                                1
# llama.cpp                                                                                                                                                                                                                                                                                                                          1
# continue and ollama in vscode                                                                                                                                                                                                                                                                                                      1
# Organization doesn't allow to share information.                                                                                                                                                                                                                                                                                   1
# Geminy gem's, agents built in GTP-chat, agents built in Claude, agents as extension in VSCode                                                                                                                                                                                                                                      1
# phpstorm                                                                                                                                                                                                                                                                                                                           1
# Dependabot                                                                                                                                                                                                                                                                                                                         1
# GitHub CoPilot, Microsoft CoPilot                                                                                                                                                                                                                                                                                                  1
# I don't use any                                                                                                                                                                                                                                                                                                                    1
# Android Studio                                                                                                                                                                                                                                                                                                                     1
# Im the developer of arroy the vector database in meilisearch                                                                                                                                                                                                                                                                       1
# CodderRabbit                                                                                                                                                                                                                                                                                                                       1
# Jira, Confluence                                                                                                                                                                                                                                                                                                                   1
# Spring Ai                                                                                                                                                                                                                                                                                                                          1
# anthropic claude                                                                                                                                                                                                                                                                                                                   1
# ElasticSearch                                                                                                                                                                                                                                                                                                                      1
# NATS                                                                                                                                                                                                                                                                                                                               1
# Snowflake MCP                                                                                                                                                                                                                                                                                                                      1
# Cursor.ai                                                                                                                                                                                                                                                                                                                          1
# rust code                                                                                                                                                                                                                                                                                                                          1
# gemini gems                                                                                                                                                                                                                                                                                                                        1
# LMStudio, Gemini                                                                                                                                                                                                                                                                                                                   1
# Opensearch                                                                                                                                                                                                                                                                                                                         1
# GitHub Copilot, Cursor, JetBrains Junie                                                                                                                                                                                                                                                                                            1
# only for caching                                                                                                                                                                                                                                                                                                                   1
# JetBrains MCP Server                                                                                                                                                                                                                                                                                                               1
# Google DialogFlow                                                                                                                                                                                                                                                                                                                  1
# self made ones along with claude code and cursor                                                                                                                                                                                                                                                                                   1
# chatgbt                                                                                                                                                                                                                                                                                                                            1
# none of above.  the tools i used are different than these                                                                                                                                                                                                                                                                          1
# StackSpot AI                                                                                                                                                                                                                                                                                                                       1
# ...
# chatgpt, grok, cursor,claude                                                                                                                                                                                                                                                                                                       1
# openAi, capilot, bingAi                                                                                                                                                                                                                                                                                                            1
# ADK, Ollama, Langchain                                                                                                                                                                                                                                                                                                             1
# Github Copilot, Claude                                                                                                                                                                                                                                                                                                             1
# Manus, Bolt                                                                                                                                                                                                                                                                                                                        1
# autogen                                                                                                                                                                                                                                                                                                                            1
# Markdown files                                                                                                                                                                                                                                                                                                                     1
# avante                                                                                                                                                                                                                                                                                                                             1
# Binance,Exness,b2p,p2psystem,Reedit                                                                                                                                                                                                                                                                                                1
# OpenAI Responses                                                                                                                                                                                                                                                                                                                   1
# dust, crew.ai, autogen                                                                                                                                                                                                                                                                                                             1
# GitLab MCP,Atlassian MCP,Raycast AI,Claude                                                                                                                                                                                                                                                                                         1
# Playwright, OpenAI Codex, Claude, Cursor, Replit, AbacusAI, Lovable, Base44                                                                                                                                                                                                                                                        1
# no used                                                                                                                                                                                                                                                                                                                            1
# Langgraph, Langchain                                                                                                                                                                                                                                                                                                               1
# nmp                                                                                                                                                                                                                                                                                                                                1
# Langgraph, custom                                                                                                                                                                                                                                                                                                                  1
# XcodebuildMCP                                                                                                                                                                                                                                                                                                                      1
# Terraform MCP Servers and AWS MCP Servers                                                                                                                                                                                                                                                                                          1
# Chat GPT AI Agent                                                                                                                                                                                                                                                                                                                  1
# gihub copilot                                                                                                                                                                                                                                                                                                                      1
# watsonx                                                                                                                                                                                                                                                                                                                            1
# ag2                                                                                                                                                                                                                                                                                                                                1
# copilot, vscode, claude                                                                                                                                                                                                                                                                                                            1
# Copilot studio                                                                                                                                                                                                                                                                                                                     1
# Vs Code Exstensions                                                                                                                                                                                                                                                                                                                1
# sqlite, text files.                                                                                                                                                                                                                                                                                                                1
# Zenml                                                                                                                                                                                                                                                                                                                              1
# GitLab duo workflow                                                                                                                                                                                                                                                                                                                1
# Not applicable                                                                                                                                                                                                                                                                                                                     1
# copilot, chatgpt                                                                                                                                                                                                                                                                                                                   1
# 30                                                                                                                                                                                                                                                                                                                                 1
# Gemini AI                                                                                                                                                                                                                                                                                                                          1
# langchain, langflow and scripts                                                                                                                                                                                                                                                                                                    1
# Part of a product, not made by us                                                                                                                                                                                                                                                                                                  1
# Asana                                                                                                                                                                                                                                                                                                                              1
# copilot, chatgpt, Claude                                                                                                                                                                                                                                                                                                           1
# JetBrains AI, Github Copilot, Google Gemini. Mistral AI                                                                                                                                                                                                                                                                            1
# -                                                                                                                                                                                                                                                                                                                                  1
# Botpress  LangChain  CrewAI  Microsoft Semantic Kernel  LlamaIndex  AutoGen  OpenAI Agents SDK  Google Agent Development Kit (ADK)  UiPath Orchestrator  IBM Watson Assistant  Microsoft Bot Framework  Google Dialogflow  Orby AI  SuperAGI                                                                                       1
# Gemini code completion                                                                                                                                                                                                                                                                                                             1
# 4                                                                                                                                                                                                                                                                                                                                  1
# Yes                                                                                                                                                                                                                                                                                                                                1
# Yes, the tools I’ve used for AI agent orchestration or agent frameworks in the past year that were not listed above include: LangGraph, CrewAI, AutoGen, and MetaGPT.                                                                                                                                                              1
# Copilot Agentic Mode, Cursor                                                                                                                                                                                                                                                                                                       1
# Roo code, GitHub copilot                                                                                                                                                                                                                                                                                                           1
# proprietary                                                                                                                                                                                                                                                                                                                        1
# GitHub                                                                                                                                                                                                                                                                                                                             1
# DuckDB, MariaDB                                                                                                                                                                                                                                                                                                                    1
# Name: count, dtype: int64

# %%
df["Country"].value_counts()
# Out:
# Country
# United States of America                                7233
# Germany                                                 3025
# India                                                   2547
# United Kingdom of Great Britain and Northern Ireland    2042
# France                                                  1409
# Canada                                                  1305
# Ukraine                                                  964
# Poland                                                   888
# Netherlands                                              867
# Italy                                                    835
# Brazil                                                   825
# Australia                                                804
# Spain                                                    717
# Sweden                                                   616
# Switzerland                                              546
# Czech Republic                                           520
# Austria                                                  410
# Romania                                                  323
# Belgium                                                  321
# Denmark                                                  316
# Israel                                                   297
# Turkey                                                   295
# Mexico                                                   286
# Portugal                                                 280
# China                                                    255
# New Zealand                                              255
# Finland                                                  254
# South Africa                                             253
# Greece                                                   252
# Bulgaria                                                 244
# Pakistan                                                 239
# Norway                                                   237
# Hungary                                                  236
# Argentina                                                222
# Bangladesh                                               220
# Ireland                                                  209
# Colombia                                                 202
# Russian Federation                                       200
# Nigeria                                                  199
# Japan                                                    188
# Indonesia                                                181
# Serbia                                                   158
# Iran, Islamic Republic of...                             149
# Kenya                                                    148
# Slovakia                                                 147
# Viet Nam                                                 145
# Philippines                                              142
# Egypt                                                    140
# Chile                                                    131
# Thailand                                                 119
# Taiwan                                                   118
# Croatia                                                  113
# Lithuania                                                101
# Sri Lanka                                                 95
# United Arab Emirates                                      89
# Singapore                                                 89
# Nepal                                                     83
# Malaysia                                                  82
# Slovenia                                                  78
# Hong Kong (S.A.R.)                                        72
# Estonia                                                   70
# Peru                                                      64
# Latvia                                                    62
# Morocco                                                   55
# Uruguay                                                   52
# Algeria                                                   49
# Georgia                                                   48
# South Korea                                               48
# Venezuela, Bolivarian Republic of...                      47
# Tunisia                                                   46
# Ghana                                                     46
# Cyprus                                                    39
# Ethiopia                                                  38
# Republic of Korea                                         38
# Saudi Arabia                                              37
# Guatemala                                                 33
# Jordan                                                    32
# Bosnia and Herzegovina                                    30
# Kazakhstan                                                29
# Nomadic                                                   29
# Uganda                                                    28
# Ecuador                                                   28
# Costa Rica                                                27
# Dominican Republic                                        26
# Belarus                                                   26
# Armenia                                                   25
# Luxembourg                                                23
# Albania                                                   22
# Paraguay                                                  21
# Republic of North Macedonia                               20
# Lebanon                                                   20
# Malta                                                     19
# Bolivia                                                   18
# Yemen                                                     18
# Azerbaijan                                                18
# Myanmar                                                   17
# Uzbekistan                                                16
# Montenegro                                                15
# Rwanda                                                    15
# Zimbabwe                                                  13
# Iraq                                                      13
# Zambia                                                    13
# Cameroon                                                  13
# Afghanistan                                               13
# Iceland                                                   13
# El Salvador                                               12
# Madagascar                                                11
# Honduras                                                  11
# Cambodia                                                  11
# Mauritius                                                 11
# Syrian Arab Republic                                      11
# Kyrgyzstan                                                10
# Panama                                                    10
# Isle of Man                                               10
# Togo                                                       9
# Maldives                                                   9
# Moldova                                                    9
# Republic of Moldova                                        8
# Côte d'Ivoire                                              8
# Cuba                                                       8
# Trinidad and Tobago                                        7
# Bahrain                                                    7
# Angola                                                     7
# Palestine                                                  7
# Namibia                                                    7
# Democratic Republic of the Congo                           7
# United Republic of Tanzania                                7
# Kuwait                                                     7
# Nicaragua                                                  6
# Kosovo                                                     6
# Oman                                                       6
# North Korea                                                6
# Andorra                                                    6
# Qatar                                                      5
# Mozambique                                                 5
# Fiji                                                       5
# Swaziland                                                  5
# Benin                                                      5
# Senegal                                                    5
# Congo, Republic of the...                                  5
# Democratic People's Republic of Korea                      4
# Guyana                                                     4
# Jamaica                                                    4
# Somalia                                                    4
# Barbados                                                   4
# Malawi                                                     4
# Sudan                                                      3
# Belize                                                     3
# Bhutan                                                     3
# Brunei Darussalam                                          3
# Mongolia                                                   3
# Papua New Guinea                                           3
# Saint Lucia                                                2
# Haiti                                                      2
# Tajikistan                                                 2
# Suriname                                                   2
# Botswana                                                   2
# Micronesia, Federated States of...                         2
# Mali                                                       2
# Lao People's Democratic Republic                           2
# Turkmenistan                                               2
# Libyan Arab Jamahiriya                                     2
# Antigua and Barbuda                                        2
# Sierra Leone                                               2
# Burundi                                                    2
# Mauritania                                                 1
# Timor-Leste                                                1
# Gabon                                                      1
# Guinea-Bissau                                              1
# Gambia                                                     1
# Niger                                                      1
# Lesotho                                                    1
# San Marino                                                 1
# Djibouti                                                   1
# Cape Verde                                                 1
# Palau                                                      1
# Guinea                                                     1
# Name: count, dtype: int64

# %%
country_grp = df.groupby("Country")
country_grp.get_group("South Korea")
# Out:
#                                                    MainBranch  \
# ResponseId
# 47927       I used to be a developer by profession, but no...
#
#                         Age                                       EdLevel  \
# ResponseId
# 47927       25-34 years old  Bachelor’s degree (B.A., B.S., B.Eng., etc.)
#
#               Employment                                     EmploymentAddl  \
# ResponseId
# 47927       Not employed  Engaged in paid work (less than 10 hours per w...
#
#             WorkExp                                    LearnCodeChoose  \
# ResponseId
# 47927           5.0  Yes, I am not new to coding but am learning ne...
#
#                                                     LearnCode  \
# ResponseId
# 47927       Blogs or podcasts;School (i.e., University, Co...
#
#                                                   LearnCodeAI AILearnHow  \
# ResponseId
# 47927       No, I learned something that was not related t...        NaN
#
#             YearsCode  DevType  \
# ResponseId
# 47927             1.0  Student
#
#                                                       OrgSize  \
# ResponseId
# 47927       Just me - I am a freelancer, sole proprietor, ...
#
#                             ICorPM RemoteWork  \
# ResponseId
# 47927       Individual contributor     Remote
#
#                                             PurchaseInfluence  \
# ResponseId
# 47927       Yes, I endorsed a tool that was ultimately not...
#
#            TechEndorseIntro  TechEndorse_1  TechEndorse_2  TechEndorse_3  \
# ResponseId
# 47927                School            1.0            7.0            6.0
#
#             TechEndorse_4  TechEndorse_5  TechEndorse_6  TechEndorse_7  \
# ResponseId
# 47927                 4.0            9.0            2.0            3.0
#
#             TechEndorse_8  TechEndorse_9  TechEndorse_13 TechEndorse_13_TEXT  \
# ResponseId
# 47927                 5.0            8.0            10.0                 NaN
#
#             TechOppose_1  TechOppose_2  TechOppose_3  TechOppose_5  \
# ResponseId
# 47927                9.0           6.0           7.0           5.0
#
#             TechOppose_7  TechOppose_9  TechOppose_11  TechOppose_13  \
# ResponseId
# 47927                2.0           1.0            3.0            8.0
#
#             TechOppose_16  TechOppose_15 TechOppose_15_TEXT          Industry  \
# ResponseId
# 47927                 4.0           10.0                NaN  Higher Education
#
#             JobSatPoints_1  JobSatPoints_2  JobSatPoints_3  JobSatPoints_4  \
# ResponseId
# 47927                  NaN             NaN             NaN             NaN
#
#             JobSatPoints_5  JobSatPoints_6  JobSatPoints_7  JobSatPoints_8  \
# ResponseId
# 47927                  NaN             NaN             NaN             NaN
#
#             JobSatPoints_9  JobSatPoints_10  JobSatPoints_11  JobSatPoints_13  \
# ResponseId
# 47927                  NaN              NaN              NaN              NaN
#
#             JobSatPoints_14  JobSatPoints_15  JobSatPoints_16  \
# ResponseId
# 47927                   NaN              NaN              NaN
#
#            JobSatPoints_15_TEXT AIThreat NewRole  ToolCountWork  \
# ResponseId
# 47927                       NaN      Yes     NaN           55.0
#
#             ToolCountPersonal Country                  Currency  CompTotal  \
# ResponseId
# 47927                    66.0   Palau  USD United States dollar        NaN
#
#            LanguageChoice                             LanguageHaveWorkedWith  \
# ResponseId
# 47927                 NaN  Bash/Shell (all shells);COBOL;Dart;Delphi;Elix...
#
#            LanguageWantToWorkWith LanguageAdmired LanguagesHaveEntry  \
# ResponseId
# 47927         Ada;C;C#;C++;Erlang             NaN                NaN
#
#            LanguagesWantEntry DatabaseChoice  \
# ResponseId
# 47927                     NaN            NaN
#
#                                        DatabaseHaveWorkedWith  \
# ResponseId
# 47927       Cloud Firestore;Databricks SQL;Datomic;DuckDB;...
#
#                                        DatabaseWantToWorkWith DatabaseAdmired  \
# ResponseId
# 47927       BigQuery;Cassandra;Cosmos DB;Elasticsearch;H2;...             NaN
#
#            DatabaseHaveEntry DatabaseWantEntry PlatformChoice  \
# ResponseId
# 47927                    NaN               NaN            Yes
#
#            PlatformHaveWorkedWith PlatformWantToWorkWith PlatformAdmired  \
# ResponseId
# 47927                         NaN                    NaN             NaN
#
#            PlatformHaveEntry PlatformWantEntry WebframeChoice  \
# ResponseId
# 47927                    NaN               NaN            NaN
#
#            WebframeHaveWorkedWith WebframeWantToWorkWith WebframeAdmired  \
# ResponseId
# 47927                         NaN                    NaN             NaN
#
#            WebframeHaveEntry WebframeWantEntry DevEnvsChoice  \
# ResponseId
# 47927                    NaN               NaN           NaN
#
#            DevEnvsHaveWorkedWith DevEnvsWantToWorkWith DevEnvsAdmired  \
# ResponseId
# 47927                        NaN                   NaN            NaN
#
#            DevEnvHaveEntry DevEnvWantEntry SOTagsHaveWorkedWith  \
# ResponseId
# 47927                  NaN             NaN                  NaN
#
#            SOTagsWantToWorkWith SOTagsAdmired SOTagsHaveEntry  \
# ResponseId
# 47927                       NaN           NaN             NaN
#
#            SOTagsWant Entry OpSysPersonal use OpSysProfessional use  \
# ResponseId
# 47927                   NaN               NaN                   NaN
#
#            OfficeStackAsyncHaveWorkedWith OfficeStackAsyncWantToWorkWith  \
# ResponseId
# 47927                                 NaN                            NaN
#
#            OfficeStackAsyncAdmired OfficeStackHaveEntry OfficeStackWantEntry  \
# ResponseId
# 47927                          NaN                  NaN                  NaN
#
#            CommPlatformHaveWorkedWith CommPlatformWantToWorkWith  \
# ResponseId
# 47927                             NaN                        NaN
#
#            CommPlatformAdmired CommPlatformHaveEntr CommPlatformWantEntr  \
# ResponseId
# 47927                      NaN                  NaN                  NaN
#
#            AIModelsChoice AIModelsHaveWorkedWith AIModelsWantToWorkWith  \
# ResponseId
# 47927                 NaN                    NaN                    NaN
#
#            AIModelsAdmired AIModelsHaveEntry AIModelsWantEntry  \
# ResponseId
# 47927                  NaN               NaN               NaN
#
#                           SOAccount           SOVisitFreq  \
# ResponseId
# 47927       Not sure/can't remember  A few times per week
#
#                        SODuration             SOPartFreq SO_Dev_Content  \
# ResponseId
# 47927       Between 1 and 3 years  Daily or almost daily      Job board
#
#             SO_Actions_1  SO_Actions_16  SO_Actions_3  SO_Actions_4  \
# ResponseId
# 47927                2.0            9.0           8.0           6.0
#
#             SO_Actions_5  SO_Actions_6  SO_Actions_9  SO_Actions_7  \
# ResponseId
# 47927                4.0           5.0           7.0           3.0
#
#             SO_Actions_10  SO_Actions_15 SO_Actions_15_TEXT           SOComm  \
# ResponseId
# 47927                 1.0           10.0                NaN  Yes, definitely
#
#                                     SOFriction                AISelect  \
# ResponseId
# 47927       I don't use AI or AI-enabled tools  No, but I plan to soon
#
#             AISent                       AIAcc  \
# ResponseId
# 47927       Unsure  Neither trust nor distrust
#
#                                                 AIComplex  \
# ResponseId
# 47927       Good, but not great at handling complex tasks
#
#            AIToolCurrently partially AI  \
# ResponseId
# 47927                 Other (write in):
#
#                      AIToolDon't plan to use AI for this task  \
# ResponseId
# 47927       Committing and reviewing code;Creating or main...
#
#                                AIToolPlan to partially use AI  \
# ResponseId
# 47927       Learning about a codebase;Writing code;Testing...
#
#                                   AIToolPlan to mostly use AI  \
# ResponseId
# 47927       Project planning;Predictive analytics;Generati...
#
#                                     AIToolCurrently mostly AI  \
# ResponseId
# 47927       Documenting code;Deployment and monitoring;Sea...
#
#                                                 AIFrustration AIExplain  \
# ResponseId
# 47927       I’ve become less confident in my own problem-s...       NaN
#
#                                                      AIAgents  \
# ResponseId
# 47927       Yes, I use AI agents at work monthly or infreq...
#
#                                                 AIAgentChange AIAgent_Uses  \
# ResponseId
# 47927       No, but my development work has significantly ...    Marketing
#
#            AgentUsesGeneral  \
# ResponseId
# 47927                   NaN
#
#                                   AIAgentImpactSomewhat agree  \
# ResponseId
# 47927       AI agents have helped me solve complex problem...
#
#                                        AIAgentImpactNeutral  \
# ResponseId
# 47927       AI agents have improved the quality of my code.
#
#            AIAgentImpactSomewhat disagree  \
# ResponseId
# 47927                                 NaN
#
#                                   AIAgentImpactStrongly agree  \
# ResponseId
# 47927       AI agents have improved collaboration within m...
#
#                                AIAgentImpactStrongly disagree  \
# ResponseId
# 47927       AI agents have increased my productivity.;AI a...
#
#            AIAgentChallengesNeutral  \
# ResponseId
# 47927                           NaN
#
#                            AIAgentChallengesSomewhat disagree  \
# ResponseId
# 47927       It takes significant time and effort to learn ...
#
#                               AIAgentChallengesStrongly agree  \
# ResponseId
# 47927       Integrating AI agents with my existing tools a...
#
#            AIAgentChallengesSomewhat agree  \
# ResponseId
# 47927                                  NaN
#
#                            AIAgentChallengesStrongly disagree  \
# ResponseId
# 47927       I am concerned about the accuracy of the infor...
#
#            AIAgentKnowledge AIAgentKnowWrite AIAgentOrchestration  \
# ResponseId
# 47927               LangMem              NaN       IBM watsonx.ai
#
#            AIAgentOrchWrite AIAgentObserveSecure AIAgentObsWrite  \
# ResponseId
# 47927                   NaN            Honeycomb             NaN
#
#            AIAgentExternal AIAgentExtWrite  \
# ResponseId
# 47927          Claude Code             NaN
#
#                                            AIHuman AIOpen  \
# ResponseId
# 47927       When I need quick help troubleshooting      3
#
#             ConvertedCompYearly  JobSat
# ResponseId
# 47927                       NaN     NaN

# %%
filt =df["Country"] == "South Korea"

# %%
df.loc[filt]
# Out:
#                                                    MainBranch  \
# ResponseId
# 1883                           I am a developer by profession
# 2873                           I am a developer by profession
# 3064                           I am a developer by profession
# 3233        I used to be a developer by profession, but no...
# 4438                           I am a developer by profession
# 5901                                    I am learning to code
# 5907                              I code primarily as a hobby
# 6187                           I am a developer by profession
# 6273                                    I am learning to code
# 6374        I am not primarily a developer, but I write co...
# 8126                           I am a developer by profession
# 9431                           I am a developer by profession
# 9749                           I am a developer by profession
# 11971                          I am a developer by profession
# 12407       I am not primarily a developer, but I write co...
# 12601                          I am a developer by profession
# 12617       I am not primarily a developer, but I write co...
# 15044                                   I am learning to code
# 18933                          I am a developer by profession
# 19054                          I am a developer by profession
# 21022                                   I am learning to code
# 21086       I am not primarily a developer, but I write co...
# 22124                          I am a developer by profession
# 23413                          I am a developer by profession
# 23844                                   I am learning to code
# 26989                                   I am learning to code
# 28294                          I am a developer by profession
# 29890                          I am a developer by profession
# 30705                          I am a developer by profession
# 31172                          I am a developer by profession
# 32290                          I am a developer by profession
# 32303                          I am a developer by profession
# 32690                          I am a developer by profession
# 34114                          I am a developer by profession
# 34127                          I am a developer by profession
# 35935                          I am a developer by profession
# 36755                          I am a developer by profession
# 37696                                   I am learning to code
# 37785                          I am a developer by profession
# 39433       I am not primarily a developer, but I write co...
# 39580                          I am a developer by profession
# 41951                          I am a developer by profession
# 42256                          I am a developer by profession
# 42915                                   I am learning to code
# 43405                          I am a developer by profession
# 45932                          I am a developer by profession
# 46416                             I code primarily as a hobby
# 48369                             I code primarily as a hobby
#
#                           Age  \
# ResponseId
# 1883          25-34 years old
# 2873          35-44 years old
# 3064          35-44 years old
# 3233          25-34 years old
# 4438          25-34 years old
# 5901          18-24 years old
# 5907          18-24 years old
# 6187          25-34 years old
# 6273          18-24 years old
# 6374          25-34 years old
# 8126          25-34 years old
# 9431          35-44 years old
# 9749          35-44 years old
# 11971         25-34 years old
# 12407         18-24 years old
# 12601         18-24 years old
# 12617         25-34 years old
# 15044         18-24 years old
# 18933         25-34 years old
# 19054         45-54 years old
# 21022         18-24 years old
# 21086       65 years or older
# 22124         35-44 years old
# 23413         25-34 years old
# 23844         18-24 years old
# 26989         18-24 years old
# 28294         18-24 years old
# 29890         18-24 years old
# 30705         25-34 years old
# 31172         18-24 years old
# 32290         35-44 years old
# 32303         25-34 years old
# 32690         35-44 years old
# 34114         25-34 years old
# 34127         35-44 years old
# 35935         25-34 years old
# 36755         35-44 years old
# 37696         25-34 years old
# 37785         25-34 years old
# 39433         25-34 years old
# 39580         25-34 years old
# 41951         25-34 years old
# 42256         25-34 years old
# 42915         18-24 years old
# 43405         45-54 years old
# 45932         18-24 years old
# 46416         45-54 years old
# 48369         55-64 years old
#
#                                                       EdLevel  \
# ResponseId
# 1883             Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 2873             Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 3064          Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 3233             Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 4438                      Associate degree (A.A., A.S., etc.)
# 5901        Some college/university study without earning ...
# 5907        Secondary school (e.g. American high school, G...
# 6187          Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 6273             Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 6374           Professional degree (JD, MD, Ph.D, Ed.D, etc.)
# 8126             Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 9431        Some college/university study without earning ...
# 9749             Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 11971            Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 12407            Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 12601            Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 12617            Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 15044       Secondary school (e.g. American high school, G...
# 18933            Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 19054         Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 21022       Secondary school (e.g. American high school, G...
# 21086          Professional degree (JD, MD, Ph.D, Ed.D, etc.)
# 22124         Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 23413            Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 23844       Some college/university study without earning ...
# 26989       Some college/university study without earning ...
# 28294       Secondary school (e.g. American high school, G...
# 29890       Secondary school (e.g. American high school, G...
# 30705       Some college/university study without earning ...
# 31172            Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 32290            Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 32303       Some college/university study without earning ...
# 32690            Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 34114            Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 34127                     Associate degree (A.A., A.S., etc.)
# 35935         Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 36755            Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 37696            Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 37785            Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 39433            Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 39580            Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 41951            Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 42256            Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 42915       Secondary school (e.g. American high school, G...
# 43405         Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 45932       Secondary school (e.g. American high school, G...
# 46416            Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 48369            Bachelor’s degree (B.A., B.S., B.Eng., etc.)
#
#                                                    Employment  \
# ResponseId
# 1883                                                 Employed
# 2873        Independent contractor, freelancer, or self-em...
# 3064                                                 Employed
# 3233                                                 Employed
# 4438                                                 Employed
# 5901                                                  Student
# 5907                                      I prefer not to say
# 6187                                                 Employed
# 6273                                                  Student
# 6374                                                 Employed
# 8126                                                 Employed
# 9431                                                 Employed
# 9749        Independent contractor, freelancer, or self-em...
# 11971                                            Not employed
# 12407                                                 Student
# 12601                                            Not employed
# 12617                                            Not employed
# 15044                                                 Student
# 18933                                                Employed
# 19054       Independent contractor, freelancer, or self-em...
# 21022                                                 Student
# 21086                                                 Retired
# 22124                                                Employed
# 23413                                                Employed
# 23844                                            Not employed
# 26989                                                 Student
# 28294                                                Employed
# 29890                                                 Student
# 30705                                                Employed
# 31172                                                Employed
# 32290                                                Employed
# 32303                                            Not employed
# 32690                                                Employed
# 34114                                                Employed
# 34127                                                Employed
# 35935                                                 Student
# 36755                                                Employed
# 37696                                            Not employed
# 37785                                                Employed
# 39433                                                Employed
# 39580                                                Employed
# 41951       Independent contractor, freelancer, or self-em...
# 42256       Independent contractor, freelancer, or self-em...
# 42915                                                 Student
# 43405                                                Employed
# 45932                                                Employed
# 46416                                                Employed
# 48369       Independent contractor, freelancer, or self-em...
#
#                                                EmploymentAddl  WorkExp  \
# ResponseId
# 1883              Engaged in paid work (20-29 hours per week)      5.0
# 2873                                        None of the above     16.0
# 3064                                 Volunteering (regularly)     10.0
# 3233                                        None of the above      2.0
# 4438                                        None of the above     10.0
# 5901                                        None of the above      NaN
# 5907                                                      NaN      1.0
# 6187        Volunteering (regularly);Attending school (ful...      5.0
# 6273                             Attending school (full-time)      NaN
# 6374                                        None of the above      NaN
# 8126                                        None of the above      5.0
# 9431                                        None of the above      6.0
# 9749          Caring for dependents (children, elderly, etc.)     15.0
# 11971                                       None of the above      NaN
# 12407       Engaged in paid work (20-29 hours per week);At...      NaN
# 12601                                       None of the above      5.0
# 12617                            Attending school (part-time)      NaN
# 15044       Volunteering (regularly);Attending school (ful...      NaN
# 18933                                       None of the above      4.0
# 19054             Engaged in paid work (20-29 hours per week)     20.0
# 21022       Attending school (full-time);Engaged in paid w...      5.0
# 21086                                       None of the above     30.0
# 22124                                       None of the above     12.0
# 23413                                       None of the above      7.0
# 23844             Engaged in paid work (10-19 hours per week)      NaN
# 26989                            Attending school (full-time)      NaN
# 28294                                                     NaN      5.0
# 29890                            Attending school (full-time)      NaN
# 30705                                       None of the above      2.0
# 31172       Engaged in paid work (20-29 hours per week);At...      2.0
# 32290                                       None of the above      8.0
# 32303                                       None of the above      8.0
# 32690             Engaged in paid work (20-29 hours per week)      5.0
# 34114                                       None of the above      3.0
# 34127                                Volunteering (regularly)      3.0
# 35935                            Attending school (full-time)      8.0
# 36755             Engaged in paid work (10-19 hours per week)      5.0
# 37696                                       None of the above      NaN
# 37785                                       None of the above      1.0
# 39433                                                     NaN      5.0
# 39580                                       None of the above      6.0
# 41951                            Attending school (full-time)      2.0
# 42256                                       None of the above      6.0
# 42915                            Attending school (full-time)      NaN
# 43405                                       None of the above     27.0
# 45932                                       None of the above      1.0
# 46416                                       None of the above     20.0
# 48369       Transitioning to retirement (gradually reducin...     40.0
#
#                                               LearnCodeChoose  \
# ResponseId
# 1883        Yes, I am not new to coding but am learning ne...
# 2873        Yes, I am not new to coding but am learning ne...
# 3064        No, I am not new to coding and did not learn n...
# 3233        Yes, I am not new to coding but am learning ne...
# 4438        Yes, I am not new to coding but am learning ne...
# 5901        Yes, I am not new to coding but am learning ne...
# 5907        Yes, I am not new to coding but am learning ne...
# 6187        Yes, I am not new to coding but am learning ne...
# 6273        Yes, I am not new to coding but am learning ne...
# 6374        Yes, I am not new to coding but am learning ne...
# 8126        No, I am not new to coding and did not learn n...
# 9431        Yes, I am not new to coding but am learning ne...
# 9749        Yes, I am not new to coding but am learning ne...
# 11971       Yes, I am not new to coding but am learning ne...
# 12407       Yes, I am not new to coding but am learning ne...
# 12601       No, I am not new to coding and did not learn n...
# 12617       No, I am not new to coding and did not learn n...
# 15044       Yes, I am not new to coding but am learning ne...
# 18933       Yes, I am not new to coding but am learning ne...
# 19054       Yes, I am not new to coding but am learning ne...
# 21022       Yes, I am not new to coding but am learning ne...
# 21086       Yes, I am not new to coding but am learning ne...
# 22124       Yes, I am not new to coding but am learning ne...
# 23413       Yes, I am not new to coding but am learning ne...
# 23844       Yes, I am not new to coding but am learning ne...
# 26989       Yes, I am not new to coding but am learning ne...
# 28294       Yes, I am not new to coding but am learning ne...
# 29890       Yes, I am not new to coding but am learning ne...
# 30705       Yes, I am not new to coding but am learning ne...
# 31172       No, I am not new to coding and did not learn n...
# 32290       No, I am not new to coding and did not learn n...
# 32303       Yes, I am not new to coding but am learning ne...
# 32690       Yes, I am not new to coding but am learning ne...
# 34114       Yes, I am not new to coding but am learning ne...
# 34127       No, I am not new to coding and did not learn n...
# 35935       Yes, I am not new to coding but am learning ne...
# 36755       Yes, I am not new to coding but am learning ne...
# 37696       Yes, I am not new to coding but am learning ne...
# 37785       Yes, I am not new to coding but am learning ne...
# 39433       No, I am not new to coding and did not learn n...
# 39580       Yes, I am not new to coding but am learning ne...
# 41951       Yes, I am not new to coding but am learning ne...
# 42256       Yes, I am not new to coding but am learning ne...
# 42915       Yes, I am not new to coding but am learning ne...
# 43405       Yes, I am not new to coding but am learning ne...
# 45932       Yes, I am not new to coding but am learning ne...
# 46416       No, I am not new to coding and did not learn n...
# 48369       Yes, I am not new to coding but am learning ne...
#
#                                                     LearnCode  \
# ResponseId
# 1883        Technical documentation (is generated for/by t...
# 2873        Other online resources (e.g. standard search, ...
# 3064                                                      NaN
# 3233        Books / Physical media;Videos (not associated ...
# 4438        Other online resources (e.g. standard search, ...
# 5901        Online Courses or Certification (includes all ...
# 5907        Technical documentation (is generated for/by t...
# 6187        Other online resources (e.g. standard search, ...
# 6273        Other online resources (e.g. standard search, ...
# 6374        Other online resources (e.g. standard search, ...
# 8126                                                      NaN
# 9431        Online Courses or Certification (includes all ...
# 9749                                   Books / Physical media
# 11971       Other online resources (e.g. standard search, ...
# 12407       Other online resources (e.g. standard search, ...
# 12601                                                     NaN
# 12617                                                     NaN
# 15044       Online Courses or Certification (includes all ...
# 18933       Other online resources (e.g. standard search, ...
# 19054       Online Courses or Certification (includes all ...
# 21022       Other online resources (e.g. standard search, ...
# 21086       Online Courses or Certification (includes all ...
# 22124       Books / Physical media;Videos (not associated ...
# 23413       Other online resources (e.g. standard search, ...
# 23844       Other online resources (e.g. standard search, ...
# 26989       Other online resources (e.g. standard search, ...
# 28294       AI CodeGen tools or AI-enabled apps;Other (ple...
# 29890       Technical documentation (is generated for/by t...
# 30705       Other online resources (e.g. standard search, ...
# 31172                                                     NaN
# 32290                                                     NaN
# 32303       Online Courses or Certification (includes all ...
# 32690       Online Courses or Certification (includes all ...
# 34114       Online Courses or Certification (includes all ...
# 34127                                                     NaN
# 35935       Online Courses or Certification (includes all ...
# 36755       Other online resources (e.g. standard search, ...
# 37696       Other online resources (e.g. standard search, ...
# 37785       Online Courses or Certification (includes all ...
# 39433                                                     NaN
# 39580       Online Courses or Certification (includes all ...
# 41951       Online Courses or Certification (includes all ...
# 42256       Stack Overflow or Stack Exchange;Technical doc...
# 42915       Technical documentation (is generated for/by t...
# 43405       Other online resources (e.g. standard search, ...
# 45932       Online Courses or Certification (includes all ...
# 46416                                                     NaN
# 48369       Other online resources (e.g. standard search, ...
#
#                                                   LearnCodeAI  \
# ResponseId
# 1883        Yes, I learned how to use AI-enabled tools for...
# 2873        Yes, I learned how to use AI-enabled tools for...
# 3064        No, I learned something that was not related t...
# 3233        No, I learned something that was not related t...
# 4438        Yes, I learned how to use AI-enabled tools for...
# 5901        Yes, I learned how to use AI-enabled tools req...
# 5907        No, I learned something that was not related t...
# 6187        Yes, I learned how to use AI-enabled tools req...
# 6273        Yes, I learned how to use AI-enabled tools for...
# 6374        No, I didn't spend time learning in the past year
# 8126        Yes, I learned how to use AI-enabled tools for...
# 9431        No, I learned something that was not related t...
# 9749        Yes, I learned how to use AI-enabled tools for...
# 11971       Yes, I learned how to use AI-enabled tools for...
# 12407       Yes, I learned how to use AI-enabled tools req...
# 12601       Yes, I learned how to use AI-enabled tools req...
# 12617       No, I learned something that was not related t...
# 15044       Yes, I learned how to use AI-enabled tools for...
# 18933       Yes, I learned how to use AI-enabled tools req...
# 19054       Yes, I learned how to use AI-enabled tools req...
# 21022       Yes, I learned how to use AI-enabled tools for...
# 21086       Yes, I learned how to use AI-enabled tools for...
# 22124       Yes, I learned how to use AI-enabled tools for...
# 23413       No, I learned something that was not related t...
# 23844       Yes, I learned how to use AI-enabled tools for...
# 26989       Yes, I learned how to use AI-enabled tools for...
# 28294       Yes, I learned how to use AI-enabled tools for...
# 29890       No, I didn't spend time learning in the past year
# 30705       Yes, I learned how to use AI-enabled tools req...
# 31172       Yes, I learned how to use AI-enabled tools for...
# 32290       No, I learned something that was not related t...
# 32303       Yes, I learned how to use AI-enabled tools for...
# 32690       Yes, I learned how to use AI-enabled tools for...
# 34114       Yes, I learned how to use AI-enabled tools req...
# 34127       Yes, I learned how to use AI-enabled tools req...
# 35935       Yes, I learned how to use AI-enabled tools req...
# 36755       Yes, I learned how to use AI-enabled tools for...
# 37696       Yes, I learned how to use AI-enabled tools for...
# 37785       Yes, I learned how to use AI-enabled tools req...
# 39433       Yes, I learned how to use AI-enabled tools for...
# 39580       Yes, I learned how to use AI-enabled tools req...
# 41951       Yes, I learned how to use AI-enabled tools for...
# 42256       Yes, I learned how to use AI-enabled tools req...
# 42915       Yes, I learned how to use AI-enabled tools for...
# 43405       Yes, I learned how to use AI-enabled tools req...
# 45932       No, I didn't spend time learning in the past year
# 46416       No, I didn't spend time learning in the past year
# 48369       No, I learned something that was not related t...
#
#                                                    AILearnHow  YearsCode  \
# ResponseId
# 1883                      AI CodeGen tools or AI-enabled apps        5.0
# 2873        AI CodeGen tools or AI-enabled apps;Videos (no...       24.0
# 3064                                                      NaN       15.0
# 3233                                                      NaN        7.0
# 4438        Technical documentation (is generated for/by t...       12.0
# 5901        AI CodeGen tools or AI-enabled apps;Videos (no...        7.0
# 5907                                                      NaN       10.0
# 6187                      AI CodeGen tools or AI-enabled apps       14.0
# 6273        Technical documentation (is generated for/by t...        4.0
# 6374                                                      NaN       10.0
# 8126        AI CodeGen tools or AI-enabled apps;Technical ...        6.0
# 9431                                                      NaN        8.0
# 9749        Online Courses or Certification (includes all ...       15.0
# 11971       Videos (not associated with specific online co...        6.0
# 12407       AI CodeGen tools or AI-enabled apps;Technical ...        6.0
# 12601       Other online resources (e.g. standard search, ...        8.0
# 12617                                                     NaN        4.0
# 15044       Other online resources (e.g. standard search, ...        8.0
# 18933       AI CodeGen tools or AI-enabled apps;Videos (no...        5.0
# 19054       Technical documentation (is generated for/by t...       24.0
# 21022       Stack Overflow or Stack Exchange;School (i.e.,...       10.0
# 21086       Technical documentation (is generated for/by t...       30.0
# 22124       Videos (not associated with specific online co...       18.0
# 23413                                                     NaN       10.0
# 23844                     AI CodeGen tools or AI-enabled apps        2.0
# 26989       AI CodeGen tools or AI-enabled apps;Technical ...        7.0
# 28294                     AI CodeGen tools or AI-enabled apps       10.0
# 29890                                                     NaN        6.0
# 30705       Other online resources (e.g. standard search, ...        8.0
# 31172       Other online resources (e.g. standard search, ...        5.0
# 32290                                                     NaN       15.0
# 32303       AI CodeGen tools or AI-enabled apps;Technical ...        3.0
# 32690       Technical documentation (is generated for/by t...        8.0
# 34114       Online Courses or Certification (includes all ...        7.0
# 34127       Videos (not associated with specific online co...        1.0
# 35935       AI CodeGen tools or AI-enabled apps;Other onli...       12.0
# 36755       Videos (not associated with specific online co...        7.0
# 37696       Technical documentation (is generated for/by t...        5.0
# 37785       AI CodeGen tools or AI-enabled apps;Other onli...        8.0
# 39433       Videos (not associated with specific online co...       10.0
# 39580       Colleague or on-the-job training;Books / Physi...        NaN
# 41951       Other online resources (e.g. standard search, ...        4.0
# 42256       Technical documentation (is generated for/by t...       10.0
# 42915       Technical documentation (is generated for/by t...        2.0
# 43405       Technical documentation (is generated for/by t...       27.0
# 45932                                                     NaN        4.0
# 46416                                                     NaN        3.0
# 48369                                                     NaN       35.0
#
#                                                   DevType  \
# ResponseId
# 1883                     Architect, software or solutions
# 2873          Developer, embedded applications or devices
# 3064                                 Developer, front-end
# 3233                          Developer, game or graphics
# 4438                                 Developer, front-end
# 5901                                              Student
# 5907                                Developer, full-stack
# 6187                                  Academic researcher
# 6273                                              Student
# 6374                                  Academic researcher
# 8126                                Developer, full-stack
# 9431                                  Developer, back-end
# 9749                                Developer, full-stack
# 11971                         Developer, game or graphics
# 12407                                 Academic researcher
# 12601                                 Developer, back-end
# 12617                                             Student
# 15044                                             Student
# 18933                                Developer, front-end
# 19054                               Developer, full-stack
# 21022                                             Student
# 21086                                 Academic researcher
# 22124                                 Developer, back-end
# 23413                                 Developer, back-end
# 23844       Developer, desktop or enterprise applications
# 26989                                             Student
# 28294                               Developer, full-stack
# 29890                                             Student
# 30705                               Developer, full-stack
# 31172                                      AI/ML engineer
# 32290                                Developer, front-end
# 32303                                 Developer, back-end
# 32690                               Developer, full-stack
# 34114                                 Developer, back-end
# 34127                                 Developer, back-end
# 35935                                 Academic researcher
# 36755                               Developer, full-stack
# 37696                                             Student
# 37785                               Developer, full-stack
# 39433                                System administrator
# 39580                                Developer, front-end
# 41951                                 Developer, back-end
# 42256                                      AI/ML engineer
# 42915                                             Student
# 43405       Developer, desktop or enterprise applications
# 45932                               Developer, full-stack
# 46416                         Support engineer or analyst
# 48369                             Other (please specify):
#
#                                                       OrgSize  \
# ResponseId
# 1883                                   Less than 20 employees
# 2873                                                      NaN
# 3064                                   Less than 20 employees
# 3233                                       20 to 99 employees
# 4438                                       20 to 99 employees
# 5901                                                      NaN
# 5907                                                      NaN
# 6187                                   Less than 20 employees
# 6273                                                      NaN
# 6374                                   Less than 20 employees
# 8126                                       20 to 99 employees
# 9431                                     500 to 999 employees
# 9749                                                      NaN
# 11971                                                     NaN
# 12407                                  Less than 20 employees
# 12601                                                     NaN
# 12617                                                     NaN
# 15044                                                     NaN
# 18933                                5,000 to 9,999 employees
# 19054                                  Less than 20 employees
# 21022       Just me - I am a freelancer, sole proprietor, ...
# 21086                                                     NaN
# 22124                                      20 to 99 employees
# 23413                                  Less than 20 employees
# 23844       Just me - I am a freelancer, sole proprietor, ...
# 26989                                                     NaN
# 28294                                      20 to 99 employees
# 29890                                                     NaN
# 30705                                  Less than 20 employees
# 31172                                  Less than 20 employees
# 32290                                      20 to 99 employees
# 32303                                                     NaN
# 32690                                  Less than 20 employees
# 34114                                5,000 to 9,999 employees
# 34127                                  Less than 20 employees
# 35935                                                     NaN
# 36755                                  Less than 20 employees
# 37696                                                     NaN
# 37785                                      20 to 99 employees
# 39433                                1,000 to 4,999 employees
# 39580                                      20 to 99 employees
# 41951                                                     NaN
# 42256                                                     NaN
# 42915                                                     NaN
# 43405                                10,000 or more employees
# 45932                                10,000 or more employees
# 46416                                  Less than 20 employees
# 48369                                                     NaN
#
#                             ICorPM  \
# ResponseId
# 1883        Individual contributor
# 2873                           NaN
# 3064        Individual contributor
# 3233        Individual contributor
# 4438        Individual contributor
# 5901                           NaN
# 5907                           NaN
# 6187        Individual contributor
# 6273                           NaN
# 6374        Individual contributor
# 8126        Individual contributor
# 9431        Individual contributor
# 9749                           NaN
# 11971                          NaN
# 12407       Individual contributor
# 12601                          NaN
# 12617                          NaN
# 15044                          NaN
# 18933       Individual contributor
# 19054       Individual contributor
# 21022       Individual contributor
# 21086                          NaN
# 22124       Individual contributor
# 23413       Individual contributor
# 23844       Individual contributor
# 26989                          NaN
# 28294       Individual contributor
# 29890                          NaN
# 30705       Individual contributor
# 31172       Individual contributor
# 32290       Individual contributor
# 32303                          NaN
# 32690               People manager
# 34114       Individual contributor
# 34127       Individual contributor
# 35935                          NaN
# 36755               People manager
# 37696                          NaN
# 37785       Individual contributor
# 39433       Individual contributor
# 39580       Individual contributor
# 41951                          NaN
# 42256                          NaN
# 42915                          NaN
# 43405       Individual contributor
# 45932       Individual contributor
# 46416       Individual contributor
# 48369                          NaN
#
#                                                    RemoteWork  \
# ResponseId
# 1883        Hybrid (some in-person, leans heavy to flexibi...
# 2873                                                      NaN
# 3064        Hybrid (some in-person, leans heavy to flexibi...
# 3233                                                In-person
# 4438                                                In-person
# 5901                                                      NaN
# 5907                                                      NaN
# 6187                                                In-person
# 6273                                                      NaN
# 6374        Hybrid (some in-person, leans heavy to flexibi...
# 8126           Hybrid (some remote, leans heavy to in-person)
# 9431        Hybrid (some in-person, leans heavy to flexibi...
# 9749                                                      NaN
# 11971                                                     NaN
# 12407                                               In-person
# 12601                                                     NaN
# 12617                                                     NaN
# 15044                                                     NaN
# 18933       Hybrid (some in-person, leans heavy to flexibi...
# 19054                                                  Remote
# 21022                                                  Remote
# 21086                                                     NaN
# 22124                                                  Remote
# 23413                                                  Remote
# 23844                                               In-person
# 26989                                                     NaN
# 28294                                               In-person
# 29890                                                     NaN
# 30705                                               In-person
# 31172                                               In-person
# 32290          Hybrid (some remote, leans heavy to in-person)
# 32303                                                     NaN
# 32690          Hybrid (some remote, leans heavy to in-person)
# 34114                                               In-person
# 34127                                               In-person
# 35935                                                     NaN
# 36755          Hybrid (some remote, leans heavy to in-person)
# 37696                                                     NaN
# 37785                                               In-person
# 39433                                               In-person
# 39580          Hybrid (some remote, leans heavy to in-person)
# 41951                                                     NaN
# 42256                                                     NaN
# 42915                                                     NaN
# 43405                                               In-person
# 45932                                               In-person
# 46416          Hybrid (some remote, leans heavy to in-person)
# 48369                                                     NaN
#
#                                             PurchaseInfluence  \
# ResponseId
# 1883        Yes, I endorsed a tool that was ultimately not...
# 2873                                                       No
# 3064        Yes, I influenced the purchase of a substantia...
# 3233                                                       No
# 4438                                                       No
# 5901                                                      NaN
# 5907                                                      NaN
# 6187        Yes, I endorsed a tool that was open-source an...
# 6273                                                      NaN
# 6374                                                       No
# 8126                                                       No
# 9431        Yes, I influenced the purchase of a tool that ...
# 9749        Yes, I endorsed a tool that was open-source an...
# 11971                                                     NaN
# 12407                                                      No
# 12601                                                     NaN
# 12617                                                     NaN
# 15044                                                     NaN
# 18933       Yes, I influenced the purchase of a substantia...
# 19054       Yes, I influenced the purchase of a substantia...
# 21022                                                      No
# 21086                                                     NaN
# 22124                                                     NaN
# 23413       Yes, I endorsed a tool that was open-source an...
# 23844       Yes, I influenced the purchase of a substantia...
# 26989                                                     NaN
# 28294       Yes, I influenced the purchase of a substantia...
# 29890                                                     NaN
# 30705       Yes, I influenced the purchase of a substantia...
# 31172       Yes, I influenced the purchase of a substantia...
# 32290       Yes, I influenced the purchase of a tool that ...
# 32303                                                     NaN
# 32690       Yes, I influenced the purchase of a substantia...
# 34114       Yes, I endorsed a tool that was open-source an...
# 34127       Yes, I influenced the purchase of a substantia...
# 35935                                                     NaN
# 36755       Yes, I influenced the purchase of a substantia...
# 37696                                                     NaN
# 37785       Yes, I endorsed a tool that was open-source an...
# 39433                                                      No
# 39580                                                      No
# 41951       Yes, I influenced the purchase of a substantia...
# 42256       Yes, I endorsed a tool that was open-source an...
# 42915                                                     NaN
# 43405       Yes, I endorsed a tool that was ultimately not...
# 45932                                                      No
# 46416                                                      No
# 48369       Yes, I influenced the purchase of a substantia...
#
#             TechEndorseIntro  TechEndorse_1  TechEndorse_2  TechEndorse_3  \
# ResponseId
# 1883                    Work           10.0            3.0            9.0
# 2873        Personal Project            9.0            5.0            3.0
# 3064                    Work           10.0            2.0            1.0
# 3233                    Work            7.0            2.0            8.0
# 4438                    Work            6.0            1.0            2.0
# 5901        Personal Project            9.0            4.0            5.0
# 5907        Personal Project            9.0            7.0            4.0
# 6187                  School            7.0            2.0            3.0
# 6273                  School            9.0            4.0            7.0
# 6374                    Work            8.0            7.0            6.0
# 8126                     NaN            NaN            NaN            NaN
# 9431                    Work            9.0            5.0            2.0
# 9749                    Work            9.0            1.0            2.0
# 11971                 School            9.0            5.0            6.0
# 12407                   Work            NaN            NaN            NaN
# 12601                   Work            7.0            6.0            5.0
# 12617       Personal Project            5.0            7.0            2.0
# 15044       Personal Project            9.0            3.0            4.0
# 18933                   Work            9.0            4.0            3.0
# 19054                   Work            6.0            5.0            1.0
# 21022       Personal Project            9.0            6.0            5.0
# 21086                   Work            8.0            5.0            6.0
# 22124       Personal Project            9.0            4.0            6.0
# 23413                   Work            9.0            2.0            5.0
# 23844       Personal Project            4.0            7.0            6.0
# 26989       Personal Project            8.0            2.0            4.0
# 28294       Personal Project            4.0            2.0            8.0
# 29890                 School            8.0            5.0            9.0
# 30705                   Work            3.0            8.0            7.0
# 31172       Personal Project            6.0            5.0            4.0
# 32290                   Work            8.0            3.0            4.0
# 32303       Personal Project            9.0            6.0            7.0
# 32690                   Work            8.0            7.0            1.0
# 34114                   Work            1.0            3.0            4.0
# 34127                   Work            9.0            2.0            1.0
# 35935                 School            7.0            8.0            1.0
# 36755                   Work            7.0            5.0            2.0
# 37696                 School            9.0            1.0            5.0
# 37785                 School            1.0            2.0            5.0
# 39433                   Work            8.0            5.0            3.0
# 39580                   Work            9.0            2.0            7.0
# 41951                   Work            8.0            7.0            5.0
# 42256       Personal Project            7.0            5.0            6.0
# 42915                 School            5.0            9.0            7.0
# 43405       Personal Project            NaN            NaN            NaN
# 45932                   Work            8.0            6.0            5.0
# 46416       Personal Project            4.0            3.0            6.0
# 48369                   Work            9.0            5.0            2.0
#
#             TechEndorse_4  TechEndorse_5  TechEndorse_6  TechEndorse_7  \
# ResponseId
# 1883                  5.0            6.0           13.0            7.0
# 2873                  6.0            8.0            4.0            7.0
# 3064                  3.0            6.0            7.0            8.0
# 3233                  5.0            1.0            3.0            9.0
# 4438                  8.0            4.0            5.0            7.0
# 5901                  6.0            1.0            8.0            3.0
# 5907                  2.0            5.0            1.0            8.0
# 6187                  5.0            1.0            8.0            9.0
# ...
# 23844                   NaN                                   NaN
# 26989                   NaN                                   NaN
# 28294                   NaN                                   NaN
# 29890                   NaN                                   NaN
# 30705                   NaN                                   NaN
# 31172                   NaN                                   NaN
# 32290                   NaN                                   NaN
# 32303                   NaN                                   NaN
# 32690                   NaN                  Grafana + Prometheus
# 34114                   NaN                                   NaN
# 34127                   NaN                                   NaN
# 35935                   NaN                                   NaN
# 36755                   NaN                  Grafana + Prometheus
# 37696                   NaN                                   NaN
# 37785                   NaN                                   NaN
# 39433                   NaN                                   NaN
# 39580                   NaN  Adversarial Robustness Toolbox (ART)
# 41951                   NaN                             LangSmith
# 42256                   NaN                                   NaN
# 42915                   NaN                                   NaN
# 43405                   NaN                                   NaN
# 45932                   NaN                                   NaN
# 46416                   NaN                                   NaN
# 48369                   NaN                                   NaN
#
#            AIAgentObsWrite                                    AIAgentExternal  \
# ResponseId
# 1883                   NaN                                                NaN
# 2873                   NaN   ChatGPT;Claude Code;GitHub Copilot;Google Gemini
# 3064                   NaN                                                NaN
# 3233                   NaN                             ChatGPT;GitHub Copilot
# 4438                   NaN          ChatGPT;Claude Code;Google Gemini;Tabnine
# 5901                   NaN  ChatGPT;Claude Code;Google Gemini;Roo code (Ro...
# 5907                   NaN                                                NaN
# 6187                   NaN  ChatGPT;Claude Code;GitHub Copilot;Google Gemi...
# 6273                   NaN                                                NaN
# 6374                   NaN                                                NaN
# 8126                   NaN                                                NaN
# 9431                   NaN                                                NaN
# 9749                   NaN                                                NaN
# 11971                  NaN  ChatGPT;GitHub Copilot;Google Gemini;Microsoft...
# 12407                  NaN                                                NaN
# 12601                  NaN                                                NaN
# 12617                  NaN                                                NaN
# 15044                  NaN                                                NaN
# 18933                  NaN  ChatGPT;GitHub Copilot;Google Gemini;OpenHands...
# 19054                  NaN                      Claude Code;Microsoft Copilot
# 21022                  NaN                                                NaN
# 21086                  NaN                                                NaN
# 22124                  NaN                                      Google Gemini
# 23413                  NaN                                                NaN
# 23844                  NaN                                                NaN
# 26989                  NaN                                                NaN
# 28294                  NaN                                                NaN
# 29890                  NaN                             ChatGPT;GitHub Copilot
# 30705                  NaN                                                NaN
# 31172                  NaN                                                NaN
# 32290                  NaN                                ChatGPT;Claude Code
# 32303                  NaN                                                NaN
# 32690                  NaN                          Claude Code;Google Gemini
# 34114                  NaN                                                NaN
# 34127                  NaN                                                NaN
# 35935                  NaN                                                NaN
# 36755                  NaN           Claude Code;GitHub Copilot;Google Gemini
# 37696                  NaN                                                NaN
# 37785                  NaN                                                NaN
# 39433                  NaN                                                NaN
# 39580                  NaN                                                NaN
# 41951                  NaN                              ChatGPT;Google Gemini
# 42256                  NaN                            GitHub Copilot;Auto-GPT
# 42915                  NaN                                                NaN
# 43405                  NaN                                                NaN
# 45932                  NaN                                                NaN
# 46416                  NaN                                                NaN
# 48369                  NaN                                                NaN
#
#               AIAgentExtWrite  \
# ResponseId
# 1883                      NaN
# 2873                      NaN
# 3064                      NaN
# 3233                      NaN
# 4438                      NaN
# 5901        T3 Chat, Windsurf
# 5907                      NaN
# 6187                      NaN
# 6273                      NaN
# 6374                      NaN
# 8126                      NaN
# 9431                      NaN
# 9749                      NaN
# 11971                     NaN
# 12407                     NaN
# 12601                     NaN
# 12617                     NaN
# 15044                     NaN
# 18933                     NaN
# 19054                     NaN
# 21022                     NaN
# 21086                     NaN
# 22124                     NaN
# 23413                     NaN
# 23844                     NaN
# 26989                     NaN
# 28294                     NaN
# 29890                     NaN
# 30705                     NaN
# 31172                     NaN
# 32290                     NaN
# 32303                     NaN
# 32690                     NaN
# 34114                     NaN
# 34127                     NaN
# 35935                     NaN
# 36755                     NaN
# 37696                     NaN
# 37785                     NaN
# 39433                     NaN
# 39580                     NaN
# 41951                     NaN
# 42256                     NaN
# 42915                     NaN
# 43405                     NaN
# 45932                     NaN
# 46416                     NaN
# 48369                     NaN
#
#                                                       AIHuman  \
# ResponseId
# 1883                When I want to fully understand something
# 2873        When I don’t trust AI’s answers;When I want to...
# 3064        When I don’t trust AI’s answers;When I want to...
# 3233                   When I need quick help troubleshooting
# 4438         I don’t think I’ll need help from people anymore
# 5901        When I don’t trust AI’s answers;When I want to...
# 5907        When I don’t trust AI’s answers;When I want to...
# 6187        When I don’t trust AI’s answers;When I want to...
# 6273        When I don’t trust AI’s answers;When I want to...
# 6374        When I don’t trust AI’s answers;When I want to...
# 8126        When I don’t trust AI’s answers;When I want to...
# 9431        When I don’t trust AI’s answers;When I want to...
# 9749                                                      NaN
# 11971       When I don’t trust AI’s answers;When I want to...
# 12407                                                     NaN
# 12601       When I don’t trust AI’s answers;When I want to...
# 12617       When I don’t trust AI’s answers;When I have et...
# 15044       When I don’t trust AI’s answers;When I want to...
# 18933       When I want to fully understand something;When...
# 19054       When I don’t trust AI’s answers;When I want to...
# 21022                         When I don’t trust AI’s answers
# 21086            When I’m stuck and can’t explain the problem
# 22124        I don’t think I’ll need help from people anymore
# 23413       When I don’t trust AI’s answers;When I want to...
# 23844                                                     NaN
# 26989                                                     NaN
# 28294                                                     NaN
# 29890       When I don’t trust AI’s answers;When I’m stuck...
# 30705                                                     NaN
# 31172       When I don’t trust AI’s answers;When I have et...
# 32290       When I don’t trust AI’s answers;When I want to...
# 32303       When I don’t trust AI’s answers;When I want to...
# 32690       When I don’t trust AI’s answers;When I have et...
# 34114                                                     NaN
# 34127                                                     NaN
# 35935       When I don’t trust AI’s answers;When I have et...
# 36755       When I don’t trust AI’s answers;When I want to...
# 37696       When I don’t trust AI’s answers;When I want to...
# 37785       When I don’t trust AI’s answers;When I want to...
# 39433                                                     NaN
# 39580            When I’m stuck and can’t explain the problem
# 41951       When I don’t trust AI’s answers;When I want to...
# 42256       When I want to fully understand something;When...
# 42915                                                     NaN
# 43405                                                     NaN
# 45932                                                     NaN
# 46416       When I don’t trust AI’s answers;When I want to...
# 48369                                                     NaN
#
#                                                        AIOpen  \
# ResponseId
# 1883                                                      NaN
# 2873        Having deep domain knowledge of obscure areas ...
# 3064                                     Being able to think.
# 3233                                        non-Hallucination
# 4438                                                     none
# 5901                                    Asking good questions
# 5907        Developers are humans. We value what we make. ...
# 6187        Identifying correct problems to solve, and ver...
# 6273        Testing and analyze codebase, Reading and unde...
# 6374                                                      NaN
# 8126                      Skill for code review would remain.
# 9431        Core knowledge of Computer Science. The more y...
# 9749                                                      NaN
# 11971       Low level programming, Debugging, Learning new...
# 12407                                                     NaN
# 12601                                           Communication
# 12617                                ability to solve problem
# 15044                                                     NaN
# 18933                              Architect, troubleshooting
# 19054       The ability to explain what we need to solve a...
# 21022                    creativity. what production to build
# 21086       Integration of the computer codings from diver...
# 22124                                    Communication skills
# 23413       In-depth knowledge of their domain (eg how pro...
# 23844                                                     NaN
# 26989                                                     NaN
# 28294                                                     NaN
# 29890                                                     NaN
# 30705                                                     NaN
# 31172           Problem Solving with good calculus background
# 32290       Consideration of real-world problems and appro...
# 32303                                                 cooking
# 32690                                        how to read code
# 34114                                                     NaN
# 34127                                                     NaN
# 35935                                                     NaN
# 36755                                             code review
# 37696                                                     NaN
# 37785                                                     NaN
# 39433                                                     NaN
# 39580                                                     NaN
# 41951       knowledge for building system (architect & infra)
# 42256                                                     NaN
# 42915                                                     NaN
# 43405                                                     NaN
# 45932                                                     NaN
# 46416                                                     NaN
# 48369                                                     NaN
#
#             ConvertedCompYearly  JobSat
# ResponseId
# 1883                        NaN     8.0
# 2873                   293971.0    10.0
# 3064                    53348.0     5.0
# 3233                        NaN     NaN
# 4438                    48505.0     6.0
# 5901                        NaN     NaN
# 5907                        NaN     NaN
# 6187                        2.0    10.0
# 6273                        NaN     NaN
# 6374                        NaN     NaN
# 8126                    33072.0     8.0
# 9431                    45565.0     6.0
# 9749                        NaN     6.0
# 11971                       NaN     3.0
# 12407                    9119.0     NaN
# 12601                       NaN     6.0
# 12617                       NaN     NaN
# 15044                       NaN     NaN
# 18933                       NaN     9.0
# 19054                   73493.0     9.0
# 21022                    1470.0     NaN
# 21086                    2205.0     NaN
# 22124                       5.0     3.0
# 23413                  140000.0     8.0
# 23844                    7349.0     NaN
# 26989                       NaN     NaN
# 28294                   33072.0     9.0
# 29890                       NaN     8.0
# 30705                   23518.0     5.0
# 31172                   18520.0     4.0
# 32290                   64674.0     7.0
# 32303                   10000.0     6.0
# 32690                   44096.0     8.0
# 34114                       NaN     7.0
# 34127                       NaN     2.0
# 35935                       NaN     7.0
# 36755                   44096.0     8.0
# 37696                       NaN     NaN
# 37785                   26457.0     9.0
# 39433                       NaN     NaN
# 39580                       NaN     5.0
# 41951                   24988.0    10.0
# 42256                       NaN     NaN
# 42915                       NaN     NaN
# 43405                       NaN     8.0
# 45932                   36746.0     0.0
# 46416                       NaN     NaN
# 48369                       NaN     NaN

# %%
country_grp["ConvertedCompYearly"].value_counts().head(50)
# Out:
# Country              ConvertedCompYearly
# Afghanistan          1000.0                 1
#                      8450.0                 1
#                      65000.0                1
#                      986.0                  1
#                      5200.0                 1
#                      282.0                  1
#                      9858.0                 1
#                      7042.0                 1
# Albania              139218.0               1
#                      67779.0                1
#                      15.0                   1
#                      17734.0                1
#                      14187.0                1
#                      118286.0               1
#                      8.0                    1
#                      236.0                  1
#                      116014.0               1
#                      34804.0                1
#                      50000.0                1
#                      17402.0                1
# Algeria              4438.0                 1
#                      1156.0                 1
#                      7088.0                 1
#                      98612.0                1
#                      12000.0                1
#                      23114.0                1
#                      17.0                   1
#                      6472.0                 1
#                      2400.0                 1
#                      1109.0                 1
#                      50000.0                1
#                      3852.0                 1
#                      7705.0                 1
#                      185.0                  1
#                      20883.0                1
# Andorra              400000.0               1
#                      34804.0                1
#                      348044.0               1
#                      52207.0                1
# Angola               13922.0                1
#                      5234.0                 1
#                      580073.0               1
#                      200.0                  1
# Antigua and Barbuda  1.0                    1
# Argentina            100000.0               7
#                      120000.0               6
#                      42653.0                5
#                      34122.0                4
#                      50000.0                3
#                      60000.0                3
# Name: count, dtype: int64

# %%
country_grp["ConvertedCompYearly"].median().loc["Ukraine"]
# Out:
# np.float64(25021.0)

# %%
country_grp["ConvertedCompYearly"].agg(["median", "mean"])
# Out:
#                                                       median           mean
# Country
# Afghanistan                                           6121.0   12227.250000
# Albania                                              26269.0   47973.583333
# Algeria                                               6472.0   15935.400000
# Andorra                                             200125.5  208763.750000
# Angola                                                9578.0  149857.250000
# Antigua and Barbuda                                      1.0       1.000000
# Argentina                                            40000.0   46271.187500
# Armenia                                               9076.0   25016.363636
# Australia                                            97514.0  115941.413005
# Austria                                              78310.0   79477.625000
# Azerbaijan                                           29397.0   31202.333333
# Bahrain                                              74240.5   74240.500000
# Bangladesh                                            7895.5   15520.941667
# Barbados                                             45450.5   45450.500000
# Belarus                                              46614.5   58267.312500
# Belgium                                              69609.0   84666.275229
# Belize                                              102121.0  102121.000000
# Benin                                                 1698.0    6816.333333
# Bhutan                                               20361.0   20361.000000
# Bolivia                                              18784.0   25214.307692
# Bosnia and Herzegovina                               47000.0   51890.473684
# Botswana                                              1277.0    1277.000000
# Brazil                                               27306.0   51690.289515
# Brunei Darussalam                                        NaN            NaN
# Bulgaria                                             49817.5   54613.575949
# Burundi                                               1697.0    1697.000000
# Cambodia                                              1500.0    4694.000000
# Cameroon                                              1265.5    4547.000000
# Canada                                               87550.0  100143.382514
# Cape Verde                                               NaN            NaN
# Chile                                                33930.0   39241.252632
# China                                                34125.0   47847.632479
# Colombia                                             20500.0   31370.534351
# Congo, Republic of the...                            42811.5   42811.500000
# Costa Rica                                           59500.0   71422.111111
# Croatia                                              46406.0   55424.829268
# Cuba                                                 14041.5   71668.875000
# Cyprus                                               92812.0   91799.041667
# Czech Republic                                       60660.0   67003.573407
# Côte d'Ivoire                                        33966.0   75877.200000
# Democratic People's Republic of Korea                    NaN            NaN
# Democratic Republic of the Congo                     30000.0   33000.000000
# Denmark                                              98678.0  106030.465217
# Djibouti                                              5833.0    5833.000000
# Dominican Republic                                   27681.5   44179.600000
# Ecuador                                              30000.0   40952.260870
# Egypt                                                 6595.0   14453.921875
# El Salvador                                          27000.0   41800.000000
# Estonia                                              69609.0   76545.326923
# Ethiopia                                               762.0   33087.166667
# Fiji                                                     NaN            NaN
# Finland                                              74249.0   85162.361257
# France                                               63228.0   73778.737098
# Gabon                                                    NaN            NaN
# Gambia                                                   NaN            NaN
# Georgia                                              53653.5   56644.250000
# Germany                                              81210.0   86443.718356
# Ghana                                                 2610.0    9833.318182
# Greece                                               44260.0   53055.137931
# Guatemala                                            29668.0   37647.896552
# Guinea                                                2773.0    2773.000000
# Guinea-Bissau                                            NaN            NaN
# Guyana                                               35871.0   31566.333333
# Haiti                                                 9149.0    9149.000000
# Honduras                                             11982.0   22198.833333
# Hong Kong (S.A.R.)                                   76433.0  111564.300000
# Hungary                                              46266.0   55376.591716
# Iceland                                             117637.0   88158.714286
# India                                                17029.0   44291.789234
# Indonesia                                             5638.0   17902.716049
# Iran, Islamic Republic of...                         18516.0  277297.200000
# Iraq                                                 18000.0   15420.666667
# Ireland                                             116015.0  121326.818182
# Isle of Man                                          83632.0   82521.444444
# Israel                                              141188.0  131723.762712
# Italy                                                47566.0   55911.454389
# Jamaica                                              96796.5   96796.500000
# Japan                                                58725.0   73440.617188
# Jordan                                               30000.0   34879.826087
# Kazakhstan                                           28381.5   33210.611111
# Kenya                                                 6502.0   31946.506849
# Kosovo                                               45245.5   50176.250000
# Kuwait                                               26838.0   44543.600000
# Kyrgyzstan                                           12605.0   41211.000000
# Lao People's Democratic Republic                         7.0       7.000000
# Latvia                                               51845.5   84648.050000
# Lebanon                                              47000.0   77244.444444
# Lesotho                                               2822.0    2822.000000
# Libyan Arab Jamahiriya                                5541.0    5541.000000
# Lithuania                                            66708.0   71457.739130
# Luxembourg                                           98612.0  101348.235294
# Madagascar                                            5288.0   16751.125000
# Malawi                                               11252.5   11252.500000
# Malaysia                                             18261.0   24403.434783
# Maldives                                             24600.5   25039.500000
# Mali                                                 11941.5   11941.500000
# Malta                                                70189.0   69516.187500
# Mauritania                                          121570.0  121570.000000
# Mauritius                                            15976.0   16405.800000
# Mexico                                               28951.0   37245.638743
# Micronesia, Federated States of...                       1.0       1.000000
# Moldova                                              29177.5   37324.500000
# Mongolia                                             29757.0   31626.666667
# Montenegro                                           42873.0   59133.916667
# Morocco                                              21987.0   24531.695652
# Mozambique                                            9381.0   36629.200000
# Myanmar                                               5716.0    8404.200000
# Namibia                                               3923.0    8024.333333
# Nepal                                                 4060.0   25012.536585
# Netherlands                                          81210.0  115292.822294
# New Zealand                                          81318.0   81957.436464
# Nicaragua                                            47000.0   67822.500000
# Niger                                                    NaN            NaN
# Nigeria                                               1291.0   63181.843137
# Nomadic                                             135157.5  135473.833333
# North Korea                                         233924.5  233924.500000
# Norway                                               88945.0   99256.809783
# Oman                                                390135.0  261217.000000
# Pakistan                                              6321.0   12997.733333
# Palau                                                    NaN            NaN
# Palestine                                               78.0      78.000000
# Panama                                               26400.0   55300.000000
# Papua New Guinea                                      7574.0    7574.000000
# Paraguay                                             21178.0   42256.000000
# Peru                                                 16998.0   31296.575000
# Philippines                                          12291.0   23956.063291
# Poland                                               60038.0   97821.346350
# Portugal                                             60908.0   74386.754630
# Qatar                                                46111.0   46111.000000
# Republic of Korea                                    44096.0   82366.555556
# Republic of Moldova                                  46924.0   51249.400000
# Republic of North Macedonia                          29472.0   31328.300000
# Romania                                              57437.0   64200.027907
# Russian Federation                                   38278.0   42168.700787
# Rwanda                                               15591.5   16245.700000
# Saint Lucia                                          30810.5   30810.500000
# San Marino                                               NaN            NaN
# Saudi Arabia                                         32789.0   49335.388889
# Senegal                                              11786.5   11786.500000
# Serbia                                               48000.0   57883.798165
# Sierra Leone                                             NaN            NaN
# Singapore                                            92563.0  131430.187500
# Slovakia                                             55687.0   58923.165049
# Slovenia                                             56847.0   73555.661290
# Somalia                                               5300.0    6766.666667
# South Africa                                         43412.0   78843.243243
# South Korea                                          33072.0   44968.304348
# Spain                                                62648.0   70795.607143
# Sri Lanka                                            10391.0   21905.372881
# Sudan                                                 4864.5    4864.500000
# Suriname                                             18686.5   18686.500000
# Swaziland                                             4848.5    8145.250000
# Sweden                                               70440.0   73943.915074
# Switzerland                                         142592.0  151290.444976
# Syrian Arab Republic                                  9845.5   13265.166667
# Taiwan                                               33886.0   41913.571429
# Tajikistan                                               NaN            NaN
# Thailand                                             32123.0   47619.614035
# Timor-Leste                                              NaN            NaN
# Togo                                                   711.0    3688.333333
# Trinidad and Tobago                                  29595.0   37923.250000
# Tunisia                                               6517.0   13840.520000
# Turkey                                               29000.0   38163.090426
# Turkmenistan                                         35000.0   35000.000000
# Uganda                                                4588.0   14159.833333
# Ukraine                                              25021.0  105101.259520
# United Arab Emirates                                 54460.0  105481.808511
# United Kingdom of Great Britain and Northern Ir...   94618.0  112948.493943
# United Republic of Tanzania                           5014.0   12041.200000
# United States of America                            150000.0  179804.501621
# Uruguay                                              49338.0   78567.414634
# Uzbekistan                                            9675.0   12593.555556
# Venezuela, Bolivarian Republic of...                  9000.0   17008.400000
# Viet Nam                                              7642.0  189894.192982
# Yemen                                                 5545.5   17582.500000
# Zambia                                                1966.5    6594.875000
# Zimbabwe                                             17500.0   25662.500000

# %%
filt =df["Country"] == "South Korea"
df.loc[filt]["LanguageHaveWorkedWith"].str.contains("Python").sum()
# Out:
# np.int64(23)

# %%
country_grp["LanguageHaveWorkedWith"].apply(lambda x: x.str.contains("Python").sum() / x.count() * 100)
# Out:
# /tmp/ipykernel_216203/2906370951.py:1: RuntimeWarning: invalid value encountered in scalar divide
#   country_grp["LanguageHaveWorkedWith"].apply(lambda x: x.str.contains("Python").sum() / x.count() * 100)
# Country
# Afghanistan                                              44.444444
# Albania                                                  47.619048
# Algeria                                                  63.888889
# Andorra                                                  40.000000
# Angola                                                   33.333333
# Antigua and Barbuda                                     100.000000
# Argentina                                                54.271357
# Armenia                                                  35.000000
# Australia                                                56.258412
# Austria                                                  57.069409
# Azerbaijan                                               50.000000
# Bahrain                                                  80.000000
# Bangladesh                                               49.438202
# Barbados                                                 66.666667
# Belarus                                                  31.818182
# Belgium                                                  56.655290
# Belize                                                   50.000000
# Benin                                                    60.000000
# Bhutan                                                   66.666667
# Bolivia                                                  50.000000
# Bosnia and Herzegovina                                   37.037037
# Botswana                                                 50.000000
# Brazil                                                   57.567185
# Brunei Darussalam                                       100.000000
# Bulgaria                                                 47.136564
# Burundi                                                  50.000000
# Cambodia                                                 44.444444
# Cameroon                                                 66.666667
# Canada                                                   57.634228
# Cape Verde                                              100.000000
# Chile                                                    72.566372
# China                                                    68.468468
# Colombia                                                 65.317919
# Congo, Republic of the...                                33.333333
# Costa Rica                                               66.666667
# Croatia                                                  43.564356
# Cuba                                                     75.000000
# Cyprus                                                   45.454545
# Czech Republic                                           54.756871
# Côte d'Ivoire                                            66.666667
# Democratic People's Republic of Korea                   100.000000
# Democratic Republic of the Congo                         50.000000
# Denmark                                                  53.356890
# Djibouti                                                  0.000000
# Dominican Republic                                       55.000000
# Ecuador                                                  55.555556
# Egypt                                                    43.269231
# El Salvador                                              30.000000
# Estonia                                                  44.117647
# Ethiopia                                                 40.740741
# Fiji                                                    100.000000
# Finland                                                  64.315353
# France                                                   62.739097
# Gabon                                                          NaN
# Gambia                                                  100.000000
# Georgia                                                  50.000000
# Germany                                                  60.286225
# Ghana                                                    71.428571
# Greece                                                   51.801802
# Guatemala                                                58.620690
# Guinea                                                  100.000000
# Guinea-Bissau                                           100.000000
# Guyana                                                   50.000000
# Haiti                                                   100.000000
# Honduras                                                 40.000000
# Hong Kong (S.A.R.)                                       56.060606
# Hungary                                                  54.298643
# Iceland                                                  77.777778
# India                                                    57.524752
# Indonesia                                                48.051948
# Iran, Islamic Republic of...                             46.280992
# Iraq                                                     50.000000
# Ireland                                                  53.886010
# Isle of Man                                              50.000000
# Israel                                                   65.283019
# Italy                                                    57.978723
# Jamaica                                                  50.000000
# Japan                                                    58.381503
# Jordan                                                   44.000000
# Kazakhstan                                               60.714286
# Kenya                                                    65.289256
# Kosovo                                                   66.666667
# Kuwait                                                   75.000000
# Kyrgyzstan                                               44.444444
# Lao People's Democratic Republic                         50.000000
# Latvia                                                   56.140351
# Lebanon                                                  60.000000
# Lesotho                                                 100.000000
# Libyan Arab Jamahiriya                                    0.000000
# Lithuania                                                51.041667
# Luxembourg                                               52.631579
# Madagascar                                               62.500000
# Malawi                                                   50.000000
# Malaysia                                                 57.746479
# Maldives                                                 66.666667
# Mali                                                    100.000000
# Malta                                                    68.421053
# Mauritania                                                0.000000
# Mauritius                                                70.000000
# Mexico                                                   57.613169
# Micronesia, Federated States of...                             NaN
# Moldova                                                  44.444444
# Mongolia                                                100.000000
# Montenegro                                               42.857143
# Morocco                                                  62.000000
# Mozambique                                               66.666667
# Myanmar                                                  53.846154
# Namibia                                                  50.000000
# Nepal                                                    55.714286
# Netherlands                                              57.901391
# New Zealand                                              56.431535
# Nicaragua                                                40.000000
# Niger                                                   100.000000
# Nigeria                                                  54.794521
# Nomadic                                                  62.962963
# North Korea                                              75.000000
# Norway                                                   50.691244
# Oman                                                     40.000000
# Pakistan                                                 51.612903
# Palau                                                   100.000000
# Palestine                                                75.000000
# Panama                                                   70.000000
# Papua New Guinea                                         50.000000
# Paraguay                                                 42.105263
# Peru                                                     50.980392
# Philippines                                              59.829060
# Poland                                                   56.877323
# Portugal                                                 60.546875
# Qatar                                                    25.000000
# Republic of Korea                                        61.764706
# Republic of Moldova                                      14.285714
# Republic of North Macedonia                              47.058824
# Romania                                                  46.075085
# Russian Federation                                       59.782609
# Rwanda                                                   75.000000
# Saint Lucia                                             100.000000
# San Marino                                                0.000000
# Saudi Arabia                                             65.517241
# Senegal                                                  25.000000
# Serbia                                                   52.112676
# Sierra Leone                                              0.000000
# Singapore                                                65.384615
# Slovakia                                                 56.204380
# Slovenia                                                 56.164384
# Somalia                                                  25.000000
# South Africa                                             55.357143
# South Korea                                              58.974359
# Spain                                                    60.120846
# Sri Lanka                                                66.233766
# Sudan                                                          NaN
# Suriname                                                100.000000
# Swaziland                                                50.000000
# Sweden                                                   51.504425
# Switzerland                                              63.035019
# Syrian Arab Republic                                     55.555556
# Taiwan                                                   63.000000
# Tajikistan                                               50.000000
# Thailand                                                 57.281553
# Timor-Leste                                               0.000000
# Togo                                                     33.333333
# Trinidad and Tobago                                      28.571429
# Tunisia                                                  63.636364
# Turkey                                                   52.000000
# Turkmenistan                                              0.000000
# Uganda                                                   72.222222
# Ukraine                                                  46.098439
# United Arab Emirates                                     57.352941
# United Kingdom of Great Britain and Northern Ireland     55.126141
# United Republic of Tanzania                              33.333333
# United States of America                                 63.425995
# Uruguay                                                  53.061224
# Uzbekistan                                               66.666667
# Venezuela, Bolivarian Republic of...                     54.761905
# Viet Nam                                                 66.666667
# Yemen                                                    50.000000
# Zambia                                                   70.000000
# Zimbabwe                                                 63.636364
# Name: LanguageHaveWorkedWith, dtype: float64
